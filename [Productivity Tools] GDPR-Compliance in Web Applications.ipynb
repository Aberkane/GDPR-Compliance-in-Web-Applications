# %% [markdown]
# # Assessing GDPR-Compliance in Web Applications: A Machine Learning Approach

# %% [markdown]
# We will assess the GDPR-compliance of web applications based on their privacy policies. We use a classification model, trained on a corpus of 18,397 natural sentences, to classify the privacy policies on whether five General Data Protection Regulation (GDPR) privacy policy core requirements are communicated in the policy.
#
# __Relevance:__ The GDPR applies to any personal data processing of EU citizens. We aim to assess the state of GDPR-compliance in application software based on their privacy policies.
#
# __Focus:__ web applications; as the web application paradigm is widely used due to the omnipresence of web browsers across PCs and mobile devices. In particular, we focus on organisations that provide cloud-based solutions: Cloud Computing, Cloud Data Services, Cloud Infrastructure, Cloud, Management, and Cloud Storage.
#
#
# __Goal:__ to scrutinize the privacy policies of web applications using ML, to assess whether core privacy policy requirements are communicated.
#
# #### __RQ:__ What is the state of GDPR-compliance disclosure in web applications?

# %% [markdown]
# ---

# %% [markdown]
# ### Step 1: collect list of companies active in the Web Apps industry
#
# To do so we utilize the Crunchbase database that allows us to identify companies that provide webbased services, filtered on location (which in our case will be the European Union). We used
#
# We've imported 2792 companies using the following criteria:
# - Industry: Web Services -> Cloud Computing, Cloud Data Services, Cloud Infrastructure, Cloud, Management, and Cloud Storage
# - Location: USA, India, EU

# %% [markdown]
# ---

# %%
import os
from newspaper import Article
from bs4 import BeautifulSoup
from six.moves.urllib.parse import urlparse
import urllib
import sys
import time
import nltk
import glob
import pandas as pd
import requests
import spacy
import random
# from googlesearch import search
from langdetect import detect
import re
import pickle
import math
import numpy as np
import collections
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import re
from tabulate import tabulate
from IPython.display import display, HTML

# %% [markdown]
# ### Step 2: read data

# %%
path = r'C:\Users\aaberkan\OneDrive - UGent\Scripts\GDPR-Compliance in Web Applications\data\Crunchbase\Productivity tools'
filenames = glob.glob(path + "/*.csv")

# %%
# len = 30
len(filenames)
# Out:
# 1

# %%
dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# %%
crunch_data = pd.concat(dfs, ignore_index=True)

# %%
crunch_data
# Out:
#        Organization Name                              Organization Name URL  \
# 0          Burgon & Ball  https://www.crunchbase.com/organization/burgon...
# 1            Witte Tools  https://www.crunchbase.com/organization/witte-...
# 2                WÜSTHOF  https://www.crunchbase.com/organization/wüstho...
# 3     C.S. Osborne & Co.  https://www.crunchbase.com/organization/c-s-os...
# 4    Browns Agricultural  https://www.crunchbase.com/organization/browns...
# ..                   ...                                                ...
# 995              JotForm    https://www.crunchbase.com/organization/jotform
# 996             Viewpath   https://www.crunchbase.com/organization/viewpath
# 997          Wide Narrow  https://www.crunchbase.com/organization/wide-n...
# 998       Express Mobile  https://www.crunchbase.com/organization/expres...
# 999    Gigantic Software  https://www.crunchbase.com/organization/gigant...
#
#     Founded Date Founded Date Precision Number of Employees  \
# 0     1730-01-01                   year               11-50
# 1     1785-01-01                   year              10001+
# 2     1814-01-01                   year             101-250
# 3     1826-01-01                   year             101-250
# 4     1830-01-01                   year                 NaN
# ..           ...                    ...                 ...
# 995   2006-01-01                   year             251-500
# 996   2006-01-01                   year                1-10
# 997   2006-01-01                    day               11-50
# 998   2006-01-01                   year                1-10
# 999   2006-01-01                   year                1-10
#
#                                       Full Description  \
# 0    Founded in Sheffield in 1730, Burgon & Ball is...
# 1                                                  NaN
# 2    WÜSTHOF products include chef's knives, asian-...
# 3    C.S. Osborne & Co. manufactures and distribute...
# 4                                                  NaN
# ..                                                 ...
# 995  JotForm is an online form building tool that h...
# 996  Viewpath is a computer software company that s...
# 997  The Wide Narrow software and information ecosy...
# 998  Express Mobile is a technology company that sp...
# 999                                                NaN
#
#                                Website  \
# 0       https://www.burgonandball.com/
# 1           https://www.wittetools.com
# 2      https://www.wuesthof.com/en-in/
# 3                https://csosborne.com
# 4    https://brownsagricultural.co.uk/
# ..                                 ...
# 995            https://www.jotform.com
# 996            http://www.viewpath.com
# 997        https://www.widenarrow.com/
# 998           http://www.xpressmo.com/
# 999  https://www.giganticsoftware.com/
#
#                                             Industries  \
# 0    Consumer Goods, Home and Garden, Manufacturing...
# 1                    Manufacturing, Productivity Tools
# 2    Consumer Goods, Manufacturing, Product Design,...
# 3    Industrial, Manufacturing, Productivity Tools,...
# 4    Agriculture, AgTech, Farming, Machinery Manufa...
# ..                                                 ...
# 995  Information Technology, Productivity Tools, So...
# 996  Collaboration, Enterprise Software, Product Ma...
# 997  Analytics, Artificial Intelligence, Business I...
# 998  Enterprise Software, Information Technology, M...
# 999      Audio, Hardware, Productivity Tools, Software
#
#                               Headquarters Location  \
# 0              Sheffield, Sheffield, United Kingdom
# 1               Hagen, Nordrhein-Westfalen, Germany
# 2            Solingen, Nordrhein-Westfalen, Germany
# 3               Harrison, New Jersey, United States
# 4    Leighton Buzzard, Bedfordshire, United Kingdom
# ..                                              ...
# 995        San Francisco, California, United States
# 996              Seattle, Washington, United States
# 997               Stockholm, Stockholms Lan, Sweden
# 998             Larkspur, California, United States
# 999            Santa Ana, California, United States
#
#                                            Description  ...  \
# 0    Burgon & Ball manufacturer of Garden Tools to ...  ...
# 1    Witte Tools is a tool manufacturer for automob...  ...
# 2    WÜSTHOF manufactures cutlery with precision an...  ...
# 3             CS Osborne & Co. is a tool manufacturer.  ...
# 4    Browns Agricultural is a machinery manufacturi...  ...
# ..                                                 ...  ...
# 995  JotForm is an online form-building tool that h...  ...
# 996  Viewpath is a computer software company that s...  ...
# 997  The Wide Narrow software and information ecosy...  ...
# 998  Express Mobile is a technology company that sp...  ...
# 999  Gigantic Software designs and develops high-qu...  ...
#
#     SEMrush - Monthly Visits Growth SEMrush - Visit Duration Growth  \
# 0                           167.15%                         -25.25%
# 1                            23.02%                         565.96%
# 2                               NaN                             NaN
# 3                           198.25%                         992.42%
# 4                               NaN                             NaN
# ..                              ...                             ...
# 995                          -2.05%                           4.38%
# 996                             NaN                             NaN
# 997                         -84.94%                            -75%
# 998                             NaN                             NaN
# 999                             NaN                             NaN
#
#     SEMrush - Visit Duration SEMrush - Page Views / Visit  \
# 0                         74                         2.81
# 1                        626                         6.00
# 2                          0                         1.00
# 3                        378                         1.42
# 4                        NaN                          NaN
# ..                       ...                          ...
# 995                      572                         1.97
# 996                        0                         1.00
# 997                       83                         1.60
# 998                      NaN                          NaN
# 999                      NaN                          NaN
#
#     SEMrush - Page Views / Visit Growth SEMrush - Bounce Rate  \
# 0                                19.74%                 48.5%
# 1                               132.59%                    0%
# 2                                   NaN                  100%
# 3                                41.74%                58.24%
# 4                                   NaN                   NaN
# ..                                  ...                   ...
# 995                              -4.04%                59.53%
# 996                                 NaN                  100%
# 997                              32.42%                79.94%
# 998                                 NaN                   NaN
# 999                                 NaN                   NaN
#
#      SEMrush - Bounce Rate Growth SEMrush - Global Traffic Rank  \
# 0                          -4.68%                     1,045,844
# 1                         -44.08%                     4,823,027
# 2                             NaN                     2,569,355
# 3                         -41.76%                     3,856,985
# 4                             NaN                           NaN
# ..                            ...                           ...
# 995                         4.48%                         3,441
# 996                           NaN                     9,546,283
# 997                         1.15%                     7,805,544
# 998                           NaN                           NaN
# 999                           NaN                           NaN
#
#     SEMrush - Monthly Rank Change (#) SEMrush - Monthly Rank Growth
# 0                            -765,972                       -42.28%
# 1                            -216,235                        -4.29%
# 2                                 NaN                           NaN
# 3                          -2,662,737                       -40.84%
# 4                                 NaN                           NaN
# ..                                ...                           ...
# 995                               -81                         -2.3%
# 996                               NaN                           NaN
# 997                         4,159,456                       114.08%
# 998                               NaN                           NaN
# 999                               NaN                           NaN
#
# [1000 rows x 23 columns]

# %%
# remove duplicates
crunch_data.drop_duplicates(inplace=True)

# %%
crunch_data
# Out:
#        Organization Name                              Organization Name URL  \
# 0          Burgon & Ball  https://www.crunchbase.com/organization/burgon...
# 1            Witte Tools  https://www.crunchbase.com/organization/witte-...
# 2                WÜSTHOF  https://www.crunchbase.com/organization/wüstho...
# 3     C.S. Osborne & Co.  https://www.crunchbase.com/organization/c-s-os...
# 4    Browns Agricultural  https://www.crunchbase.com/organization/browns...
# ..                   ...                                                ...
# 995              JotForm    https://www.crunchbase.com/organization/jotform
# 996             Viewpath   https://www.crunchbase.com/organization/viewpath
# 997          Wide Narrow  https://www.crunchbase.com/organization/wide-n...
# 998       Express Mobile  https://www.crunchbase.com/organization/expres...
# 999    Gigantic Software  https://www.crunchbase.com/organization/gigant...
#
#     Founded Date Founded Date Precision Number of Employees  \
# 0     1730-01-01                   year               11-50
# 1     1785-01-01                   year              10001+
# 2     1814-01-01                   year             101-250
# 3     1826-01-01                   year             101-250
# 4     1830-01-01                   year                 NaN
# ..           ...                    ...                 ...
# 995   2006-01-01                   year             251-500
# 996   2006-01-01                   year                1-10
# 997   2006-01-01                    day               11-50
# 998   2006-01-01                   year                1-10
# 999   2006-01-01                   year                1-10
#
#                                       Full Description  \
# 0    Founded in Sheffield in 1730, Burgon & Ball is...
# 1                                                  NaN
# 2    WÜSTHOF products include chef's knives, asian-...
# 3    C.S. Osborne & Co. manufactures and distribute...
# 4                                                  NaN
# ..                                                 ...
# 995  JotForm is an online form building tool that h...
# 996  Viewpath is a computer software company that s...
# 997  The Wide Narrow software and information ecosy...
# 998  Express Mobile is a technology company that sp...
# 999                                                NaN
#
#                                Website  \
# 0       https://www.burgonandball.com/
# 1           https://www.wittetools.com
# 2      https://www.wuesthof.com/en-in/
# 3                https://csosborne.com
# 4    https://brownsagricultural.co.uk/
# ..                                 ...
# 995            https://www.jotform.com
# 996            http://www.viewpath.com
# 997        https://www.widenarrow.com/
# 998           http://www.xpressmo.com/
# 999  https://www.giganticsoftware.com/
#
#                                             Industries  \
# 0    Consumer Goods, Home and Garden, Manufacturing...
# 1                    Manufacturing, Productivity Tools
# 2    Consumer Goods, Manufacturing, Product Design,...
# 3    Industrial, Manufacturing, Productivity Tools,...
# 4    Agriculture, AgTech, Farming, Machinery Manufa...
# ..                                                 ...
# 995  Information Technology, Productivity Tools, So...
# 996  Collaboration, Enterprise Software, Product Ma...
# 997  Analytics, Artificial Intelligence, Business I...
# 998  Enterprise Software, Information Technology, M...
# 999      Audio, Hardware, Productivity Tools, Software
#
#                               Headquarters Location  \
# 0              Sheffield, Sheffield, United Kingdom
# 1               Hagen, Nordrhein-Westfalen, Germany
# 2            Solingen, Nordrhein-Westfalen, Germany
# 3               Harrison, New Jersey, United States
# 4    Leighton Buzzard, Bedfordshire, United Kingdom
# ..                                              ...
# 995        San Francisco, California, United States
# 996              Seattle, Washington, United States
# 997               Stockholm, Stockholms Lan, Sweden
# 998             Larkspur, California, United States
# 999            Santa Ana, California, United States
#
#                                            Description  ...  \
# 0    Burgon & Ball manufacturer of Garden Tools to ...  ...
# 1    Witte Tools is a tool manufacturer for automob...  ...
# 2    WÜSTHOF manufactures cutlery with precision an...  ...
# 3             CS Osborne & Co. is a tool manufacturer.  ...
# 4    Browns Agricultural is a machinery manufacturi...  ...
# ..                                                 ...  ...
# 995  JotForm is an online form-building tool that h...  ...
# 996  Viewpath is a computer software company that s...  ...
# 997  The Wide Narrow software and information ecosy...  ...
# 998  Express Mobile is a technology company that sp...  ...
# 999  Gigantic Software designs and develops high-qu...  ...
#
#     SEMrush - Monthly Visits Growth SEMrush - Visit Duration Growth  \
# 0                           167.15%                         -25.25%
# 1                            23.02%                         565.96%
# 2                               NaN                             NaN
# 3                           198.25%                         992.42%
# 4                               NaN                             NaN
# ..                              ...                             ...
# 995                          -2.05%                           4.38%
# 996                             NaN                             NaN
# 997                         -84.94%                            -75%
# 998                             NaN                             NaN
# 999                             NaN                             NaN
#
#     SEMrush - Visit Duration SEMrush - Page Views / Visit  \
# 0                         74                         2.81
# 1                        626                         6.00
# 2                          0                         1.00
# 3                        378                         1.42
# 4                        NaN                          NaN
# ..                       ...                          ...
# 995                      572                         1.97
# 996                        0                         1.00
# 997                       83                         1.60
# 998                      NaN                          NaN
# 999                      NaN                          NaN
#
#     SEMrush - Page Views / Visit Growth SEMrush - Bounce Rate  \
# 0                                19.74%                 48.5%
# 1                               132.59%                    0%
# 2                                   NaN                  100%
# 3                                41.74%                58.24%
# 4                                   NaN                   NaN
# ..                                  ...                   ...
# 995                              -4.04%                59.53%
# 996                                 NaN                  100%
# 997                              32.42%                79.94%
# 998                                 NaN                   NaN
# 999                                 NaN                   NaN
#
#      SEMrush - Bounce Rate Growth SEMrush - Global Traffic Rank  \
# 0                          -4.68%                     1,045,844
# 1                         -44.08%                     4,823,027
# 2                             NaN                     2,569,355
# 3                         -41.76%                     3,856,985
# 4                             NaN                           NaN
# ..                            ...                           ...
# 995                         4.48%                         3,441
# 996                           NaN                     9,546,283
# 997                         1.15%                     7,805,544
# 998                           NaN                           NaN
# 999                           NaN                           NaN
#
#     SEMrush - Monthly Rank Change (#) SEMrush - Monthly Rank Growth
# 0                            -765,972                       -42.28%
# 1                            -216,235                        -4.29%
# 2                                 NaN                           NaN
# 3                          -2,662,737                       -40.84%
# 4                                 NaN                           NaN
# ..                                ...                           ...
# 995                               -81                         -2.3%
# 996                               NaN                           NaN
# 997                         4,159,456                       114.08%
# 998                               NaN                           NaN
# 999                               NaN                           NaN
#
# [1000 rows x 23 columns]

# %%
crunch_data.to_csv("crunch_collaboration.csv", sep='\t', header=True, index=False)

# %% [markdown]
# #### Clean websites list

# %%
websites_list = crunch_data["Website"].tolist()

# %%
len(websites_list)
# Out:
# 1000

# %%
# remove / from the end of the string that contains the website
# websites_list = [website.rstrip(website[-1]) if (website[-1] == "/") else website for website in websites_list]
websites_list = [website.rstrip(website[-1]) if (isinstance(website, str) and website[-1] == "/") else website for website in websites_list]
# een keer extra voor het geval er een url was met // op het eind
websites_list = [website.rstrip(website[-1]) if (isinstance(website, str) and website[-1] == "/") else website for website in websites_list]

# %%
len(websites_list)
# Out:
# 1000

# %% [markdown]
# ---

# %% [markdown]
# ### Step 3: scrape privacy policies

# %%
def get_privacy_policy_url(query):
    keyword_in_title = 0
    attempts = 0
    url = ""
    print("Query: " + query)
    
    try:
        query_results_list = return_google_results(query, 3, 5)
        print("Considering " + str(len(query_results_list)) + " URL(s) ...")
        for i, url in enumerate(query_results_list):
            term_in_url = 0
            attempts = attempts + 1
            print("Assessing privacy policy URL: " + url)
            
            if (re.findall('privacy', url) or re.findall('policy', url) or re.findall('gdpr', url) 
                or re.findall('terms', url) or re.findall('legal', url)): 
                print("Found relevant terms in URL! Succesful break!")
                break

#                     pass
            if keyword_in_title == 1 or attempts == 3 or i==(len(query_results_list)-1): 
                keyword_in_title = 0
                attempts = 0
                print("No results. Breaking ..")
                url = ""
#                 print(sentences)
                break   
    except Exception as e:
            print(str(e))
            pass
    return url

# %%
def return_google_results(keywords, num_results, attempts):
    user_agent_list = [
      'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15',
      'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0',
      'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
      'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0',
      'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
    ]

    html_keywords = urllib.parse.quote_plus(keywords)
    sleep_init = 10
    
    url = "https://www.google.com/search?q=" + html_keywords + "&num=" + str(num_results)
    print("** Search query in URL: " + url)

    headers = {'User-Agent': random.choice(user_agent_list)}
    
    html = requests.get(url, headers=headers)

    if html.status_code == 429:
        if(attempts == 0):
            sys.exit("Too many request 429, attempted "+ str(5)+ " times, break ...")
        else:
            if 'Retry_After' in html.headers:
                print("Helaas, geen retry-after info")
            else:
                time.sleep(sleep_init)
                print("Too many requests (attempt "+ str(5 - attempts)+ "), we will attempt again in " + str(sleep_init) + " seconds")
                return_google_results(keywords, num_results, (attempts - 1))
    else: 
        pass
        
    soup = BeautifulSoup(html.text, 'html.parser')

    allData = soup.find_all("div",{"class":"g"})

    link_list = []
    print("len alldata: " + str(len(allData)))
    
    for i in range(0,len(allData)):
        link = allData[i].find('a').get('href')
        
        if(link is not None):
            if(link.find('https') != -1 and link.find('http') == 0 and link.find('aclk') == -1):
                print(link)
                link_list.append(link)
    print(link_list)
    return link_list

# %% [markdown]
# #### Collect privacy policy URLs

# %%
privacy_policies_url_list = []

# %%
# loop through each company URL and attempt to find the URL of the privacy policy
count_urls = 0
for i, url_company in enumerate(websites_list):    
    print(i)

#     print(len(privacy_policies_url_list))
    if(isinstance("url_company", str) is False or (url_company == url_company) is False):
        privacy_policies_url_list.append("")
    else:
        query = "site:\"" + url_company + " \"privacy policy"
        privacy_policies_url_list.append(get_privacy_policy_url(query))
        if(len(privacy_policies_url_list[-1]) > 0):
            count_urls = count_urls + 1
    print("URL count: " + str(count_urls))
    print()
    time.sleep(50)
# Out:
# 0
# Query: site:"https://www.burgonandball.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.burgonandball.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.burgonandball.com/pages/privacy-policy
# https://www.burgonandball.com/pages/gdpr-compliance
# ['https://www.burgonandball.com/pages/privacy-policy', 'https://www.burgonandball.com/pages/gdpr-compliance']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.burgonandball.com/pages/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 1
#
# 1
# Query: site:"https://www.wittetools.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.wittetools.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.wittetools.com/en/general-terms-conditions-of-delivery-and-payment/privacy-policy/
# https://www.wittetools.com/en/general-terms-conditions-of-delivery-and-payment/legal-notice/
# ['https://www.wittetools.com/en/general-terms-conditions-of-delivery-and-payment/privacy-policy/', 'https://www.wittetools.com/en/general-terms-conditions-of-delivery-and-payment/legal-notice/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.wittetools.com/en/general-terms-conditions-of-delivery-and-payment/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 2
#
# 2
# Query: site:"https://www.wuesthof.com/en-in "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.wuesthof.com%2Fen-in+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 2
#
# 3
# Query: site:"https://csosborne.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fcsosborne.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 2
#
# 4
# Query: site:"https://brownsagricultural.co.uk "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fbrownsagricultural.co.uk+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 2
#
# 5
# Query: site:"https://www.ferry-capitain.eu "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.ferry-capitain.eu+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 2
#
# 6
# Query: site:"https://www.bentallrowlands.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.bentallrowlands.com+%22privacy+policy&num=3
# len alldata: 3
# https://www.bentallrowlands.com/privacy-policy
# https://www.bentallrowlands.com/privacy-policy-bg
# https://www.bentallrowlands.com/sitemap
# ['https://www.bentallrowlands.com/privacy-policy', 'https://www.bentallrowlands.com/privacy-policy-bg', 'https://www.bentallrowlands.com/sitemap']
# Considering 3 URL(s) ...
# Assessing privacy policy URL: https://www.bentallrowlands.com/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 3
#
# 7
# Query: site:"https://wackerneuson.us "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwackerneuson.us+%22privacy+policy&num=3
# len alldata: 3
# []
# Considering 0 URL(s) ...
# URL count: 3
#
# 8
# Query: site:"https://www.nalapipe.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.nalapipe.com+%22privacy+policy&num=3
# len alldata: 1
# []
# Considering 0 URL(s) ...
# URL count: 3
#
# 9
# Query: site:"https://www.singerfrance.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.singerfrance.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 3
#
# 10
# Query: site:"https://www.witzenmann-usa.com/en "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.witzenmann-usa.com%2Fen+%22privacy+policy&num=3
# len alldata: 2
# https://www.witzenmann-usa.com/en/careers/
# https://www.witzenmann-usa.com/en/careers/why-witzenmann/social/
# ['https://www.witzenmann-usa.com/en/careers/', 'https://www.witzenmann-usa.com/en/careers/why-witzenmann/social/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.witzenmann-usa.com/en/careers/
# Assessing privacy policy URL: https://www.witzenmann-usa.com/en/careers/why-witzenmann/social/
# No results. Breaking ..
# URL count: 3
#
# 11
# Query: site:"https://www.kingdicktools.co.uk "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.kingdicktools.co.uk+%22privacy+policy&num=3
# len alldata: 3
# https://www.kingdicktools.co.uk/info/privacy-policy.asp
# https://www.kingdicktools.co.uk/info/acceptable-use-policy.asp
# https://www.kingdicktools.co.uk/info/terms-of-use.asp
# ['https://www.kingdicktools.co.uk/info/privacy-policy.asp', 'https://www.kingdicktools.co.uk/info/acceptable-use-policy.asp', 'https://www.kingdicktools.co.uk/info/terms-of-use.asp']
# Considering 3 URL(s) ...
# Assessing privacy policy URL: https://www.kingdicktools.co.uk/info/privacy-policy.asp
# Found relevant terms in URL! Succesful break!
# URL count: 4
#
# 12
# Query: site:"https://www.huron.fr "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.huron.fr+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 4
#
# 13
# Query: site:"https://hydrants.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fhydrants.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 4
#
# 14
# Query: site:"https://www.chhanson.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.chhanson.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 4
#
# 15
# Query: site:"http://www.zurich.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.zurich.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.zurich.com/en/services/privacy
# https://www.zurich.com/en/sustainability/governance-and-policies/data-commitment-and-privacy-protection
# ['https://www.zurich.com/en/services/privacy', 'https://www.zurich.com/en/sustainability/governance-and-policies/data-commitment-and-privacy-protection']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.zurich.com/en/services/privacy
# Found relevant terms in URL! Succesful break!
# URL count: 5
#
# 16
# Query: site:"https://www.bernzomatic.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.bernzomatic.com+%22privacy+policy&num=3
# len alldata: 3
# https://www.bernzomatic.com/Utility/Privacy-Policy
# https://www.bernzomatic.com/Utility/Terms-of-Use
# https://www.bernzomatic.com/app7687519
# ['https://www.bernzomatic.com/Utility/Privacy-Policy', 'https://www.bernzomatic.com/Utility/Terms-of-Use', 'https://www.bernzomatic.com/app7687519']
# Considering 3 URL(s) ...
# Assessing privacy policy URL: https://www.bernzomatic.com/Utility/Privacy-Policy
# Assessing privacy policy URL: https://www.bernzomatic.com/Utility/Terms-of-Use
# Assessing privacy policy URL: https://www.bernzomatic.com/app7687519
# No results. Breaking ..
# URL count: 5
#
# 17
# Query: site:"https://www.trenois.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.trenois.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 5
#
# 18
# Query: site:"https://www.sartorius-werkzeuge.de "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.sartorius-werkzeuge.de+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 5
#
# 19
# Query: site:"https://www.forgesdeniaux.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.forgesdeniaux.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 5
#
# 20
# Query: site:"http://www.irwin.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.irwin.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.irwin.com/about-us/privacy-policy
# https://www.irwin.com/about-us/terms-use
# ['https://www.irwin.com/about-us/privacy-policy', 'https://www.irwin.com/about-us/terms-use']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.irwin.com/about-us/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 6
# 21
# Query: site:"https://comipolaris.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fcomipolaris.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 6
#
# 22
# Query: site:"https://www.comercole.it "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.comercole.it+%22privacy+policy&num=3
# len alldata: 2
# https://www.comercole.it/privacy-policy-ch.html
# https://www.comercole.it/content/files/GDPR%20POLITICA-PRIVACY%20ingl.pdf
# ['https://www.comercole.it/privacy-policy-ch.html', 'https://www.comercole.it/content/files/GDPR%20POLITICA-PRIVACY%20ingl.pdf']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.comercole.it/privacy-policy-ch.html
# Found relevant terms in URL! Succesful break!
# URL count: 7
#
# 23
# Query: site:"https://www.bahco.com/int_en "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.bahco.com%2Fint_en+%22privacy+policy&num=3
# len alldata: 3
# https://www.bahco.com/int_en/privacy-policy
# https://www.bahco.com/int_en/privacy-policy-cookie-restriction-mode
# https://www.bahco.com/int_en/terms-of-use
# ['https://www.bahco.com/int_en/privacy-policy', 'https://www.bahco.com/int_en/privacy-policy-cookie-restriction-mode', 'https://www.bahco.com/int_en/terms-of-use']
# Considering 3 URL(s) ...
# Assessing privacy policy URL: https://www.bahco.com/int_en/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 8
#
# 24
# Query: site:"https://calsaw.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fcalsaw.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 8
#
# 25
# Query: site:"https://lecot.be "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Flecot.be+%22privacy+policy&num=3
# len alldata: 2
# https://jobs.lecot.be/nl/privacy-policy/
# https://lecot.be/nl-be/wettelijke-bepalingen/privacyverklaring
# ['https://jobs.lecot.be/nl/privacy-policy/', 'https://lecot.be/nl-be/wettelijke-bepalingen/privacyverklaring']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://jobs.lecot.be/nl/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 9
#
# 26
# Query: site:"https://www.onejoon.de/en "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.onejoon.de%2Fen+%22privacy+policy&num=3
# len alldata: 2
# https://www.onejoon.de/en/privacy/
# https://www.onejoon.de/en/privacy/privacy-policy-website/
# ['https://www.onejoon.de/en/privacy/', 'https://www.onejoon.de/en/privacy/privacy-policy-website/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.onejoon.de/en/privacy/
# Found relevant terms in URL! Succesful break!
# URL count: 10
#
# 27
# Query: site:"https://www.maxitools.nl/home.php "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.maxitools.nl%2Fhome.php+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 10
#
# 28
# Query: site:"https://www.clecotools.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.clecotools.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.clecotools.com/privacy-policy
# https://www.clecotools.com/node/1762
# ['https://www.clecotools.com/privacy-policy', 'https://www.clecotools.com/node/1762']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.clecotools.com/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 11
#
# 29
# Query: site:"https://jbtc.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fjbtc.com+%22privacy+policy&num=3
# len alldata: 3
# https://www.jbtc.com/privacy-and-cookie-policy/
# https://www.jbtc.com/privacy-policy/
# https://www.jbtc.com/employment-privacy-notice/
# ['https://www.jbtc.com/privacy-and-cookie-policy/', 'https://www.jbtc.com/privacy-policy/', 'https://www.jbtc.com/employment-privacy-notice/']
# Considering 3 URL(s) ...
# Assessing privacy policy URL: https://www.jbtc.com/privacy-and-cookie-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 12
#
# 30
# Query: site:"http://www.ihttimme.de "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.ihttimme.de+%22privacy+policy&num=3
# len alldata: 1
# https://www.ihttimme.de/inhalt/Impressum/de/
# ['https://www.ihttimme.de/inhalt/Impressum/de/']
# Considering 1 URL(s) ...
# Assessing privacy policy URL: https://www.ihttimme.de/inhalt/Impressum/de/
# No results. Breaking ..
# URL count: 12
#
# 31
# Query: site:"https://americanlawnmower.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Famericanlawnmower.com+%22privacy+policy&num=3
# len alldata: 3
# https://americanlawnmower.com/policies/privacy-policy
# https://americanlawnmower.com/pages/accessibility-policy
# https://americanlawnmower.com/pages/product-notifications
# ['https://americanlawnmower.com/policies/privacy-policy', 'https://americanlawnmower.com/pages/accessibility-policy', 'https://americanlawnmower.com/pages/product-notifications']
# Considering 3 URL(s) ...
# Assessing privacy policy URL: https://americanlawnmower.com/policies/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 13
#
# 32
# Query: site:"https://www.wieseindustries.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.wieseindustries.com+%22privacy+policy&num=3
# len alldata: 1
# https://www.wieseindustries.com/
# ['https://www.wieseindustries.com/']
# Considering 1 URL(s) ...
# Assessing privacy policy URL: https://www.wieseindustries.com/
# No results. Breaking ..
# URL count: 13
#
# 33
# Query: site:"https://www.apexical.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.apexical.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 13
#
# 34
# Query: site:"https://www.stocko-ykk.de "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.stocko-ykk.de+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 13
#
# 35
# Query: site:"http://www.stiletto.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.stiletto.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.stiletto.com/privacy-policy
# https://www.stiletto.com/legal
# ['https://www.stiletto.com/privacy-policy', 'https://www.stiletto.com/legal']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.stiletto.com/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 14
#
# 36
# Query: site:"https://lagrinding.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Flagrinding.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 14
#
# 37
# Query: site:"https://www.macto.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.macto.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 14
#
# 38
# URL count: 14
#
# 39
# Query: site:"https://reiden.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Freiden.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 14
#
# 40
# Query: site:"https://www.mascherpa.it "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.mascherpa.it+%22privacy+policy&num=3
# len alldata: 1
# https://www.mascherpa.it/wp-content/uploads/2019/12/privacy.pdf
# ['https://www.mascherpa.it/wp-content/uploads/2019/12/privacy.pdf']
# Considering 1 URL(s) ...
# Assessing privacy policy URL: https://www.mascherpa.it/wp-content/uploads/2019/12/privacy.pdf
# Found relevant terms in URL! Succesful break!
# URL count: 15
#
# 41
# Query: site:"https://www.gemathis.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.gemathis.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.gemathis.com/sitemap/
# https://www.gemathis.com/resources/
# ['https://www.gemathis.com/sitemap/', 'https://www.gemathis.com/resources/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.gemathis.com/sitemap/
# Assessing privacy policy URL: https://www.gemathis.com/resources/
# No results. Breaking ..
# URL count: 15
# 42
# Query: site:"http://www.homberger.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.homberger.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.homberger.com/en/qualita/
# https://www.homberger.com/en/news/e-on-line-il-nuovo-sito-web/
# ['https://www.homberger.com/en/qualita/', 'https://www.homberger.com/en/news/e-on-line-il-nuovo-sito-web/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.homberger.com/en/qualita/
# Assessing privacy policy URL: https://www.homberger.com/en/news/e-on-line-il-nuovo-sito-web/
# No results. Breaking ..
# URL count: 15
#
# 43
# Query: site:"https://www.sam-outillage.fr "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.sam-outillage.fr+%22privacy+policy&num=3
# len alldata: 2
# https://www.sam-outillage.fr/mentions-legales.html
# https://www.sam-outillage.fr/sam-outillage-kapsam-privacy.htm
# ['https://www.sam-outillage.fr/mentions-legales.html', 'https://www.sam-outillage.fr/sam-outillage-kapsam-privacy.htm']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.sam-outillage.fr/mentions-legales.html
# Found relevant terms in URL! Succesful break!
# URL count: 16
#
# 44
# Query: site:"https://www.markeymachinery.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.markeymachinery.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 16
#
# 45
# Query: site:"https://sbsg.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fsbsg.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.sbsg.com/contact/
# ['https://www.sbsg.com/contact/']
# Considering 1 URL(s) ...
# Assessing privacy policy URL: https://www.sbsg.com/contact/
# No results. Breaking ..
# URL count: 16
#
# 46
# Query: site:"https://www.mfgsup.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.mfgsup.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 16
#
# 47
# Query: site:"https://oneilprint.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Foneilprint.com+%22privacy+policy&num=3
# len alldata: 2
# https://oneilprint.com/privacy-policy/
# https://oneilprint.com/sitemap/
# ['https://oneilprint.com/privacy-policy/', 'https://oneilprint.com/sitemap/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://oneilprint.com/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 17
#
# 48
# Query: site:"https://www.carbox.de/de "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.carbox.de%2Fde+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 17
#
# 49
# Query: site:"https://www.vitz.de "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.vitz.de+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 17
#
# 50
# Query: site:"https://www.tajimatool.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.tajimatool.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.tajimatool.com/contact/privacy/
# https://www.tajimatool.com/contact/
# ['https://www.tajimatool.com/contact/privacy/', 'https://www.tajimatool.com/contact/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.tajimatool.com/contact/privacy/
# Found relevant terms in URL! Succesful break!
# URL count: 18
#
# 51
# Query: site:"http://www.monarchmt.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.monarchmt.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 18
#
# 52
# Query: site:"https://www.knoblauch.eu "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.knoblauch.eu+%22privacy+policy&num=3
# len alldata: 2
# https://www.knoblauch.eu/en/datenschutzerklaerung/
# https://www.knoblauch.eu/en/download/
# ['https://www.knoblauch.eu/en/datenschutzerklaerung/', 'https://www.knoblauch.eu/en/download/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.knoblauch.eu/en/datenschutzerklaerung/
# Assessing privacy policy URL: https://www.knoblauch.eu/en/download/
# No results. Breaking ..
# URL count: 18
#
# 53
# Query: site:"http://www.unitex-lhs.de "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.unitex-lhs.de+%22privacy+policy&num=3
# len alldata: 3
# []
# Considering 0 URL(s) ...
# URL count: 18
#
# 54
# Query: site:"https://www.abwe.se "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.abwe.se+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 18
#
# 55
# Query: site:"https://www.everhard.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.everhard.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.everhard.com/privacy-policy/
# https://www.everhard.com/terms-of-use/
# ['https://www.everhard.com/privacy-policy/', 'https://www.everhard.com/terms-of-use/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.everhard.com/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 19
#
# 56
# Query: site:"http://www.malveseequipment.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.malveseequipment.com+%22privacy+policy&num=3
# len alldata: 1
# []
# Considering 0 URL(s) ...
# URL count: 19
#
# 57
# Query: site:"https://www.illstonandrobson.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.illstonandrobson.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 19
#
# 58
# Query: site:"https://www.gesswein.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.gesswein.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.gesswein.com/privacy-policy/
# https://www.gesswein.com/return-policy
# ['https://www.gesswein.com/privacy-policy/', 'https://www.gesswein.com/return-policy']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.gesswein.com/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 20
#
# 59
# Query: site:"http://www.branick.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.branick.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.branick.com/terms-conditions/
# https://www.branick.com/wp-content/uploads/2019/03/5035-Tire-Spreader.pdf
# ['https://www.branick.com/terms-conditions/', 'https://www.branick.com/wp-content/uploads/2019/03/5035-Tire-Spreader.pdf']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.branick.com/terms-conditions/
# Found relevant terms in URL! Succesful break!
# URL count: 21
#
# 60
# Query: site:"http://www.mooneygeneral.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.mooneygeneral.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 21
#
# 61
# Query: site:"https://www.americanlube.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.americanlube.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 21
#
# 62
# Query: site:"https://www.berg-spanntechnik.de "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.berg-spanntechnik.de+%22privacy+policy&num=3
# len alldata: 1
# https://www.berg-spanntechnik.de/en/privacy/
# ['https://www.berg-spanntechnik.de/en/privacy/']
# Considering 1 URL(s) ...
# Assessing privacy policy URL: https://www.berg-spanntechnik.de/en/privacy/
# Found relevant terms in URL! Succesful break!
# URL count: 22
#
# 63
# Query: site:"http://www.mercurymarking.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.mercurymarking.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 22
#
# 64
# Query: site:"https://www.drapertools.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.drapertools.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.drapertools.com/privacy-policy
# https://www.drapertools.com/cookies-policy
# ['https://www.drapertools.com/privacy-policy', 'https://www.drapertools.com/cookies-policy']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.drapertools.com/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 23
#
# 65
# Query: site:"http://www.gothamstaple.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.gothamstaple.com+%22privacy+policy&num=3
# len alldata: 2
# []
# Considering 0 URL(s) ...
# URL count: 23
#
# 66
# Query: site:"http://www.gratomat.de "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.gratomat.de+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 23
#
# 67
# Query: site:"https://remingtonpowertools.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fremingtonpowertools.com+%22privacy+policy&num=3
# len alldata: 2
# https://remingtonpowertools.com/privacy-policy/
# https://remingtonpowertools.com/terms-of-use/
# ['https://remingtonpowertools.com/privacy-policy/', 'https://remingtonpowertools.com/terms-of-use/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://remingtonpowertools.com/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 24
#
# 68
# Query: site:"http://www.osswald-buero.de "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.osswald-buero.de+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 24
#
# 69
# Query: site:"https://abcarter.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fabcarter.com+%22privacy+policy&num=3
# len alldata: 2
# https://tr.abcarter.com/privacy-policy/
# https://www.abcarter.com/terms-and-conditions/
# ['https://tr.abcarter.com/privacy-policy/', 'https://www.abcarter.com/terms-and-conditions/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://tr.abcarter.com/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 25
#
# 70
# Query: site:"https://www.williamsform.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.williamsform.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 25
#
# 71
# Query: site:"http://www.ramseychain.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.ramseychain.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 25
#
# 72
# Query: site:"https://www.knuth.de "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.knuth.de+%22privacy+policy&num=3
# len alldata: 2
# https://www.knuth.de/de_en/our-company/history
# https://www.knuth.de/de_en/our-company/contact-service
# ['https://www.knuth.de/de_en/our-company/history', 'https://www.knuth.de/de_en/our-company/contact-service']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.knuth.de/de_en/our-company/history
# Assessing privacy policy URL: https://www.knuth.de/de_en/our-company/contact-service
# No results. Breaking ..
# URL count: 25
#
# 73
# Query: site:"https://www.beta-tools.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.beta-tools.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.beta-tools.com/en/privacy-policy
# https://www.beta-tools.com/it/privacy-policy/
# ['https://www.beta-tools.com/en/privacy-policy', 'https://www.beta-tools.com/it/privacy-policy/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.beta-tools.com/en/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 26
#
# 74
# Query: site:"http://www.swansontoolco.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.swansontoolco.com+%22privacy+policy&num=3
# len alldata: 2
# []
# Considering 0 URL(s) ...
# URL count: 26
#
# 75
# Query: site:"https://www.diehlsteel.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.diehlsteel.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 26
#
# 76
# Query: site:"https://www.huot.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.huot.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.huot.com/terms-and-conditions-privacy-policy/
# https://www.huot.com/
# ['https://www.huot.com/terms-and-conditions-privacy-policy/', 'https://www.huot.com/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.huot.com/terms-and-conditions-privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 27
#
# 77
# Query: site:"https://www.universaldevlieg.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.universaldevlieg.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.universaldevlieg.com/privacy-policy
# https://www.universaldevlieg.com/technical-data
# ['https://www.universaldevlieg.com/privacy-policy', 'https://www.universaldevlieg.com/technical-data']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.universaldevlieg.com/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 28
#
# 78
# Query: site:"https://www.fssystem.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.fssystem.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.fssystem.com/Terms-of-Use
# https://www.fssystem.com/Footer-Links
# ['https://www.fssystem.com/Terms-of-Use', 'https://www.fssystem.com/Footer-Links']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.fssystem.com/Terms-of-Use
# Assessing privacy policy URL: https://www.fssystem.com/Footer-Links
# No results. Breaking ..
# URL count: 28
#
# 79
# Query: site:"http://www.kitzel.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.kitzel.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 28
#
# 80
# Query: site:"http://www.warnertool.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.warnertool.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 28
#
# 81
# Query: site:"https://benoist.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fbenoist.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.benoist.com/about-us/privacy-policy
# https://www.benoist.com/about-us/terms-of-service
# ['https://www.benoist.com/about-us/privacy-policy', 'https://www.benoist.com/about-us/terms-of-service']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.benoist.com/about-us/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 29
#
# 82
# Query: site:"https://www.wkwinc.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.wkwinc.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 29
#
# 83
# Query: site:"https://www.dold.co.uk "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.dold.co.uk+%22privacy+policy&num=3
# len alldata: 2
# []
# Considering 0 URL(s) ...
# URL count: 29
#
# 84
# Query: site:"http://www.metalunion.be "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.metalunion.be+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 29
#
# 85
# Query: site:"http://www.sun-source.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.sun-source.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.sun-source.com/privacy
# https://www.sun-source.com/UserFiles/resources/terms-and-conditions.pdf
# ['https://www.sun-source.com/privacy', 'https://www.sun-source.com/UserFiles/resources/terms-and-conditions.pdf']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.sun-source.com/privacy
# Found relevant terms in URL! Succesful break!
# URL count: 30
# 86
# Query: site:"https://www.grupp.de "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.grupp.de+%22privacy+policy&num=3
# len alldata: 1
# https://www.grupp.de/datenschutz
# ['https://www.grupp.de/datenschutz']
# Considering 1 URL(s) ...
# Assessing privacy policy URL: https://www.grupp.de/datenschutz
# No results. Breaking ..
# URL count: 30
#
# 87
# Query: site:"https://www.jrboone.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.jrboone.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.jrboone.com/privacy-policy
# https://www.jrboone.com/industry/powders-oils
# ['https://www.jrboone.com/privacy-policy', 'https://www.jrboone.com/industry/powders-oils']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.jrboone.com/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 31
#
# 88
# Query: site:"https://www.bkpowersystems.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.bkpowersystems.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.bkpowersystems.com/our-services/
# https://www.bkpowersystems.com/industry-served/material-handling/
# ['https://www.bkpowersystems.com/our-services/', 'https://www.bkpowersystems.com/industry-served/material-handling/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.bkpowersystems.com/our-services/
# Assessing privacy policy URL: https://www.bkpowersystems.com/industry-served/material-handling/
# No results. Breaking ..
# URL count: 31
#
# 89
# Query: site:"https://multigrind.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fmultigrind.com+%22privacy+policy&num=3
# len alldata: 2
# https://multigrind.com/datenschutz
# https://multigrind.com/en/contact-1
# ['https://multigrind.com/datenschutz', 'https://multigrind.com/en/contact-1']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://multigrind.com/datenschutz
# Assessing privacy policy URL: https://multigrind.com/en/contact-1
# No results. Breaking ..
# URL count: 31
#
# 90
# Query: site:"https://www.whs-plastics.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.whs-plastics.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 31
#
# 91
# Query: site:"https://www.idolz.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.idolz.com+%22privacy+policy&num=3
# len alldata: 1
# https://www.idolz.com/politica-de-cookies/
# ['https://www.idolz.com/politica-de-cookies/']
# Considering 1 URL(s) ...
# Assessing privacy policy URL: https://www.idolz.com/politica-de-cookies/
# No results. Breaking ..
# URL count: 31
#
# 92
# Query: site:"http://www.severancetools.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.severancetools.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 31
#
# 93
# Query: site:"https://perrygraf.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fperrygraf.com+%22privacy+policy&num=3
# len alldata: 2
# []
# Considering 0 URL(s) ...
# URL count: 31
#
# 94
# Query: site:"http://www.varomachinery.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.varomachinery.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.varomachinery.com/gdpr/
# https://www.varomachinery.com/cookie-policy/
# ['https://www.varomachinery.com/gdpr/', 'https://www.varomachinery.com/cookie-policy/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.varomachinery.com/gdpr/
# Found relevant terms in URL! Succesful break!
# URL count: 32
#
# 95
# Query: site:"http://www.kaltenbachtools.nl "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.kaltenbachtools.nl+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 32
#
# 96
# Query: site:"https://www.levanto.fi "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.levanto.fi+%22privacy+policy&num=3
# len alldata: 2
# https://www.levanto.fi/wp-content/uploads/2021/09/Levanto-Privacy-Policy.pdf
# https://www.levanto.fi/en/cookie-policy/
# ['https://www.levanto.fi/wp-content/uploads/2021/09/Levanto-Privacy-Policy.pdf', 'https://www.levanto.fi/en/cookie-policy/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.levanto.fi/wp-content/uploads/2021/09/Levanto-Privacy-Policy.pdf
# Assessing privacy policy URL: https://www.levanto.fi/en/cookie-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 33
#
# 97
# Query: site:"https://lukas-erzett.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Flukas-erzett.com+%22privacy+policy&num=3
# len alldata: 3
# https://lukas-erzett.com/en/privacy-note/
# https://lukas-erzett.com/wp-content/uploads/Privacy-Policy-VWL00060-15.08.2022.docx
# https://lukas-erzett.com/wp-content/uploads/2021-07-01_AGB-ENG.pdf
# ['https://lukas-erzett.com/en/privacy-note/', 'https://lukas-erzett.com/wp-content/uploads/Privacy-Policy-VWL00060-15.08.2022.docx', 'https://lukas-erzett.com/wp-content/uploads/2021-07-01_AGB-ENG.pdf']
# Considering 3 URL(s) ...
# Assessing privacy policy URL: https://lukas-erzett.com/en/privacy-note/
# Found relevant terms in URL! Succesful break!
# URL count: 34
#
# 98
# Query: site:"https://www.sommatool.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.sommatool.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.sommatool.com/privacy.asp
# https://www.sommatool.com/return_policy.asp
# ['https://www.sommatool.com/privacy.asp', 'https://www.sommatool.com/return_policy.asp']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.sommatool.com/privacy.asp
# Found relevant terms in URL! Succesful break!
# URL count: 35
#
# 99
# Query: site:"http://www.desktalk.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.desktalk.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 35
#
# 100
# Query: site:"https://www.melintool.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.melintool.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 35
#
# 101
# Query: site:"https://udico.co "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fudico.co+%22privacy+policy&num=3
# len alldata: 2
# https://udico.co/company/policies
# https://udico.co/company/help-center
# ['https://udico.co/company/policies', 'https://udico.co/company/help-center']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://udico.co/company/policies
# Assessing privacy policy URL: https://udico.co/company/help-center
# No results. Breaking ..
# URL count: 35
#
# 102
# Query: site:"https://www.hilti.ch "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.hilti.ch+%22privacy+policy&num=3
# len alldata: 3
# https://www.hilti.ch/content/hilti/E3/CH/fr/miscellaneous/landing-pages/data-subject-right-request.html
# https://www.hilti.ch/content/dam/documents/pdf/e4/condizioni/PRIVACY_NOTICE_master-for-localization_v2018_May_Italiano.pdf
# https://www.hilti.ch/content/hilti/E3/CH/it/company/hilti-website/datenschutzerklaerung.html
# ['https://www.hilti.ch/content/hilti/E3/CH/fr/miscellaneous/landing-pages/data-subject-right-request.html', 'https://www.hilti.ch/content/dam/documents/pdf/e4/condizioni/PRIVACY_NOTICE_master-for-localization_v2018_May_Italiano.pdf', 'https://www.hilti.ch/content/hilti/E3/CH/it/company/hilti-website/datenschutzerklaerung.html']
# Considering 3 URL(s) ...
# Assessing privacy policy URL: https://www.hilti.ch/content/hilti/E3/CH/fr/miscellaneous/landing-pages/data-subject-right-request.html
# Assessing privacy policy URL: https://www.hilti.ch/content/dam/documents/pdf/e4/condizioni/PRIVACY_NOTICE_master-for-localization_v2018_May_Italiano.pdf
# Assessing privacy policy URL: https://www.hilti.ch/content/hilti/E3/CH/it/company/hilti-website/datenschutzerklaerung.html
# No results. Breaking ..
# URL count: 35
# 103
# Query: site:"http://www.redondoygarcia.com/en/home "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.redondoygarcia.com%2Fen%2Fhome+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 35
#
# 104
# Query: site:"https://www.eisc.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.eisc.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 35
#
# 105
# Query: site:"https://flextek.dk "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fflextek.dk+%22privacy+policy&num=3
# len alldata: 3
# https://flextek.dk/machines/produkt/u630-advanced/
# https://flextek.dk/machines/produkt/lb3000exii/?lang=da
# https://flextek.dk/automation/cases/mobil-robot-distribuerer-udstyr-paa-hospital/?lang=en
# ['https://flextek.dk/machines/produkt/u630-advanced/', 'https://flextek.dk/machines/produkt/lb3000exii/?lang=da', 'https://flextek.dk/automation/cases/mobil-robot-distribuerer-udstyr-paa-hospital/?lang=en']
# Considering 3 URL(s) ...
# Assessing privacy policy URL: https://flextek.dk/machines/produkt/u630-advanced/
# Assessing privacy policy URL: https://flextek.dk/machines/produkt/lb3000exii/?lang=da
# Assessing privacy policy URL: https://flextek.dk/automation/cases/mobil-robot-distribuerer-udstyr-paa-hospital/?lang=en
# No results. Breaking ..
# URL count: 35
#
# 106
# Query: site:"https://www.garrtool.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.garrtool.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.garrtool.com/privacy-policy/
# https://www.garrtool.com/knowledge-base/tag/privacy/
# ['https://www.garrtool.com/privacy-policy/', 'https://www.garrtool.com/knowledge-base/tag/privacy/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.garrtool.com/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 36
#
# 107
# Query: site:"https://kaiserkraft.de "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fkaiserkraft.de+%22privacy+policy&num=3
# len alldata: 3
# https://www.kaiserkraft.de/company/karriere/w/company_career/
# https://www.kaiserkraft.de/lagercontainer/gefahrstoff-depots/pe-gefahrstoffdepot-mit-tueren/auffangvolumen-1150-l/p/M1028953/
# https://www.kaiserkraft.de/absperrungen/absperrgitter/scherengitter/mit-2-standfuessen/p/M1006439/
# ['https://www.kaiserkraft.de/company/karriere/w/company_career/', 'https://www.kaiserkraft.de/lagercontainer/gefahrstoff-depots/pe-gefahrstoffdepot-mit-tueren/auffangvolumen-1150-l/p/M1028953/', 'https://www.kaiserkraft.de/absperrungen/absperrgitter/scherengitter/mit-2-standfuessen/p/M1006439/']
# Considering 3 URL(s) ...
# Assessing privacy policy URL: https://www.kaiserkraft.de/company/karriere/w/company_career/
# Assessing privacy policy URL: https://www.kaiserkraft.de/lagercontainer/gefahrstoff-depots/pe-gefahrstoffdepot-mit-tueren/auffangvolumen-1150-l/p/M1028953/
# Assessing privacy policy URL: https://www.kaiserkraft.de/absperrungen/absperrgitter/scherengitter/mit-2-standfuessen/p/M1006439/
# No results. Breaking ..
# URL count: 36
#
# 108
# Query: site:"https://goodson.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fgoodson.com+%22privacy+policy&num=3
# len alldata: 2
# https://goodson.com/pages/privacy-policy
# https://goodson.com/pages/email-sign-up
# ['https://goodson.com/pages/privacy-policy', 'https://goodson.com/pages/email-sign-up']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://goodson.com/pages/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 37
#
# 109
# Query: site:"https://www.alexbauer.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.alexbauer.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 37
#
# 110
# Query: site:"https://perrotton.fr "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fperrotton.fr+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 37
#
# 111
# Query: site:"https://www.mullallybros.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.mullallybros.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 37
#
# 112
# Query: site:"http://www.rimaag.ch "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.rimaag.ch+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 37
#
# 113
# Query: site:"http://www.matcotools.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.matcotools.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.matcotools.com/customercare/privacy-policy/
# https://www.matcotools.com/mobile/catalog/privacy/student.html
# ['https://www.matcotools.com/customercare/privacy-policy/', 'https://www.matcotools.com/mobile/catalog/privacy/student.html']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.matcotools.com/customercare/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 38
#
# 114
# Query: site:"https://www.proudfoot.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.proudfoot.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 38
#
# 115
# Query: site:"https://russellresearch.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Frussellresearch.com+%22privacy+policy&num=3
# len alldata: 2
# https://russellresearch.com/privacy-policy/
# https://russellresearch.com/respondent-privacy-policy/
# ['https://russellresearch.com/privacy-policy/', 'https://russellresearch.com/respondent-privacy-policy/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://russellresearch.com/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 39
#
# 116
# Query: site:"https://www.bavelloni.com "privacy policy
# ...
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.censornet.com/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 273
#
# 961
# Query: site:"http://www.open-xchange.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.open-xchange.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.open-xchange.com/privacy
# https://www.open-xchange.com/about-ox/career/gdpr/
# ['https://www.open-xchange.com/privacy', 'https://www.open-xchange.com/about-ox/career/gdpr/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.open-xchange.com/privacy
# Found relevant terms in URL! Succesful break!
# URL count: 274
#
# 962
# Query: site:"https://www.upwave.io "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.upwave.io+%22privacy+policy&num=3
# len alldata: 2
# https://www.upwave.io/privacy/
# https://www.upwave.io/privacy-statement/
# ['https://www.upwave.io/privacy/', 'https://www.upwave.io/privacy-statement/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.upwave.io/privacy/
# Found relevant terms in URL! Succesful break!
# URL count: 275
#
# 963
# Query: site:"https://www.nextgenid.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.nextgenid.com+%22privacy+policy&num=3
# len alldata: 1
# https://www.nextgenid.com/about.php
# ['https://www.nextgenid.com/about.php']
# Considering 1 URL(s) ...
# Assessing privacy policy URL: https://www.nextgenid.com/about.php
# No results. Breaking ..
# URL count: 275
#
# 964
# Query: site:"https://www.gbtec.de/en "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.gbtec.de%2Fen+%22privacy+policy&num=3
# len alldata: 2
# https://www.gbtec.de/en/data-protection/
# https://www.gbtec.de/en/newsletter/
# ['https://www.gbtec.de/en/data-protection/', 'https://www.gbtec.de/en/newsletter/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.gbtec.de/en/data-protection/
# Assessing privacy policy URL: https://www.gbtec.de/en/newsletter/
# No results. Breaking ..
# URL count: 275
#
# 965
# Query: site:"https://www.resume-now.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.resume-now.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.resume-now.com/privacy-policy
# https://www.resume-now.com/terms-of-use
# ['https://www.resume-now.com/privacy-policy', 'https://www.resume-now.com/terms-of-use']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.resume-now.com/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 276
#
# 966
# Query: site:"http://www.shinyfrog.net "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.shinyfrog.net+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 276
#
# 967
# Query: site:"http://kt.ua "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fkt.ua+%22privacy+policy&num=3
# len alldata: 1
# https://mail.kt.ua/termsofservice
# ['https://mail.kt.ua/termsofservice']
# Considering 1 URL(s) ...
# Assessing privacy policy URL: https://mail.kt.ua/termsofservice
# Found relevant terms in URL! Succesful break!
# URL count: 277
#
# 968
# Query: site:"https://www.ecotools.nl "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.ecotools.nl+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 277
#
# 969
# Query: site:"https://www.forensicsoft.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.forensicsoft.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.forensicsoft.com/privacy-policy
# https://www.forensicsoft.com/terms-of-service
# ['https://www.forensicsoft.com/privacy-policy', 'https://www.forensicsoft.com/terms-of-service']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.forensicsoft.com/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 278
#
# 970
# Query: site:"https://www.agamimedia.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.agamimedia.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.agamimedia.com/privacy-policy
# https://www.agamimedia.com/user/register
# ['https://www.agamimedia.com/privacy-policy', 'https://www.agamimedia.com/user/register']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.agamimedia.com/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 279
#
# 971
# Query: site:"https://media-dog.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fmedia-dog.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 279
#
# 972
# Query: site:"https://bayviewcomposites.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fbayviewcomposites.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 279
#
# 973
# Query: site:"https://www.printgreener.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.printgreener.com+%22privacy+policy&num=3
# len alldata: 3
# https://www.printgreener.com/home/privacy-policy
# https://www.printgreener.com/index.php/download?file=staples/pdf/greenprint-snalytics-security-overview.pdf
# https://www.printgreener.com/home/about
# ['https://www.printgreener.com/home/privacy-policy', 'https://www.printgreener.com/index.php/download?file=staples/pdf/greenprint-snalytics-security-overview.pdf', 'https://www.printgreener.com/home/about']
# Considering 3 URL(s) ...
# Assessing privacy policy URL: https://www.printgreener.com/home/privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 280
#
# 974
# Query: site:"https://www.annotate.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.annotate.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.annotate.com/docs/annotate-privacy-policy.pdf
# https://www.annotate.com/legal-terms.html
# ['https://www.annotate.com/docs/annotate-privacy-policy.pdf', 'https://www.annotate.com/legal-terms.html']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.annotate.com/docs/annotate-privacy-policy.pdf
# Found relevant terms in URL! Succesful break!
# URL count: 281
#
# 975
# Query: site:"https://docsindustries.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fdocsindustries.com+%22privacy+policy&num=3
# len alldata: 2
# https://docsindustries.com/privacy-policy/
# https://docsindustries.com/contact-2/
# ['https://docsindustries.com/privacy-policy/', 'https://docsindustries.com/contact-2/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://docsindustries.com/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 282
#
# 976
# Query: site:"https://cinecert.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fcinecert.com+%22privacy+policy&num=3
# len alldata: 2
# https://cinecert.com/privacy-policy/
# https://cinecert.com/services/
# ['https://cinecert.com/privacy-policy/', 'https://cinecert.com/services/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://cinecert.com/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 283
# 977
# Query: site:"https://www.cmsgroup.net/home  "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.cmsgroup.net%2Fhome++%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 283
#
# 978
# Query: site:"http://www.schubertsoftware.de "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.schubertsoftware.de+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 283
#
# 979
# Query: site:"https://www.turbo-tec.eu "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.turbo-tec.eu+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 283
#
# 980
# Query: site:"https://kvtek.in "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fkvtek.in+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 283
#
# 981
# Query: site:"https://www.muvenum.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.muvenum.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.muvenum.com/company/privacy-policy/
# https://www.muvenum.com/company/terms-of-use/
# ['https://www.muvenum.com/company/privacy-policy/', 'https://www.muvenum.com/company/terms-of-use/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.muvenum.com/company/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 284
#
# 982
# Query: site:"https://www.koultools.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.koultools.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 284
#
# 983
# Query: site:"http://crwautomation.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fcrwautomation.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 284
#
# 984
# Query: site:"http://www.tehnicar-brod.hr "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.tehnicar-brod.hr+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 284
#
# 985
# Query: site:"http://www.mettlertools.ch "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.mettlertools.ch+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 284
#
# 986
# Query: site:"https://www.edoxx.net "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.edoxx.net+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 284
#
# 987
# Query: site:"http://www.svarmetal.cz "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.svarmetal.cz+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 284
#
# 988
# Query: site:"https://www.goodtimegifts.nl "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.goodtimegifts.nl+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 284
#
# 989
# Query: site:"https://www.skill-box.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.skill-box.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.skill-box.com/index.php?page=privacy
# https://www.skill-box.com/
# ['https://www.skill-box.com/index.php?page=privacy', 'https://www.skill-box.com/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.skill-box.com/index.php?page=privacy
# Found relevant terms in URL! Succesful break!
# URL count: 285
#
# 990
# Query: site:"https://mural365.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fmural365.com+%22privacy+policy&num=3
# len alldata: 2
# https://community.mural365.com/faq
# https://community.mural365.com/
# ['https://community.mural365.com/faq', 'https://community.mural365.com/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://community.mural365.com/faq
# Assessing privacy policy URL: https://community.mural365.com/
# No results. Breaking ..
# URL count: 285
#
# 991
# Query: site:"http://www.eleshop.nl "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.eleshop.nl+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 285
#
# 992
# Query: site:"https://www.anaplan.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.anaplan.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.anaplan.com/privacy-statement/
# https://www.anaplan.com/legal/policies/security/
# ['https://www.anaplan.com/privacy-statement/', 'https://www.anaplan.com/legal/policies/security/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.anaplan.com/privacy-statement/
# Found relevant terms in URL! Succesful break!
# URL count: 286
#
# 993
# Query: site:"https://www.airslate.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.airslate.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.airslate.com/workflow/3153494-terms-of-use-for-website-and-privacy-policy
# https://www.airslate.com/workflow/online-forms/73986-arrange-adult-privacy-policy
# ['https://www.airslate.com/workflow/3153494-terms-of-use-for-website-and-privacy-policy', 'https://www.airslate.com/workflow/online-forms/73986-arrange-adult-privacy-policy']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.airslate.com/workflow/3153494-terms-of-use-for-website-and-privacy-policy
# Found relevant terms in URL! Succesful break!
# URL count: 287
#
# 994
# Query: site:"https://www.foodlogiq.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.foodlogiq.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.foodlogiq.com/privacy-policy/
# https://www.foodlogiq.com/terms-and-conditions/
# ['https://www.foodlogiq.com/privacy-policy/', 'https://www.foodlogiq.com/terms-and-conditions/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.foodlogiq.com/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 288
#
# 995
# Query: site:"https://www.jotform.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.jotform.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.jotform.com/privacy/
# https://www.jotform.com/blog/how-to-add-a-privacy-policy-to-website/
# ['https://www.jotform.com/privacy/', 'https://www.jotform.com/blog/how-to-add-a-privacy-policy-to-website/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.jotform.com/privacy/
# Found relevant terms in URL! Succesful break!
# URL count: 289
#
# 996
# Query: site:"http://www.viewpath.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.viewpath.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 289
#
# 997
# Query: site:"https://www.widenarrow.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.widenarrow.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.widenarrow.com/about-wide-narrow
# https://www.widenarrow.com/info-request
# ['https://www.widenarrow.com/about-wide-narrow', 'https://www.widenarrow.com/info-request']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.widenarrow.com/about-wide-narrow
# Assessing privacy policy URL: https://www.widenarrow.com/info-request
# No results. Breaking ..
# URL count: 289
#
# 998
# Query: site:"http://www.xpressmo.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22http%3A%2F%2Fwww.xpressmo.com+%22privacy+policy&num=3
# len alldata: 0
# []
# Considering 0 URL(s) ...
# URL count: 289
#
# 999
# Query: site:"https://www.giganticsoftware.com "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.giganticsoftware.com+%22privacy+policy&num=3
# len alldata: 2
# https://www.giganticsoftware.com/privacy-policy/
# https://www.giganticsoftware.com/legal/
# ['https://www.giganticsoftware.com/privacy-policy/', 'https://www.giganticsoftware.com/legal/']
# Considering 2 URL(s) ...
# Assessing privacy policy URL: https://www.giganticsoftware.com/privacy-policy/
# Found relevant terms in URL! Succesful break!
# URL count: 290

# %%
len(privacy_policies_url_list)
# Out:
# 2468

# %%
(len([(collected_url) for collected_url in privacy_policies_url_list if collected_url is not ""]))
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-35-be691173171a>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   (len([(collected_url) for collected_url in privacy_policies_url_list if collected_url is not ""]))
# 874

# %%
crunch_data['PP URL'] = privacy_policies_url_list

# %%
#save data
crunch_data.to_csv("crunch_data_collaborate_surv.csv", sep='\t', header=True, index=False)

# %%
crunch_data_r = pd.read_csv("crunch_data_collaborate_surv.csv", sep='\t', encoding='utf-8')

# %%
crunch_data_r
# Out:
#                        Organization Name  \
# 0     Desire Group International limited
# 1                  WorkHub Platform Inc.
# 2                 Neu Ocean Technologies
# 3                   Coleridge Initiative
# 4                               Calliper
# ...                                  ...
# 2463                             Woobius
# 2464                              Onehub
# 2465                            eTask.it
# 2466                           Combionic
# 2467                         Broadchoice
#
#                                   Organization Name URL Founded Date  \
# 0     https://www.crunchbase.com/organization/desire...   2022-09-08
# 1     https://www.crunchbase.com/organization/workhu...   2022-08-01
# 2     https://www.crunchbase.com/organization/neu-oc...   2022-02-24
# 3     https://www.crunchbase.com/organization/coleri...   2022-01-01
# 4      https://www.crunchbase.com/organization/calliper   2022-01-01
# ...                                                 ...          ...
# 2463    https://www.crunchbase.com/organization/woobius   2007-10-02
# 2464     https://www.crunchbase.com/organization/onehub   2007-10-15
# 2465  https://www.crunchbase.com/organization/etask-...   2007-11-01
# 2466  https://www.crunchbase.com/organization/combionic   2007-11-01
# 2467  https://www.crunchbase.com/organization/broadc...   2007-11-01
#
#      Founded Date Precision Number of Employees  \
# 0                       day                1-10
# 1                     month              51-100
# 2                       day             101-250
# 3                      year               11-50
# 4                      year                1-10
# ...                     ...                 ...
# 2463                    day                1-10
# 2464                    day               11-50
# 2465                    day               11-50
# 2466                    day               11-50
# 2467                    day               11-50
#
#                                        Full Description  \
# 0     Desire Group International is a U.K based comp...
# 1     WorkHub is a tech company established in July ...
# 2     Neu Ocean offers a comprehensive business mana...
# 3     The Administrative Data Research Facility (ADR...
# 4                                                   NaN
# ...                                                 ...
# 2463  Woobius is a collaboration tool for architects...
# 2464  Onehub's mission is to provide small and mediu...
# 2465  eTask.it harnesses the global trend of Web 2.0...
# 2466  Combionic collaboration software connects peop...
# 2467  Broadchoice Workspaceâ„¢ provides fast, easy m...
#
#                                           Website  \
# 0     https://www.desiregroupinternational.co.uk/
# 1                         https://www.workhub.ai/
# 2                            https://neuocean.com
# 3                https://coleridgeinitiative.org/
# 4                    https://www.getcalliper.com/
# ...                                           ...
# 2463                       http://www.woobius.com
# 2464                  https://www.onehub.com/home
# 2465                          http://www.etask.it
# 2466                     http://www.combionic.com
# 2467                   http://www.broadchoice.com
#
#                                              Industries  \
# 0     Business Development, Collaboration, Enterpris...
# 1                          B2B, Collaboration, Software
# 2     Cloud Computing, Collaboration, Enterprise Sof...
# 3      Analytics, Collaboration, Information Technology
# 4     Analytics, Business Intelligence, Collaboratio...
# ...                                                 ...
# 2463  Architecture, Collaboration, Construction, Ent...
# 2464  Collaboration, Document Management, Enterprise...
# 2465  Collaboration, IT Management, Outsourcing, Pro...
# 2466  Collaboration, Content, Risk Management, Software
# 2467  Collaboration, Enterprise Software, File Shari...
#
#                        Headquarters Location  \
# 0            London, England, United Kingdom
# 1        San Jose, California, United States
# 2            London, England, United Kingdom
# 3          Brooklyn, New York, United States
# 4            London, England, United Kingdom
# ...                                      ...
# 2463         London, England, United Kingdom
# 2464      Seattle, Washington, United States
# 2465  Farnborough, Hampshire, United Kingdom
# 2466                 Berlin, Berlin, Germany
# 2467    San Mateo, California, United States
#
#                                             Description  ...  \
# 0     Saas, Business development, Techsales, Marketi...  ...
# 1     WorkHub is providing affordable team productiv...  ...
# 2     Scalable AI-powered business management and au...  ...
# 3     Coleridge Initiative is a company that provide...  ...
# 4     Making data accessible and actionable for ever...  ...
# ...                                                 ...  ...
# 2463  Woobius is a revolutionary collaboration hub f...  ...
# 2464  Securely store, organize, and share files in t...  ...
# 2465  eTask is a U.K.-based project management solut...  ...
# 2466  Combionic develops gateway technology to conne...  ...
# 2467  Broadchoice offers messaging and file sharing ...  ...
#
#      SEMrush - Visit Duration Growth SEMrush - Visit Duration  \
# 0                                NaN                      NaN
# 1                             14.91%                      925
# 2                                NaN                      NaN
# 3                             47.32%                      165
# 4                                NaN                      191
# ...                              ...                      ...
# 2463                             NaN                      NaN
# 2464                         169.62%                    2,219
# 2465                             NaN                      NaN
# 2466                             NaN                      NaN
# 2467                             NaN                      NaN
#
#      SEMrush - Page Views / Visit SEMrush - Page Views / Visit Growth  \
# 0                             NaN                                 NaN
# 1                            3.51                             -13.63%
# 2                             NaN                                 NaN
# 3                            3.81                              26.97%
# 4                            2.92                                 NaN
# ...                           ...                                 ...
# 2463                          NaN                                 NaN
# 2464                         2.09                             -16.63%
# 2465                          NaN                                 NaN
# 2466                          NaN                                 NaN
# 2467                          NaN                                 NaN
#
#      SEMrush - Bounce Rate SEMrush - Bounce Rate Growth  \
# 0                      NaN                          NaN
# 1                   27.45%                      -12.08%
# 2                      NaN                          NaN
# 3                    6.36%                      -80.92%
# 4                      10%                          NaN
# ...                    ...                          ...
# 2463                   NaN                          NaN
# 2464                 73.4%                       33.36%
# 2465                   NaN                          NaN
# 2466                   NaN                          NaN
# 2467                   NaN                          NaN
#
#       SEMrush - Global Traffic Rank SEMrush - Monthly Rank Change (#)  \
# 0                               NaN                               NaN
# 1                           459,552                        -1,880,548
# 2                               NaN                               NaN
# 3                         6,062,300                         2,483,928
# 4                         3,743,703                               NaN
# ...                             ...                               ...
# 2463                            NaN                               NaN
# 2464                         80,534                           -18,092
# 2465                            NaN                               NaN
# 2466                            NaN                               NaN
# 2467                            NaN                               NaN
#
#      SEMrush - Monthly Rank Growth  \
# 0                              NaN
# 1                          -80.36%
# 2                              NaN
# 3                           69.42%
# 4                              NaN
# ...                            ...
# 2463                           NaN
# 2464                       -18.34%
# 2465                           NaN
# 2466                           NaN
# 2467                           NaN
#
#                                                  PP URL
# 0     https://www.desiregroupinternational.co.uk/pri...
# 1                https://www.workhub.ai/privacy-policy/
# 2                                                   NaN
# 3     https://textbook.coleridgeinitiative.org/chap-...
# 4                   https://www.getcalliper.com/privacy
# ...                                                 ...
# 2463            https://www.woobius.com/privacy-policy/
# 2464                                                NaN
# 2465                                                NaN
# 2466                                                NaN
# 2467                                                NaN
#
# [2468 rows x 24 columns]

# %% [markdown]
# # Step 3: Scrape privacy policies

# %%
nlp = spacy.load("en_core_web_md")

# %%
def scrape_policies_google(url):
    policies = []
    sentences = []    
    try:
        
        article = Article(url)
#             print(url)
        article.download() #Downloads the link’s HTML content
#             print(url)
        article.parse() #Parse the article
#             print(url)
#                 print(article.title)
        doc = nlp(article.text)
        print("PP language = EN?: " + str(detect(article.text) == 'en'))
        print("PP length > 10 sentences?: " + str(len(list(doc.sents)) > 10))

        if detect(article.text) == 'en' and len(list(doc.sents)) > 10:
            print("Policy meets requirements of language and length ... ")
            sentences = list(doc.sents)
            print("Scraping successful!")

        else:
            print("Scraping not successful")
    except:
            pass
    print()
    return sentences

# %%
pp_list_sentences = []
for i, pp_url in enumerate(privacy_policies_url_list):
    print(i)
    if pp_url == "":
        pp_list_sentences.append("")
    else:
        pp_list_sentences.append(scrape_policies_google(pp_url))

# %%
[print(len(pp)) for pp in pp_list_sentences]

# %% [markdown]
# # Step 4: Classification

# %%
crunch_data_r

# %%
GDPR_classes = ['DPO', 'Purpose', 'Acquired data', 'Data sharing', 'Rights']

# %%
thresholds = [0.014130434782608696, 0.035326086956521736, 0.017934782608695653, 0.03369565217391304, 0.009782608695652175]

# %% [markdown]
# #### Preprocessing

# %%
def preprocessing(pps):
#     tokenizer = nlp.tokenizer
    # tokenize sentences
    tokenized_sent = [sent.text.split() for sent in pps]
    
    # remove punctuation
    tokenized_sent = [[re.sub('[,’\'\.!?&“”():*_;"]', '', y) for y in x] for x in tokenized_sent]
    
    # remove words with numbers in them
    tokenized_sent = [[y for y in x if not any(c.isdigit() for c in y)] for x in tokenized_sent]
    
    # remove stopwords   
    tokenized_sent_clean = tokenized_sent
#     tokenized_sent_clean = [[y for y in x if y not in stopwords.words('english')] for x in tokenized_sent]
    
    # from nltk.stem import PorterStemmer
    porter = PorterStemmer()
    tokenized_sent_clean = [[porter.stem(y) for y in x] for x in tokenized_sent_clean]
    
#     lemmatizer = WordNetLemmatizer()
#     tokenized_sent_clean = [[lemmatizer.lemmatize(y) for y in x] for x in tokenized_sent_clean]

    
    detokenized_pps = []
    for i in range(len(tokenized_sent_clean)):
        t = ' '.join(tokenized_sent_clean[i])
        detokenized_pps.append(t) 
    
    return detokenized_pps

# %%
def set_GDPR_columns(df):
    df['DPO'] = 0
    df['Purpose'] = 0
    df['Acquired data'] = 0
    df['Data sharing']  = 0
    df['Rights'] = 0

# %%
set_GDPR_columns(crunch_data_r)

# %%
pp_list_sentences_prep = []

for j, pp in enumerate(pp_list_sentences):
    pp_list_sentences_prep.append(preprocessing(pp))

# %%
pp_list_sentences_prep

# %%
crunch_data_r['PP text'] = pp_list_sentences_prep

# %%
crunch_data_r

# %%
crunch_data_r.to_csv("crunch_data_pp_url_text.csv", sep='\t', header=True)

# %% [markdown]
# #### Classification

# %%
crunch_data_r = pd.read_csv("crunch_data_pp_url_text.csv", sep='\t', encoding='utf-8', index_col = 0)

# %%
crunch_data_r

# %%
crunch_data_r_selected = crunch_data_r.loc[crunch_data_r['PP text'] != "[]"]

# %%
crunch_data_r_selected

# %%
for index, row in crunch_data_r_selected.iterrows(): 
    x = row["PP text"]
    pp_text_split = x.split(', ')
    
    for j, category in enumerate(GDPR_classes):
             # Load from file to check if everything is ok
        filen = "linreg-oversampling-" + category + ".pkl"      
        with open(filen, 'rb') as file:
            vectorizer, lr = pickle.load(file)
            x = vectorizer.transform(pp_text_split)
        
            y_pred = lr.predict(x)
#             print(y_pred)
            n_pos_pred = list(y_pred).count(1)
#             print(n_pos_pred)
            
            
#             print("(" + str(n_pos_pred) + "/" + str(len(pp_text_split)) + ") >= " + str(thresholds[j]))
            if (n_pos_pred/len(pp_text_split)) >= thresholds[j]:
    #           MARK THE LABEL AS POSITIVE (1), DEFAULT STATE IS NEGATIVE (0)
#                 print("TRUE")
                crunch_data_r_selected.at[index, GDPR_classes[j]] = 1
            else:
                pass

# %%
crunch_data_r_selected

# %% [markdown]
# # Classification Analysis (425 privacy policies)

# %%
for idx, GDPR_class in enumerate(GDPR_classes):
    print(GDPR_class)
    print("Positively classified:" + str(crunch_data_r_selected[GDPR_class].value_counts()[0]) + " (" + str((crunch_data_r_selected[GDPR_class].value_counts()[0]/crunch_data_r_selected.shape[0])*100) + "%)")
    print("Negatively classified:" + str(crunch_data_r_selected[GDPR_class].value_counts()[1]) + " (" + str((crunch_data_r_selected[GDPR_class].value_counts()[1]/crunch_data_r_selected.shape[0])*100) + "%)")
    classification_analysis = [
       [GDPR_class, crunch_data_r_selected.shape[0], crunch_data_r_selected[GDPR_class].value_counts()[0], crunch_data_r_selected[GDPR_class].value_counts()[1]],
#        [GDPR_labels[idx], 'L1', 'numerical', 'full data', sm_lr_numpredictors_acc[idx], {k:v for (k,v) in dict(sm_lr_numpredictors[idx].pvalues).items() if ((v <= 0.05) and ( v != 0) and (k != 'const'))}]
      ]
    classification_analysis = pd.DataFrame(classification_analysis, columns =['GDPR Class', '# companies', 'Postive', 'Negative'])
#     print(summary_sm_sk.to_markdown())
    
    display(HTML(classification_analysis.to_html(index=False)))
    print()
    print()

# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# ### Select potentially interesting predictors

# %% [markdown]
# - Employee (object),
# - Type (object),
# - Founded Date (object),
# - Location
# - Operating Status (object),
# - Industry 1 (object)

# %%
pd_stats = crunch_data_r_selected[["Employees", "Founded Date", "Location", "Industry 1", "DPO", "Purpose", "Acquired data", "Data sharing", "Rights"]].copy(deep=True)

# %%
pd_stats.info()

# %% [markdown]
# ##### Employees

# %%
pd_stats["Employees"].value_counts()

# %% [markdown]
# ##### Founded Date

# %%
pd_stats["Founded Date"].value_counts()

# %% [markdown]
# Convert to year

# %%
f_date = pd_stats["Founded Date"].tolist()

# %%
f_date_clean = [re.findall(r'(\d{4})', date)[0] if date is not np.nan else (np.nan) for date in f_date]

# %%
len(f_date)

# %%
(f_date_clean)

# %%
pd_stats["Founded Year"] = f_date_clean

# %%
pd_stats["Founded Year"].value_counts()

# %% [markdown]
# ##### Location

# %%
pd_stats["Location"].value_counts()

# %%
location = pd_stats["Location"].to_list()

# %%
country = [(country.split(", ")[-1]) for country in location]

# %%
len(country)

# %%
pd_stats["Country"] = country

# %%
pd_stats["Country"].value_counts()

# %% [markdown]
# ##### Industry 1

# %%
pd_stats["Industry 1"].value_counts()

# %% [markdown]
# ### Drop old columns

# %%
pd_stats.drop(['Founded Date', 'Location'], axis=1, inplace=True)

# %%
pd_stats.info()

# %% [markdown]
# ### Cast to category

# %%
# Define the lambda function: categorize_label
label_categorical = lambda x: x.astype('category')

# %%
pd_stats = pd_stats.apply(label_categorical, axis=0)

# %%
pd_stats.dtypes

# %% [markdown]
# ### LR with Statsmodels

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import roc_curve
from sklearn.metrics import confusion_matrix
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# scaling
from sklearn.preprocessing import StandardScaler

pd.set_option('display.max_columns', None) 
pd.set_option('display.max_colwidth', None)

# %%
pd_stats.isna().sum()

# %%
GDPR_classes

# %% [markdown]
# #### Explore correlations

# %%
X = pd_stats.drop(GDPR_classes,axis=1) # independant features
X = pd.get_dummies(X, drop_first = True)
sns.clustermap(X.corr())

# %% [markdown]
# #### Split data

# %%
train, test = train_test_split(pd_stats, test_size=0.2, random_state=42)
X_train = train.drop(GDPR_classes,axis=1) # independant features

# %% [markdown]
# #### Encode non-numerical categorical data, and drop first to avoid collinearity

# %%
X_train = pd.get_dummies(X_train, drop_first = True)

# %% [markdown]
# # Parameter Optimization

# %% [markdown]
# #### First without PO

# %%
train, test = train_test_split(pd_stats, test_size=0.25, random_state=25)
sel_alpha_list = dict()
acc_last = 0

# %%
y_train = train[GDPR_classes[0]] # dependant variable
y_test = test[GDPR_classes[0]] # dependant variable

# %%
# independent features
X_train = train.drop(GDPR_classes, axis=1) 
# encode non-numerical categorical data, and drop first to avoid collinearity
X_train = pd.get_dummies(X_train, drop_first = True)

X_test = test.drop(GDPR_classes, axis=1) # independant features
X_test = pd.get_dummies(X_test, drop_first = True)

X_train = sm.add_constant(X_train)
X_test = sm.add_constant(X_test)

# %%
X_train

# %%
model = sm.Logit(y_train,X_train)
logit_model = model.fit()

# %%
pred_train = logit_model.predict(X_train)>=.5
pred_test = logit_model.predict(X_test)>=.5

# %%
acc_train = (y_train==pred_train).mean()
acc_test = (y_test==pred_test).mean()

print("Acc: ", acc_test)
print("Alpha: ", alpha_op)

# %%
alpha_list = list(np.arange(0.001, 10, 0.1))

# %% [markdown]
# ##### Optimize parameters

# %%
opt_alpha = optimize_logit(pd_stats, True, alpha_list, True)

# %%
X_train

# %%
y_train

# %%
def optimize_logit(pd_stats, reg, alpha_range, intercept_set):
    train, test = train_test_split(pd_stats, test_size=0.2, random_state=25)
    sel_alpha_list = dict()
    acc_last = 0

    for GDPR_cat in GDPR_classes:
        alpha_sel = alpha_range[0]
        acc_last = 0

        print("***************** NEW ROUND!")
        for alpha_op in alpha_range:
            print("GDPR-category: " + GDPR_class)

            y_train = train[GDPR_class] # dependant variable
            y_test = test[GDPR_class] # dependant variable
            
#             sys.exit(0)

            # independent features
            X_train = train.drop(GDPR_classes, axis=1) 
            # encode non-numerical categorical data, and drop first to avoid collinearity
            X_train = pd.get_dummies(X_train, drop_first = True)

            X_test = test.drop(GDPR_classes, axis=1) # independant features
            X_test = pd.get_dummies(X_test, drop_first = True)

            if(intercept_set):
                X_train = sm.add_constant(X_train)
                X_test = sm.add_constant(X_test)
                
            print(y_train)

            print("flag 1")
            model = sm.Logit(y_train,X_train)
            print("flag 2")

            if(reg):
                logit_model = model.fit_regularized(method = 'l1', trim_mode = 'size', alpha = alpha_op)
            else:
                logit_model = model.fit()

            print("flag 3")

            pred_train = logit_model.predict(X_train)>=.5

            pred_test = logit_model.predict(X_test)>=.5

            acc_train = (y_train==pred_train).mean()

            acc_test = (y_test==pred_test).mean()
            
            print("Acc: ", acc_test)
            print("Alpha: ", alpha_op)

            sys.exit(0)
            if(acc_test >= acc_last):
                print("Alpha selected!")
                alpha_sel = alpha_op 
                acc_last = acc_test

            # last alpha in range? Place optimized alpha and accuracy in dict
            if(alpha_op == alpha_list[-1]):
                sel_alpha_list[GDPR_class] = [alpha_sel, acc_last]
            
            print()
            print()

    return sel_alpha_list
