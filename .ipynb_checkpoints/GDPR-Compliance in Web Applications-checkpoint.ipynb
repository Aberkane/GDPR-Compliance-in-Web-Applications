# %% [markdown]
# # Assessing GDPR-compliance in application software: A Machine Learning Approach

# %% [markdown]
# We will assess the GDPR-compliance of web applications based on their privacy policies. We use a classification model, trained on a corpus of 18,397 natural sentences, to classify the privacy policies on whether five General Data Protection Regulation (GDPR) privacy policy core requirements are communicated in the policy.
#
# __Relevance:__ The GDPR applies to any personal data processing of EU citizens. We aim to assess the state of GDPR-compliance in application software based on their privacy policies.
#
# __Focus:__ web applications; as the web application paradigm is widely used due to the omnipresence of web browsers across PCs and mobile devices.
#
# __Goal:__ to scrutinize the privacy policies of web applications using ML, to assess whether core privacy policy requirements are communicated.
#
# #### __RQ:__ What is the state of GDPR-compliance disclosure in web applications?

# %% [markdown]
# ---

# %% [markdown]
# ### Step 1: collect list of companies active in the Web Apps industry
#
# To do so we utilize the Crunchbase database that allows us to identify companies that engage in web applications, filtered on location (which in our case will be the European Union). We used
#
# We've imported 1000 companies using the following criteria:
# - Industry: Web Apps
# - Location: Europe (European Union)
#
# These criteria yield 2019 results of which we collected 1000.

# %% [markdown]
# ---

# %%
import os
from newspaper import Article
from bs4 import BeautifulSoup
from six.moves.urllib.parse import urlparse
import urllib
import sys
import time
import nltk
import pandas as pd
import requests
import spacy
from googlesearch import search
from langdetect import detect
import re
import random
import pickle
import math

# %% [markdown]
# ### Step 2: read data

# %%
# crunch_data_init = pd.read_excel('data/Advanced Search _ Companies _ Crunchbase.xlsx', index_col=0) 
crunch_data = pd.read_excel('data/companies.xlsx', index_col=0)

# %%
# crunch_data = crunch_data_init.iloc[0:999]

# %%
crunch_data
# Out:
#                                                                     Description  \
# Identifier
# 01s-community-company         01S Community company communicates and interac...
# 1000-digital                  1000 ° Digital develops innovative web applica...
# 100-net                       100% Net is a global internet solution for all...
# 100starlings                  100 Starlings creates web and mobile apps, the...
# 10geeks-software-engineering  10Geeks designs, develops, and analyzes tailor...
# ...                                                                         ...
# zonova                        Zonova is an information technology and servic...
# zoonect                       Zoonect offers web apps, mobile app, cloud pla...
# zostera                       Zostera specializes provides software and data...
# zoznam-mobile                 Zoznam Mobile offers services in the implement...
# zuinq                         Zuinq their services include web solution, fro...
#
#                                                                        Location  \
# Identifier
# 01s-community-company                                    Arezzo, Toscana, Italy
# 1000-digital                                          Leipzig, Sachsen, Germany
# 100-net                                                Pérols, Limousin, France
# 100starlings                                    London, England, United Kingdom
# 10geeks-software-engineering                 Fohren, Baden-Wurttemberg, Germany
# ...                                                                         ...
# zonova                                          Terrenoire, Rhone-Alpes, France
# zoonect                                                 Pistoia, Toscana, Italy
# zostera                            Aarlanderveen, Zuid-Holland, The Netherlands
# zoznam-mobile                 Bratislava, Bratislava, Slovakia (Slovak Repub...
# zuinq                                                 Sevilla, Andalucia, Spain
#
#                              Employees     Type  \
# Identifier
# 01s-community-company           51-100  Private
# 1000-digital                     11-50  Private
# 100-net                           1-10  Private
# 100starlings                      1-10  Private
# 10geeks-software-engineering      1-10  Private
# ...                                ...      ...
# zonova                           11-50  Private
# zoonect                           1-10  Private
# zostera                           1-10  Private
# zoznam-mobile                     1-10  Private
# zuinq                             1-10  Private
#
#                                                            Website       Rank  \
# Identifier
# 01s-community-company                                  www.01s.it/  1,284,758
# 1000-digital                                       www.1000grad.de  1,480,851
# 100-net                                    www.100pour100net.com//    986,874
# 100starlings                                 www.100starlings.com/    388,746
# 10geeks-software-engineering                       www.10geeks.com    651,610
# ...                                                            ...        ...
# zonova                                                   zonova.io    853,916
# zoonect                                            www.zoonect.com  1,741,834
# zostera                                                 zostera.nl  1,839,410
# zoznam-mobile                                              zmb.sk/  1,671,707
# zuinq                         www.zuinqstudio.com/inicio/index.php  1,825,628
#
#                              Founded Date Operating Status Company Type  \
# Identifier
# 01s-community-company                 NaN           Active   For Profit
# 1000-digital                         2000           Active   For Profit
# 100-net                              2003           Active   For Profit
# 100starlings                         2015           Active   For Profit
# 10geeks-software-engineering  Jan 1, 2012           Active   For Profit
# ...                                   ...              ...          ...
# zonova                               2017           Active   For Profit
# zoonect                              2015           Active   For Profit
# zostera                               NaN           Active   For Profit
# zoznam-mobile                 Jan 1, 2002           Active   For Profit
# zuinq                         Jan 1, 2011           Active   For Profit
#
#                                             Contact Email  ... Industry 31  \
# Identifier                                                 ...
# 01s-community-company                         info@01s.it  ...         NaN
# 1000-digital                             info@1000grad.de  ...         NaN
# 100-net                               contact@100p100.net  ...         NaN
# 100starlings                        info@100starlings.com  ...         NaN
# 10geeks-software-engineering             info@10geeks.com  ...         NaN
# ...                                                   ...  ...         ...
# zonova                                  contact@zonova.io  ...         NaN
# zoonect                                office@zoonect.com  ...         NaN
# zostera                                   info@zostera.nl  ...         NaN
# zoznam-mobile                        info@zoznammobile.sk  ...         NaN
# zuinq                         lanzamiento@zuinqstudio.com  ...         NaN
#
#                              Industry 32 Industry 33 Industry 34 Industry 35  \
# Identifier
# 01s-community-company                NaN         NaN         NaN         NaN
# 1000-digital                         NaN         NaN         NaN         NaN
# 100-net                              NaN         NaN         NaN         NaN
# 100starlings                         NaN         NaN         NaN         NaN
# 10geeks-software-engineering         NaN         NaN         NaN         NaN
# ...                                  ...         ...         ...         ...
# zonova                               NaN         NaN         NaN         NaN
# zoonect                              NaN         NaN         NaN         NaN
# zostera                              NaN         NaN         NaN         NaN
# zoznam-mobile                        NaN         NaN         NaN         NaN
# zuinq                                NaN         NaN         NaN         NaN
#
#                              Industry 36 Industry 37  \
# Identifier
# 01s-community-company                NaN         NaN
# 1000-digital                         NaN         NaN
# 100-net                              NaN         NaN
# 100starlings                         NaN         NaN
# 10geeks-software-engineering         NaN         NaN
# ...                                  ...         ...
# zonova                               NaN         NaN
# zoonect                              NaN         NaN
# zostera                              NaN         NaN
# zoznam-mobile                        NaN         NaN
# zuinq                                NaN         NaN
#
#                                                                          Link 1  \
# Identifier
# 01s-community-company                          https://www.facebook.com/01esse/
# 1000-digital                           https://www.facebook.com/1000graddigital
# 100-net                                 https://www.facebook.com/100pour100Net/
# 100starlings                  https://www.linkedin.com/company/100starlings-...
# 10geeks-software-engineering           https://www.linkedin.com/company/10geeks
# ...                                                                         ...
# zonova                                  https://www.facebook.com/ZetaOmegaNOVA/
# zoonect                                       https://www.facebook.com/zoonect/
# zostera                                     https://www.facebook.com/zostera.bv
# zoznam-mobile                                                               NaN
# zuinq                                      https://www.facebook.com/zuinqstudio
#
#                                                                          Link 2  \
# Identifier
# 01s-community-company         https://www.linkedin.com/company/01s-community...
# 1000-digital                      https://www.linkedin.com/company/1000digital/
# 100-net                               https://www.linkedin.com/company/100-net/
# 100starlings                  https://twitter.com/100Starlings?utm_source=hi...
# 10geeks-software-engineering                                                NaN
# ...                                                                         ...
# zonova                                 https://www.linkedin.com/company/zonova/
# zoonect                               https://www.linkedin.com/company/zoonect/
# zostera                               https://www.linkedin.com/company/zostera/
# zoznam-mobile                                                               NaN
# zuinq                            https://www.linkedin.com/company/zuinq-studio/
#
#                                                              link_3
# Identifier
# 01s-community-company                                           NaN
# 1000-digital                        https://twitter.com/1000digital
# 100-net                       https://www.twitter.com/100pour100net
# 100starlings                                                    NaN
# 10geeks-software-engineering                                    NaN
# ...                                                             ...
# zonova                                                          NaN
# zoonect                                 https://twitter.com/zoonect
# zostera                                 https://twitter.com/zostera
# zoznam-mobile                                                   NaN
# zuinq                               https://twitter.com/zuinqstudio
#
# [2792 rows x 67 columns]

# %% [markdown]
# #### Clean websites list

# %%
websites_list = crunch_data["Website"].tolist()

# %%
websites_list
# Out:
# ['www.01s.it/',
#  'www.1000grad.de',
#  'www.100pour100net.com//',
#  'www.100starlings.com/',
#  'www.10geeks.com',
#  'www.121digitalmedia.eu/',
#  '150sec.com/',
#  'wollow-soft.com',
#  '1minus1.com/',
#  'www.1t-s.com',
#  '21stwebb.co.uk',
#  '23g.io',
#  '247wms.com',
#  '2advance.ch',
#  'www.2develop.nl',
#  'www.2m-a2i.fr/',
#  'www.2open.it',
#  'www.2see.nl',
#  'www.2w.de',
#  '33communication.com',
#  'www.360d.be',
#  'www.360telemetry.com/',
#  'www.3asyr.com/',
#  'www.3d3.nl/',
#  'www.3d-dental.dk',
#  '3dit.de; https//govie.de',
#  '3ie.fr',
#  'www.3m5.de',
#  'www.3po.nl/',
#  'www.3tiersystems.com',
#  'www.3xw.ch',
#  'www.40bis.nl',
#  'www.4fx.co.uk/',
#  'www.4homepages.de',
#  '4kstudio.at',
#  '4tpm.fr',
#  '5w155.ch',
#  '69pixl.com/',
#  'www.7interactive.cz',
#  'www.80si.com',
#  'www.8balls.nl/',
#  'www.8trust.com/',
#  '8web.gr/',
#  'www.960labs.com/',
#  'www.999web.de',
#  'www.99codelines.com',
#  'a10sistemas.es',
#  'a2colores.es',
#  'www.aaltra.eu/',
#  'aardenexperts.com/',
#  'aardvark-creative.com',
#  'www.aardvark.gr',
#  'www.ab4d.com/',
#  'www.ab-data.de',
#  'abiatec.com/',
#  'www.abilis.de',
#  'www.abk.de',
#  'www.ablsoft.it/',
#  'abracadacook.com',
#  'www.abralytics.com/',
#  'www.absolute.ch',
#  'accesslab.gr/',
#  'www.accolm.com/',
#  'www.accsyn.com',
#  'www.aceit.cz/',
#  'www.acelo-digital.com',
#  'activesolutions.ro',
#  'www.activit.sk',
#  'www.actiworks.de/',
#  'acusu.com',
#  'www.adakom.de',
#  'www.adamapp.com/',
#  'adamfard.com',
#  'www.adamkey.com/',
#  'www.adbutveckling.se/',
#  'www.addink.net',
#  'a-digital.one',
#  'admincontrol.no',
#  'www.adroma.fr',
#  'www.aimproductions.be',
#  'advanced.team',
#  'www.advertage.com',
#  'www.adverteaser.com',
#  'aecordigital.com/',
#  'www.aeonx.ai/',
#  'www.aerian.com',
#  'aeroji.com',
#  'www.aersyn.com/',
#  'www.afronta.com',
#  'agence-webup.com/',
#  'agifly.be',
#  'agileapp.co/',
#  'www.agilepartners.eu',
#  'ag-prop.com/',
#  'www.agt-systemes.fr',
#  'ahrlich-boettcher.com/',
#  'www.aigis.ch',
#  'www.aimconsulting.it',
#  'gaderlamy.wixsite.com/aimi',
#  'ainte.com',
#  'www.aircury.com/',
#  'airtven.com/',
#  'www.ais.pl',
#  'www.aiteq.com/',
#  'www.aitia.ai',
#  nan,
#  'www.akawam.com',
#  'www.akerlund.com/',
#  'akimad.com',
#  'www.ak.software/',
#  'www.aldebaran.de',
#  'www.alecsandria.it',
#  'www.aleutos.com',
#  'floodping.org',
#  'alfa-safety.fr',
#  'alfaservice.it',
#  'algonauti.com',
#  'www.algoptis.fr/',
#  'www.algoreme.fr',
#  'www.algotech.solutions',
#  'aliquot.co.uk',
#  'www.alkalab.com',
#  'www.all-computer.cz/',
#  'www.allcryptowhitepapers.com',
#  'www.alleangeln.de/app',
#  'www.alliedassets.net',
#  'www.all-means.nl',
#  'www.allsoftware.fr/',
#  'allsop.software/',
#  'www.allthingscode.co.uk/',
#  'www.almathea.lu',
#  'www.novactive.com',
#  'almotech.co/',
#  'www.alohi.com',
#  'www.alo.it',
#  'www.alpaweb.com',
#  'www.alpha-innovations.de',
#  'www.alsacreations.fr',
#  'www.altropiano.com',
#  'amaclinics.com',
#  'www.amantech.se/',
#  'www.amazee.io/',
#  'www.ambay.com',
#  'www.ambitioncreative.co.uk',
#  'www.ambos.io/',
#  'www.amestosolutions.no/',
#  'www.am-impact.nl/',
#  'www.amnis.se',
#  'amnzero.nl',
#  'amoniac.eu/',
#  'amplitude.ch',
#  'www.activemindsolutions.co.uk/',
#  'amsterdamstandard.com/en',
#  'www.anakeen.com',
#  'www.angelmedia.de/',
#  'angria.net/',
#  'angrynerds.co/',
#  'www.anim-action.com/',
#  'animativ.pl',
#  'www.anitia.it',
#  'ankageo.com',
#  'anoigo.nl',
#  'www.anschluss80.de',
#  'antiersolutions.com/',
#  'www.antigone.fr',
#  'antosson.com',
#  'www.apdesign.de',
#  'www.apexsi.co.uk/',
#  'www.apitea.com',
#  'www.apivision.com/',
#  'appcn.mobi',
#  'appenture.com/',
#  'appfarm.io',
#  'appgreenhouse.io/',
#  'appgress.com/',
#  'apphaus.co.uk/',
#  'www.appinconf.com/',
#  'www.appizy.com',
#  'www.applify.co/',
#  'www.appmodule.net/',
#  'www.appointmentor.com',
#  'appolo.fr',
#  'appone.nl/',
#  'www.appox.se/',
#  'approach.se/',
#  'appsaloon.be',
#  'themorrow.digital/',
#  'www.appsherpas.com/',
#  'appsimplantadores.com',
#  'www.appsin.net',
#  'www.appsolutely.nl/',
#  'appsoluts.de/',
#  'www.appsonic.fr',
#  'appstor.io',
#  'apptitude.dk',
#  'apptiva.ch',
#  'www.apptree.no/',
#  'www.appyweb.es',
#  'www.apricot.com.pl',
#  'apro-software.com',
#  'www.apsynth.com/',
#  'www.aptaliko.gr',
#  'aptho.es',
#  'apus3.com/',
#  'www.a-c.fr',
#  'arboro.de',
#  'arca-computing.fr',
#  'www.arche-consulting.de/',
#  'www.archetech.fr/',
#  'arcsoftwareconsultancy.com',
#  'www.arctanedigital.co.uk/',
#  'www.ardourdigital.co.uk',
#  'www.argo.no',
#  'www.argonavis.it',
#  'www.armouragent.com/',
#  'www.computerspezl.de',
#  'www.aroban.com',
#  'www.artegis.com',
#  'artelogic.net',
#  'www.artflow.ro/',
#  'artlyticalmedia.com',
#  'www.arxio.de/',
#  'www.as4u.cz',
#  'www.ascami.ch',
#  'www.ascentiv.ch',
#  'asinpro.es',
#  'asipanet.com',
#  'www.askandy.co/',
#  'www.aspprofessionell.de',
#  'assanka.net',
#  'www.assetict.com',
#  'www.associativetrails.com/',
#  'www.aston.sk',
#  'www.astrolab-agency.com',
#  'atebe.ch',
#  'ateliom.fr',
#  'www.atinedis.it',
#  'www.atolye15.com',
#  'atomate.net/',
#  'www.atomised.coop',
#  'at-shopnet.com',
#  'www.atta-c.cz/en/',
#  'www.atticus7.co.uk',
#  'www.attopartners.com/',
#  'attrack.com/',
#  'www.atworklogin.com',
#  'www.audacia.co.uk',
#  'audaciouschurch.com',
#  'www.audaxis.com',
#  'www.augustareeves.fr',
#  'www.auronet.de',
#  'www.autentek.de/',
#  'autojerry.fi',
#  'www.auxilis.de',
#  'www.auxilium.nl/',
#  'avocet.io',
#  'www.avvivy.com',
#  'www.codearcs.io/',
#  'www.aware.be',
#  'awstudio.fr',
#  'axami.se/',
#  'www.axandra.com/',
#  'axbit.com/',
#  'www.axe-image.com',
#  'axerios.ch',
#  'axiomq.com',
#  'www.azul-multimedia.com/',
#  'buetler.biz',
#  'www.bakalari.cz',
#  'backhub.co/',
#  'backreward.eu',
#  'backslash.build/',
#  'www.bagaar.be',
#  'www.bait.no',
#  'www.baiya.io',
#  'www.madebybananas.nl/',
#  'www.banilla.co.uk/',
#  'www.barium.se',
#  'www.baselab.nl/',
#  'www.baseplate.io',
#  'www.softbas.com',
#  'www.ancyradesktop.com',
#  'www.baypmtech.com',
#  'www.bcnbit.com',
#  'www.beaconfy.com',
#  'beat.no/',
#  'www.becommitted.nl/',
#  'www.bwcom.co.uk',
#  'www.bee-ware.net',
#  'www.bekodesign.com',
#  'www.belugalinguistics.com',
#  'www.beo.de',
#  'www.bequalified.de',
#  'www.beracingapp.com',
#  'www.besized.com',
#  'www.beingsmart.it/',
#  'www.bestmanapp.com',
#  'www.beware.fr',
#  'bewizyu.com',
#  'www.bgosoftware.com/',
#  'www.bgssoft.com',
#  'www.bh-webentwicklung.de/',
#  'biffbangpow.com/',
#  'www.bilpp.com',
#  'www.binaryone.ch/tellweb/',
#  'www.binarysoul.net',
#  'bint.es/',
#  'www.bippesbrandao.de/',
#  'www.bitagency.com',
#  'www.bitbee.ch',
#  'www.bitbull.it/',
#  'www.bitco.ch',
#  'www.bitfactory.io',
#  'www.bitfang.de',
#  'bitgune.com',
#  'bitlabstudio.com',
#  'www.bitskin.de/',
#  'www.bitstone.eu',
#  'bizpora.com',
#  'bizzerd.com',
#  'blackcrystal.net/',
#  'blackdata.systems',
#  'blackfire.io',
#  'blanko.de',
#  'blastoffagy.com',
#  'www.bleu122.com',
#  'bling.sh/',
#  'www.blip.pt/',
#  'blisdigital.com/',
#  'www.bluechip.ro',
#  'bluecookie.co.uk/',
#  'bluefly.digital/',
#  'blueocto.co.uk',
#  'blueradical.ro/',
#  'bluerock.ie/',
#  'www.bluesystem.ch',
#  'bndbco.com/en',
#  'www.bnet-kg.de',
#  'bnspro.gr/en',
#  'boldcompass.com',
#  'bolden.nl',
#  'www.photonengine.com/bolt',
#  'www.bonsaimedia.nl//',
#  'www.bookkeepy.co.uk/',
#  'boosttypers.com/',
#  'www.boozttechnologybaltics.com',
#  'www.boringowl.io',
#  'www.bososoft.nl/',
#  'boulder-design.co.uk',
#  'www.boxharry.com/',
#  'box-in-a-box.com',
#  'www.boxtribute.org',
#  'www.braincomputing.com',
#  'www.braindistrict.de',
#  'brainhub.eu',
#  'www.brainsum.com',
#  'www.brancom.nl',
#  'www.brandcrew.de',
#  'www.brandperfection.de',
#  'bratia.sk',
#  'www.brenet.de',
#  'www.brentjensgeoict.nl/',
#  'brickson.nl/',
#  'www.bridgit.gr',
#  'www.brightanswers.eu/nl/contact/',
#  'www.brightsolutions.de/',
#  'www.brik.digital',
#  'brixion.com',
#  'www.brokercloud.app',
#  'broscorp.net/',
#  'www.brozr.com/',
#  'www.bouley-web.ch',
#  'www.bs-systeme.de/',
#  'www.werbeagentur.ms',
#  'www.bsystem.ch',
#  'www.bttsd.ro',
#  'bubblefish.agency',
#  'bubblefish.es',
#  'budacode.com/',
#  'buglog.com',
#  'bugloos.nl',
#  'www.burningflame.it',
#  'www.burodeng.nl',
#  'bandgkft.hu',
#  'www.bussol.com',
#  'hr-assistant.it',
#  'www.buyoda.ch',
#  'byrds.ch/',
#  'www.byrelations.com',
#  'bytemindz.com',
#  'www.byyoursite.nl',
#  'caboodle.studio/',
#  'www.cabag.ch',
#  'cafedigital.ru',
#  'www.caffeinatedcode.co/',
#  'cafffeine.com',
#  'www.cairowebdesign.com',
#  'calculate.plus',
#  'calcupal.be',
#  'www.calder.sk',
#  nan,
#  'www.callcentrix.net/nosotros/Default.aspx',
#  'www.callipigia.com',
#  'www.callis.dk',
#  'call-up.ch',
#  'cankod.com',
#  'cap-hr.fr',
#  'capica.nl',
#  'www.capvision.fr',
#  'www.carabincreatives.com',
#  'www.caramaps.com/',
#  'caramel.la',
#  'carbonteq.com/',
#  'careerradar.org',
#  'www.cargomedia.ch/',
#  'www.cariboodigital.com/',
#  'www.carlobi.se/',
#  'www.sohler.ch',
#  'www.carrement-net.fr',
#  'www.cartab.com/',
#  'cartlyapp.com',
#  'casalsonline.es/',
#  'casisoft.de/',
#  'castor-web-design.com',
#  'www.catchbull.com',
#  'www.cazemo.com',
#  'www.cartodecision.fr',
#  'www.clubdelrisparmio.com',
#  'www.cebelian.com',
#  'www.cefalo.com/',
#  'celadonsoft.com/',
#  'www.cephastech.com',
#  'www.cerebral-partner.com/home.html',
#  'www.cerqlar.com',
#  'certaince.com',
#  'cesbit.com',
#  'chakia.co.uk/',
#  'changingdigital.com',
#  'charlin.be',
#  'www.chartblocks.com',
#  'checkiteasy.com/',
#  'www.checksub.com/',
#  'www.chef-ready.com',
#  'chetaru.com',
#  'www.chili.ch/',
#  'www.sites-chirdent.net',
#  'www.chittak.co.uk',
#  'choicely.com',
#  'www.chubut.it/',
#  'www.chunk.co.uk/',
#  'ciit.at',
#  'www.cis-websolutions.nl',
#  'citio.digital',
#  'citronium.com/',
#  'www.civicuk.com/',
#  'www.ckc-net.com',
#  'clapped.im',
#  'www.classycode.com/en/',
#  'cleandesk.no',
#  'www.clearmedia.ch',
#  'clearvoyage.com',
#  'clevermedia.gr/web',
#  'www.clevernet.pt',
#  'www.click4aweb.com',
#  'www.clickanet.fr',
#  'www.clickbizz.nl',
#  'www.clickon.ch',
#  'www.clicon.de/',
#  'cliqtags.com',
#  'cliventa.com/',
#  'www.clonestudios.co.uk',
#  'www.cloudex.se/',
#  'www.cloudmotion.nl/',
#  'www.cloudwall.tk',
#  'www.cmcitymedia.de',
#  'www.cmslabs.it/',
#  'www.bigbase.nl',
#  'cockpit-sante.fr/',
#  'www.codeagency.pl',
#  'www.codebase.it/',
#  'www.codedj.co.uk/',
#  'codedlines.com/',
#  'www.codefrontiers.com/',
#  'codefusion.pl',
#  'www.codefysoftware.com/',
#  'codemask.com',
#  'codein.software/',
#  'www.codelta.be',
#  'codenest.co/',
#  'codenorm.de',
#  'codeplicity.com',
#  'codepotato.co.uk/',
#  'coderelations.com',
#  'www.code-source.ch',
#  'code-troopers.com',
#  'www.codevanilla.com',
#  'www.codevate.com/',
#  'codingo.me',
#  'www.codora.io/',
#  'www.coeus-solutions.de',
#  'coggle.it',
#  'www.cogitoweb.it',
#  'www.cognifide.com/',
#  'cogniteq.com',
#  'cognitic.be',
#  'www.cohoda.com',
#  'co-hr.com',
#  'www.columba.de',
#  'www.columbus-interactive.de',
#  'combidesk.com',
#  'comiteg.it/',
#  'www.commerceworks.net/',
#  'www.comodolab.it',
#  'www.deinestudienfinanzierung.de/de',
#  'comparegamehosting.com',
#  'www.compass-com.eu/',
#  'www.compubel.be/',
#  'www.eu.rsystems.com',
#  'comhost.eu',
#  'www.concept-computer.de',
#  'www.concepto.ch',
#  'cncrrnt.com',
#  'condacore.com',
#  'condegram.com',
#  'conferience.com/',
#  'www.connecta.ag',
#  'connect.auto/',
#  'www.connectedsoftec.com/',
#  'studioconnecte.com',
#  'www.connectlime.com/',
#  'connexionsw.com/',
#  'www.connexis.de',
#  'www.conpeak.de',
#  'www.conscribo.nl/',
#  'console9.com',
#  'www.consolidati.it',
#  'constructsys.com',
#  'contactcircuit.com/',
#  'contester.net',
#  'www.contextminds.com',
#  'www.cca.io',
#  'www.controlspace.co',
#  'www.converxys.de',
#  'www.cookieshq.co.uk',
#  'www.coolgrey.de',
#  'www.coolsis.pt',
#  'www.coral.lt/',
#  'www.corecube.it/',
#  'www.coreluso.pt',
#  'coremaker.io',
#  'coreui.io',
#  'www.corobori.com/',
#  'www.cortex-media.de',
#  'www.corussoft.de',
#  'www.cotunity.com',
#  'www.coveronweb.com/',
#  'www.cracoutech.com',
#  'crafton.pl/',
#  'craftturf.com',
#  'crafture.com/',
#  'www.crazyrobot.be',
#  'www.cre8newmedia.com',
#  'www.cre8websolutions.be/',
#  'www.creacoon.nl',
#  'www.creagh.com',
#  'www.creamive.com',
#  'create.nl/',
#  'www.createit.com',
#  'www.createlli.com',
#  'www.creativeorange.nl/',
#  'creativetheory.co.uk/',
#  'www.creawe-services.com',
#  'www.crediteo.co',
#  'crewnew.com',
#  'crewontour.com',
#  'web.cright.com/',
#  'www.crispy-it.de',
#  'www.critec.pt',
#  'www.crm-infosys.de/',
#  'www.crobasoft.com',
#  'crocoders.io',
#  'crolox.nl',
#  'crustlab.com',
#  'www.cs2.ch',
#  'cstar.io/',
#  'www.cubeapps.co',
#  'www.cubefour.de',
#  'www.cubicacomunicacion.com',
#  'www.cubicagency.com',
#  'www.cubicast.com/',
#  'www.cubicstate.com/',
#  'cudev.com/',
#  'www.cuppedia.de/',
#  'www.curabase.com',
#  'driftime.media',
#  'www.curvejump.se/',
#  'www.curvosoft.com',
#  'www.dabac.com',
#  'thedailymetrics.com/',
#  'www.damidev.com',
#  'www.danburykline.co.uk/DK/',
#  'www.sposea.com',
#  'www.databridge.it',
#  'www.datamaze.io/',
#  'datamix.io',
#  'www.datamola.com/',
#  'www.datanomic.com',
#  'data-observer.com',
#  'datap.io/',
#  nan,
#  'www.datawin.de',
#  'www.broadbandmetrics.com',
#  'datenfreunde.com/',
#  'www.datix.de',
#  'www.datlink.cz',
#  'www.datocms.com/',
#  'www.davinchi.es/',
#  'www.daxx.com/company',
#  'www.daybyday.de',
#  'dayprosoft.es',
#  'www.dazzle.be',
#  'www.debussac.net/',
#  'dbnetlink.net',
#  'www.dcc.ruhr',
#  'www.mydcs.gr/',
#  'www.dcsoftware.pt',
#  'www.debondt.de',
#  'www.debugged.be',
#  'debugme.eu/',
#  'decigio.com',
#  'dij.digital',
#  'www.deemaze.com',
#  nan,
#  'deepvision.cz',
#  'defonic.com',
#  'www.internetcompagnie.nl/',
#  'www.delta-ai.com',
#  'cds.com.ua',
#  'denforex.com',
#  'deonlinefabriek.nl',
#  'www.depositado.com',
#  'www.depotnet.co.uk/',
#  'www.deprocrastination.co',
#  'dermosafe.com/en',
#  'www.ders.cz',
#  'www.dersa-it.de',
#  'designenmedia.nl/',
#  'www.desoft.de/',
#  'www.despotsoft.dk',
#  'www.desuvit.com',
#  'www.detectify.com',
#  'dev2code.pl',
#  'devana.rs/',
#  'devanddeliver.com',
#  'www.devault.ch',
#  'it.devbu.com',
#  'www.devconsultberlin.de/',
#  'www.devdivision.net/',
#  'devedis.ch/',
#  'www.bmgroup.be',
#  'www.deversity.com',
#  'www.devision.com',
#  'www.devlogiq.com/',
#  'devmy.it',
#  'www.devolution.be',
#  'devoorkant.nl/',
#  'www.devpark.pl',
#  'www.devpod.dk',
#  'www.devrry.com',
#  'devy.io',
#  'dgtl.productions',
#  'dharmafly.com',
#  'www.dianti.fi',
#  'www.dibloc.com/home',
#  'andere-it-beratung.de/',
#  'www.schnittsteller.de/',
#  'dige.rs',
#  'www.diggsweep.com',
#  'digiants.agency',
#  'digisin.it',
#  'www.signals.co.uk/',
#  'www.digital-craftsman.de',
#  'digitaldragonsglobal.com',
#  'www.digitalestate.tech',
#  'www.thedigitalists.net',
#  'www.digitalmachine.it',
#  'www.DigitalOriented.co.uk',
#  'www.digitalreti.com',
#  'www.digitaltalents.be',
#  'www.digitalworkroom.co.uk/',
#  'www.digiteum.com',
#  'www.digititaly.net',
#  'digitools.io',
#  'www.digitsign.net/',
#  'diglabstudio.com',
#  'www.dil-93.hr',
#  'www.dimnida.com',
#  'www.directsitters.co.uk',
#  'discoverdigitals.com',
#  'dis.cuss.it',
#  'www.distemicha.com',
#  'ditho.berlin',
#  'diwa.ch/',
#  'www.diya.pro',
#  'www.dnateam.io',
#  'dnavi.pl/',
#  'dobster.pl',
#  'docaret.com/en',
#  'www.docospot.dk',
#  'www.doc-safe.co.uk',
#  'ged.dgroove.it',
#  'www.dokflyt.no/',
#  'www.domainster.com/U14F-PnK-e/domaininfo',
#  'www.donation-tracker.de/',
#  'dontpanicdesign.co.uk/',
#  'www.doppioweb.it/',
#  'www.dotcomwa.it',
#  'dotinum.com/',
#  'www.dotmedia.it',
#  'www.dotnest.com',
#  'dotnext.it',
#  'www.dotoso.de',
#  'dotways.fr',
#  'doublebit.net',
#  'www.doxinet.it',
#  'www.dps.cz',
#  'drap.hr/',
#  'www.dreamonkey.com/en/home/',
#  'www.dreamslab.it',
#  'www.dreamsolution.nl',
#  'dreipol.ch/',
#  'www.drherwig.de',
#  'driven.design/',
#  'www.dsc.net/',
#  'www.dse.se/',
#  'www.dsesoftware.nl',
#  'www.dtad.com/de',
#  'dubbelepunt.nl',
#  'www.duepuntotre.it',
#  'www.dukehoff.com',
#  'dunked.com',
#  'www.dutchgamestudio.com',
#  'www.wearedwm.com/',
#  'www.dx-solutions.be',
#  'dynabase.de',
#  'www.dynagroup.de',
#  'dynamit.nl',
#  'dynweb.cz/',
#  'www.e621.ch',
#  'www.eagna.io',
#  'www.ealys.com',
#  'earth2.io',
#  'www.eastpoint.co.uk/',
#  'eastsideco.com',
#  'www.easyfeedback.com/',
#  'www.easyleaving.com',
#  'www.easy-net.dk',
#  'www.easysolution.be',
#  'www.ebalance.ch/',
#  'ecerium.com/',
#  'jamworks.com',
#  'www.echogon.de',
#  'www.echolibre.com',
#  'echoua.com',
#  'ecologital.com',
#  'www.ecomsoft.fr',
#  'www.e-confirm.de',
#  'www.eco-soft.ch/',
#  'www.e-dea.ro/',
#  'www.edgeimpact.co.uk/',
#  'www.edgeware.tv',
#  'edicomedia.com/',
#  'www.edsi-tech.com/en/',
#  'www.edulib.com',
#  'eduspot.co.uk',
#  'eeku.fi',
#  'www.eemlandinternet.nl/',
#  'efabriek.nl/',
#  'www.effekt-etage.de',
#  'www.efigence.com',
#  'egebit.com.tr',
#  'www.egotec.com',
#  'www.eisod.com',
#  'www.ejidosoft.es',
#  'ekara.ip-label.com',
#  nan,
#  'www.ekoha.co/',
#  'elasticwings.com/',
#  'www.elatro.nl/',
#  'elearniz.fr',
#  'elemento115.es',
#  'www.eleven.nl',
#  'www.elfo.net',
#  'eli5.io',
#  'elikosoft.com.mk',
#  'elix.sr',
#  'elligense.com/',
#  'www.elvisolutions.com',
#  nan,
#  'emergeitsupport.pl/en/homepage',
#  'emico.nl',
#  'www.eminus-software.com',
#  'www.emsation.se/',
#  'www.enantena.net',
#  'www.endprizesolutions.com',
#  nan,
#  'www.enfacade.com',
#  'enflow.nl',
#  'www.enhance.ie/',
#  'www.enigmasoft.ltd.uk/',
#  'enrysisland.com',
#  'www.enyosolutions.com/en',
#  'www.eobs.fr',
#  'www.epionet.com/',
#  'www.epocaricerca.it',
#  'www.gefahrstoff.com',
#  'www.eprisma.it',
#  'www.epublic.it',
#  'www.eratio.it',
#  'www.erelia.fr',
#  'erpcontact.ro/',
#  'www.esb-net.de',
#  'esconsulting.it',
#  'www.escriptum.de',
#  'www.escsoftware.it',
#  'www.grupoesentia.com',
#  'www.esi-groupe.com',
#  'www.esokia.com/en',
#  'www.essentiadesign.be',
#  'www.esyst.nl/',
#  'www.eszconsulting.com',
#  'www.etabetaconsulting.net',
#  'www.e-tailors.com',
#  'www.etelenima.com',
#  'www.etgigrup.com',
#  'etiqa.it/',
#  'www.etiskapp.com',
#  'www.etrend.hu',
#  'eunity-service.de',
#  'www.euraconsult.ch',
#  'eurocoders.com',
#  'eurohispana.es/',
#  'www.euromediaitalia.com',
#  'www.europanda.ro',
#  'www.europublic.de/',
#  'www.evantra.de/',
#  'www.everchurch.com',
#  'evergreencomputing.com/',
#  'everlabs.com/',
#  'evermade.fi/en/',
#  'weareevermore.com',
#  'everse.ro/',
#  'www.evialog.com',
#  'www.evimedia.nl/index.html',
#  'www.evin.it',
#  'www.evomatic.it',
#  'evonove.it/',
#  'www.evosec.de',
#  'cms-ew-2020.ew-labor.de',
#  'www.ex4e.co.uk',
#  'exaitec.com',
#  'www.excel-help.eu',
#  'www.exigeapp.com/',
#  'exit25.it',
#  'www.exodussa.gr',
#  'www.exsportance.de/',
#  'www.extellient.com',
#  'www.extrea.nl/',
#  'www.exxtra.nl/',
#  'eyloo.com',
#  'www.fabres.pl',
#  'fabricaludens.it',
#  'facet-novium.nl',
#  'www.fahrenheit.ch',
#  'www.fannabee.com',
#  'www.faqtory.nl/',
#  'www.faromedia.be',
#  'www.fastest.cz/',
#  'www.fastfocus.be/',
#  'favo.no',
#  'www.fax.plus',
#  'www.fbd.be',
#  'www.fecher.de/',
#  'www.feedzon.com',
#  'www.fenetre.nl/',
#  'www.fernhall.co.uk',
#  'www.ferryheijnen.nl',
#  'fingersfingers.co.uk',
#  'fiberjungle.com/',
#  'fiduro.net',
#  'fill.ly',
#  'www.filmamo.it',
#  'financekey.com/',
#  'www.findrugbynow.com',
#  'www.finite-soft.com/',
#  'www.finkoslo.no/',
#  'www.finsoft.it',
#  'www.firefleye.be',
#  'fivedottwelve.com',
#  '5ly.co',
#  'www.fjordsoftware.eu',
#  'flatsoft.com',
#  'www.fleetback.com',
#  'www.flexio.fr',
#  'flexiweb.co',
#  'www.flightmate.ie/',
#  'www.florida-digital.de/',
#  'www.flux2fusion.com/',
#  'www.flyacts.com',
#  'www.flying-cat.de',
#  'www.foe-services.de/',
#  'foiz.io',
#  'foliovision.com',
#  'www.foodnotify.com/',
#  'forcklabs.com',
#  'www.foreach.be/',
#  'forecastads.com/',
#  'foreto.com',
#  'forkflow.io',
#  'www.fork.de/',
#  'form2chat.io',
#  'formatics.nl',
#  'www.formulewww.nl',
#  'www.forthbusiness.com/',
#  'fotka.com',
#  'www.fotojet.com/',
#  'www.fourdigits.nl/',
#  'www.fourmeta.com',
#  'www.fps.hu/',
#  'www.fraktal.co',
#  'www.freeformcreative.co.uk/',
#  'freetimefor.biz',
#  'freshapps.nl',
#  'freshcodeit.com/',
#  'www.fresh-internet.net/',
#  'freshpigment.com',
#  'www.freshtag.nl',
#  'www.freyhauer.de/',
#  'friends-of-it.de',
#  'friendstudios.no',
#  'www.frind.it',
#  'www.hypehype.com/',
#  'frogspark.co.uk/',
#  'fromidea.fi',
#  'frontosaur.com',
#  'ftprod.fr',
#  'www.fulcri.it',
#  'fullwebservice.nl/',
#  'www.fusionglobalcapital.com',
#  'www.futurace.com',
#  'gulenayva.com',
#  'g1g.nl/index.html',
#  'web.ga-insights.com',
#  'gajelabs.com',
#  'galadrim.fr/',
#  'gallimedia.com',
#  'token.gamee.com',
#  'www.gammadia.ch',
#  'gangverk.is',
#  'info.gapless.app/',
#  'www.garbott.co.uk',
#  'www.zaprojektuj-ogrod.pl/en/Home',
#  'www.garlandsoftworx.com',
#  'www.gastrosoft.ch',
#  'www.gate49.com',
#  'www.gawlitta.com',
#  'geeksters.co',
#  'gelal.com/',
#  'gematica.com',
#  'www.gemmedia.co.uk/',
#  'www.generic.se/',
#  'gentlereader.com/',
#  'www.genux.com/it',
#  'geocento.com/',
#  'www.geogarage.com',
#  'www.geographics.eu/',
#  'www.gereedschapbeheer.nl/',
#  'www.gerere.com/',
#  'gestionmedica.com',
#  'gewoon-peter.nl/webstudio.php',
#  'www.gfactory.nl',
#  'www.ggate.it/',
#  'www.ghmgesthotel.com',
#  'www.ghost.ch',
#  'www.gillz.nl',
#  'ginilab.com',
#  'www.gino.nl',
#  'giraffestudio.pl/',
#  'giscloud.hr/',
#  'www.gis-art.com',
#  'www.gis-consult.de',
#  'gis-plan.swiss',
#  'gitlabhost.com',
#  'givingtales.com/',
#  'www.givtapp.net/',
#  'www.firmware.be',
#  'glide.design',
#  'www.gfds-inc.com/',
#  'www.globalis-ms.com',
#  'www.globule.net',
#  ...]

# %%
# remove / from the end of the string that contains the website
# websites_list = [website.rstrip(website[-1]) if (website[-1] == "/") else website for website in websites_list]
websites_list = [website.rstrip(website[-1]) if (isinstance(website, str) and website[-1] == "/") else website for website in websites_list]
websites_list = [website.rstrip(website[-1]) if (isinstance(website, str) and website[-1] == "/") else website for website in websites_list]

# %%
(websites_list)
# Out:
# ['www.01s.it',
#  'www.1000grad.de',
#  'www.100pour100net.com',
#  'www.100starlings.com',
#  'www.10geeks.com',
#  'www.121digitalmedia.eu',
#  '150sec.com',
#  'wollow-soft.com',
#  '1minus1.com',
#  'www.1t-s.com',
#  '21stwebb.co.uk',
#  '23g.io',
#  '247wms.com',
#  '2advance.ch',
#  'www.2develop.nl',
#  'www.2m-a2i.fr',
#  'www.2open.it',
#  'www.2see.nl',
#  'www.2w.de',
#  '33communication.com',
#  'www.360d.be',
#  'www.360telemetry.com',
#  'www.3asyr.com',
#  'www.3d3.nl',
#  'www.3d-dental.dk',
#  '3dit.de; https//govie.de',
#  '3ie.fr',
#  'www.3m5.de',
#  'www.3po.nl',
#  'www.3tiersystems.com',
#  'www.3xw.ch',
#  'www.40bis.nl',
#  'www.4fx.co.uk',
#  'www.4homepages.de',
#  '4kstudio.at',
#  '4tpm.fr',
#  '5w155.ch',
#  '69pixl.com',
#  'www.7interactive.cz',
#  'www.80si.com',
#  'www.8balls.nl',
#  'www.8trust.com',
#  '8web.gr',
#  'www.960labs.com',
#  'www.999web.de',
#  'www.99codelines.com',
#  'a10sistemas.es',
#  'a2colores.es',
#  'www.aaltra.eu',
#  'aardenexperts.com',
#  'aardvark-creative.com',
#  'www.aardvark.gr',
#  'www.ab4d.com',
#  'www.ab-data.de',
#  'abiatec.com',
#  'www.abilis.de',
#  'www.abk.de',
#  'www.ablsoft.it',
#  'abracadacook.com',
#  'www.abralytics.com',
#  'www.absolute.ch',
#  'accesslab.gr',
#  'www.accolm.com',
#  'www.accsyn.com',
#  'www.aceit.cz',
#  'www.acelo-digital.com',
#  'activesolutions.ro',
#  'www.activit.sk',
#  'www.actiworks.de',
#  'acusu.com',
#  'www.adakom.de',
#  'www.adamapp.com',
#  'adamfard.com',
#  'www.adamkey.com',
#  'www.adbutveckling.se',
#  'www.addink.net',
#  'a-digital.one',
#  'admincontrol.no',
#  'www.adroma.fr',
#  'www.aimproductions.be',
#  'advanced.team',
#  'www.advertage.com',
#  'www.adverteaser.com',
#  'aecordigital.com',
#  'www.aeonx.ai',
#  'www.aerian.com',
#  'aeroji.com',
#  'www.aersyn.com',
#  'www.afronta.com',
#  'agence-webup.com',
#  'agifly.be',
#  'agileapp.co',
#  'www.agilepartners.eu',
#  'ag-prop.com',
#  'www.agt-systemes.fr',
#  'ahrlich-boettcher.com',
#  'www.aigis.ch',
#  'www.aimconsulting.it',
#  'gaderlamy.wixsite.com/aimi',
#  'ainte.com',
#  'www.aircury.com',
#  'airtven.com',
#  'www.ais.pl',
#  'www.aiteq.com',
#  'www.aitia.ai',
#  nan,
#  'www.akawam.com',
#  'www.akerlund.com',
#  'akimad.com',
#  'www.ak.software',
#  'www.aldebaran.de',
#  'www.alecsandria.it',
#  'www.aleutos.com',
#  'floodping.org',
#  'alfa-safety.fr',
#  'alfaservice.it',
#  'algonauti.com',
#  'www.algoptis.fr',
#  'www.algoreme.fr',
#  'www.algotech.solutions',
#  'aliquot.co.uk',
#  'www.alkalab.com',
#  'www.all-computer.cz',
#  'www.allcryptowhitepapers.com',
#  'www.alleangeln.de/app',
#  'www.alliedassets.net',
#  'www.all-means.nl',
#  'www.allsoftware.fr',
#  'allsop.software',
#  'www.allthingscode.co.uk',
#  'www.almathea.lu',
#  'www.novactive.com',
#  'almotech.co',
#  'www.alohi.com',
#  'www.alo.it',
#  'www.alpaweb.com',
#  'www.alpha-innovations.de',
#  'www.alsacreations.fr',
#  'www.altropiano.com',
#  'amaclinics.com',
#  'www.amantech.se',
#  'www.amazee.io',
#  'www.ambay.com',
#  'www.ambitioncreative.co.uk',
#  'www.ambos.io',
#  'www.amestosolutions.no',
#  'www.am-impact.nl',
#  'www.amnis.se',
#  'amnzero.nl',
#  'amoniac.eu',
#  'amplitude.ch',
#  'www.activemindsolutions.co.uk',
#  'amsterdamstandard.com/en',
#  'www.anakeen.com',
#  'www.angelmedia.de',
#  'angria.net',
#  'angrynerds.co',
#  'www.anim-action.com',
#  'animativ.pl',
#  'www.anitia.it',
#  'ankageo.com',
#  'anoigo.nl',
#  'www.anschluss80.de',
#  'antiersolutions.com',
#  'www.antigone.fr',
#  'antosson.com',
#  'www.apdesign.de',
#  'www.apexsi.co.uk',
#  'www.apitea.com',
#  'www.apivision.com',
#  'appcn.mobi',
#  'appenture.com',
#  'appfarm.io',
#  'appgreenhouse.io',
#  'appgress.com',
#  'apphaus.co.uk',
#  'www.appinconf.com',
#  'www.appizy.com',
#  'www.applify.co',
#  'www.appmodule.net',
#  'www.appointmentor.com',
#  'appolo.fr',
#  'appone.nl',
#  'www.appox.se',
#  'approach.se',
#  'appsaloon.be',
#  'themorrow.digital',
#  'www.appsherpas.com',
#  'appsimplantadores.com',
#  'www.appsin.net',
#  'www.appsolutely.nl',
#  'appsoluts.de',
#  'www.appsonic.fr',
#  'appstor.io',
#  'apptitude.dk',
#  'apptiva.ch',
#  'www.apptree.no',
#  'www.appyweb.es',
#  'www.apricot.com.pl',
#  'apro-software.com',
#  'www.apsynth.com',
#  'www.aptaliko.gr',
#  'aptho.es',
#  'apus3.com',
#  'www.a-c.fr',
#  'arboro.de',
#  'arca-computing.fr',
#  'www.arche-consulting.de',
#  'www.archetech.fr',
#  'arcsoftwareconsultancy.com',
#  'www.arctanedigital.co.uk',
#  'www.ardourdigital.co.uk',
#  'www.argo.no',
#  'www.argonavis.it',
#  'www.armouragent.com',
#  'www.computerspezl.de',
#  'www.aroban.com',
#  'www.artegis.com',
#  'artelogic.net',
#  'www.artflow.ro',
#  'artlyticalmedia.com',
#  'www.arxio.de',
#  'www.as4u.cz',
#  'www.ascami.ch',
#  'www.ascentiv.ch',
#  'asinpro.es',
#  'asipanet.com',
#  'www.askandy.co',
#  'www.aspprofessionell.de',
#  'assanka.net',
#  'www.assetict.com',
#  'www.associativetrails.com',
#  'www.aston.sk',
#  'www.astrolab-agency.com',
#  'atebe.ch',
#  'ateliom.fr',
#  'www.atinedis.it',
#  'www.atolye15.com',
#  'atomate.net',
#  'www.atomised.coop',
#  'at-shopnet.com',
#  'www.atta-c.cz/en',
#  'www.atticus7.co.uk',
#  'www.attopartners.com',
#  'attrack.com',
#  'www.atworklogin.com',
#  'www.audacia.co.uk',
#  'audaciouschurch.com',
#  'www.audaxis.com',
#  'www.augustareeves.fr',
#  'www.auronet.de',
#  'www.autentek.de',
#  'autojerry.fi',
#  'www.auxilis.de',
#  'www.auxilium.nl',
#  'avocet.io',
#  'www.avvivy.com',
#  'www.codearcs.io',
#  'www.aware.be',
#  'awstudio.fr',
#  'axami.se',
#  'www.axandra.com',
#  'axbit.com',
#  'www.axe-image.com',
#  'axerios.ch',
#  'axiomq.com',
#  'www.azul-multimedia.com',
#  'buetler.biz',
#  'www.bakalari.cz',
#  'backhub.co',
#  'backreward.eu',
#  'backslash.build',
#  'www.bagaar.be',
#  'www.bait.no',
#  'www.baiya.io',
#  'www.madebybananas.nl',
#  'www.banilla.co.uk',
#  'www.barium.se',
#  'www.baselab.nl',
#  'www.baseplate.io',
#  'www.softbas.com',
#  'www.ancyradesktop.com',
#  'www.baypmtech.com',
#  'www.bcnbit.com',
#  'www.beaconfy.com',
#  'beat.no',
#  'www.becommitted.nl',
#  'www.bwcom.co.uk',
#  'www.bee-ware.net',
#  'www.bekodesign.com',
#  'www.belugalinguistics.com',
#  'www.beo.de',
#  'www.bequalified.de',
#  'www.beracingapp.com',
#  'www.besized.com',
#  'www.beingsmart.it',
#  'www.bestmanapp.com',
#  'www.beware.fr',
#  'bewizyu.com',
#  'www.bgosoftware.com',
#  'www.bgssoft.com',
#  'www.bh-webentwicklung.de',
#  'biffbangpow.com',
#  'www.bilpp.com',
#  'www.binaryone.ch/tellweb',
#  'www.binarysoul.net',
#  'bint.es',
#  'www.bippesbrandao.de',
#  'www.bitagency.com',
#  'www.bitbee.ch',
#  'www.bitbull.it',
#  'www.bitco.ch',
#  'www.bitfactory.io',
#  'www.bitfang.de',
#  'bitgune.com',
#  'bitlabstudio.com',
#  'www.bitskin.de',
#  'www.bitstone.eu',
#  'bizpora.com',
#  'bizzerd.com',
#  'blackcrystal.net',
#  'blackdata.systems',
#  'blackfire.io',
#  'blanko.de',
#  'blastoffagy.com',
#  'www.bleu122.com',
#  'bling.sh',
#  'www.blip.pt',
#  'blisdigital.com',
#  'www.bluechip.ro',
#  'bluecookie.co.uk',
#  'bluefly.digital',
#  'blueocto.co.uk',
#  'blueradical.ro',
#  'bluerock.ie',
#  'www.bluesystem.ch',
#  'bndbco.com/en',
#  'www.bnet-kg.de',
#  'bnspro.gr/en',
#  'boldcompass.com',
#  'bolden.nl',
#  'www.photonengine.com/bolt',
#  'www.bonsaimedia.nl',
#  'www.bookkeepy.co.uk',
#  'boosttypers.com',
#  'www.boozttechnologybaltics.com',
#  'www.boringowl.io',
#  'www.bososoft.nl',
#  'boulder-design.co.uk',
#  'www.boxharry.com',
#  'box-in-a-box.com',
#  'www.boxtribute.org',
#  'www.braincomputing.com',
#  'www.braindistrict.de',
#  'brainhub.eu',
#  'www.brainsum.com',
#  'www.brancom.nl',
#  'www.brandcrew.de',
#  'www.brandperfection.de',
#  'bratia.sk',
#  'www.brenet.de',
#  'www.brentjensgeoict.nl',
#  'brickson.nl',
#  'www.bridgit.gr',
#  'www.brightanswers.eu/nl/contact',
#  'www.brightsolutions.de',
#  'www.brik.digital',
#  'brixion.com',
#  'www.brokercloud.app',
#  'broscorp.net',
#  'www.brozr.com',
#  'www.bouley-web.ch',
#  'www.bs-systeme.de',
#  'www.werbeagentur.ms',
#  'www.bsystem.ch',
#  'www.bttsd.ro',
#  'bubblefish.agency',
#  'bubblefish.es',
#  'budacode.com',
#  'buglog.com',
#  'bugloos.nl',
#  'www.burningflame.it',
#  'www.burodeng.nl',
#  'bandgkft.hu',
#  'www.bussol.com',
#  'hr-assistant.it',
#  'www.buyoda.ch',
#  'byrds.ch',
#  'www.byrelations.com',
#  'bytemindz.com',
#  'www.byyoursite.nl',
#  'caboodle.studio',
#  'www.cabag.ch',
#  'cafedigital.ru',
#  'www.caffeinatedcode.co',
#  'cafffeine.com',
#  'www.cairowebdesign.com',
#  'calculate.plus',
#  'calcupal.be',
#  'www.calder.sk',
#  nan,
#  'www.callcentrix.net/nosotros/Default.aspx',
#  'www.callipigia.com',
#  'www.callis.dk',
#  'call-up.ch',
#  'cankod.com',
#  'cap-hr.fr',
#  'capica.nl',
#  'www.capvision.fr',
#  'www.carabincreatives.com',
#  'www.caramaps.com',
#  'caramel.la',
#  'carbonteq.com',
#  'careerradar.org',
#  'www.cargomedia.ch',
#  'www.cariboodigital.com',
#  'www.carlobi.se',
#  'www.sohler.ch',
#  'www.carrement-net.fr',
#  'www.cartab.com',
#  'cartlyapp.com',
#  'casalsonline.es',
#  'casisoft.de',
#  'castor-web-design.com',
#  'www.catchbull.com',
#  'www.cazemo.com',
#  'www.cartodecision.fr',
#  'www.clubdelrisparmio.com',
#  'www.cebelian.com',
#  'www.cefalo.com',
#  'celadonsoft.com',
#  'www.cephastech.com',
#  'www.cerebral-partner.com/home.html',
#  'www.cerqlar.com',
#  'certaince.com',
#  'cesbit.com',
#  'chakia.co.uk',
#  'changingdigital.com',
#  'charlin.be',
#  'www.chartblocks.com',
#  'checkiteasy.com',
#  'www.checksub.com',
#  'www.chef-ready.com',
#  'chetaru.com',
#  'www.chili.ch',
#  'www.sites-chirdent.net',
#  'www.chittak.co.uk',
#  'choicely.com',
#  'www.chubut.it',
#  'www.chunk.co.uk',
#  'ciit.at',
#  'www.cis-websolutions.nl',
#  'citio.digital',
#  'citronium.com',
#  'www.civicuk.com',
#  'www.ckc-net.com',
#  'clapped.im',
#  'www.classycode.com/en',
#  'cleandesk.no',
#  'www.clearmedia.ch',
#  'clearvoyage.com',
#  'clevermedia.gr/web',
#  'www.clevernet.pt',
#  'www.click4aweb.com',
#  'www.clickanet.fr',
#  'www.clickbizz.nl',
#  'www.clickon.ch',
#  'www.clicon.de',
#  'cliqtags.com',
#  'cliventa.com',
#  'www.clonestudios.co.uk',
#  'www.cloudex.se',
#  'www.cloudmotion.nl',
#  'www.cloudwall.tk',
#  'www.cmcitymedia.de',
#  'www.cmslabs.it',
#  'www.bigbase.nl',
#  'cockpit-sante.fr',
#  'www.codeagency.pl',
#  'www.codebase.it',
#  'www.codedj.co.uk',
#  'codedlines.com',
#  'www.codefrontiers.com',
#  'codefusion.pl',
#  'www.codefysoftware.com',
#  'codemask.com',
#  'codein.software',
#  'www.codelta.be',
#  'codenest.co',
#  'codenorm.de',
#  'codeplicity.com',
#  'codepotato.co.uk',
#  'coderelations.com',
#  'www.code-source.ch',
#  'code-troopers.com',
#  'www.codevanilla.com',
#  'www.codevate.com',
#  'codingo.me',
#  'www.codora.io',
#  'www.coeus-solutions.de',
#  'coggle.it',
#  'www.cogitoweb.it',
#  'www.cognifide.com',
#  'cogniteq.com',
#  'cognitic.be',
#  'www.cohoda.com',
#  'co-hr.com',
#  'www.columba.de',
#  'www.columbus-interactive.de',
#  'combidesk.com',
#  'comiteg.it',
#  'www.commerceworks.net',
#  'www.comodolab.it',
#  'www.deinestudienfinanzierung.de/de',
#  'comparegamehosting.com',
#  'www.compass-com.eu',
#  'www.compubel.be',
#  'www.eu.rsystems.com',
#  'comhost.eu',
#  'www.concept-computer.de',
#  'www.concepto.ch',
#  'cncrrnt.com',
#  'condacore.com',
#  'condegram.com',
#  'conferience.com',
#  'www.connecta.ag',
#  'connect.auto',
#  'www.connectedsoftec.com',
#  'studioconnecte.com',
#  'www.connectlime.com',
#  'connexionsw.com',
#  'www.connexis.de',
#  'www.conpeak.de',
#  'www.conscribo.nl',
#  'console9.com',
#  'www.consolidati.it',
#  'constructsys.com',
#  'contactcircuit.com',
#  'contester.net',
#  'www.contextminds.com',
#  'www.cca.io',
#  'www.controlspace.co',
#  'www.converxys.de',
#  'www.cookieshq.co.uk',
#  'www.coolgrey.de',
#  'www.coolsis.pt',
#  'www.coral.lt',
#  'www.corecube.it',
#  'www.coreluso.pt',
#  'coremaker.io',
#  'coreui.io',
#  'www.corobori.com',
#  'www.cortex-media.de',
#  'www.corussoft.de',
#  'www.cotunity.com',
#  'www.coveronweb.com',
#  'www.cracoutech.com',
#  'crafton.pl',
#  'craftturf.com',
#  'crafture.com',
#  'www.crazyrobot.be',
#  'www.cre8newmedia.com',
#  'www.cre8websolutions.be',
#  'www.creacoon.nl',
#  'www.creagh.com',
#  'www.creamive.com',
#  'create.nl',
#  'www.createit.com',
#  'www.createlli.com',
#  'www.creativeorange.nl',
#  'creativetheory.co.uk',
#  'www.creawe-services.com',
#  'www.crediteo.co',
#  'crewnew.com',
#  'crewontour.com',
#  'web.cright.com',
#  'www.crispy-it.de',
#  'www.critec.pt',
#  'www.crm-infosys.de',
#  'www.crobasoft.com',
#  'crocoders.io',
#  'crolox.nl',
#  'crustlab.com',
#  'www.cs2.ch',
#  'cstar.io',
#  'www.cubeapps.co',
#  'www.cubefour.de',
#  'www.cubicacomunicacion.com',
#  'www.cubicagency.com',
#  'www.cubicast.com',
#  'www.cubicstate.com',
#  'cudev.com',
#  'www.cuppedia.de',
#  'www.curabase.com',
#  'driftime.media',
#  'www.curvejump.se',
#  'www.curvosoft.com',
#  'www.dabac.com',
#  'thedailymetrics.com',
#  'www.damidev.com',
#  'www.danburykline.co.uk/DK',
#  'www.sposea.com',
#  'www.databridge.it',
#  'www.datamaze.io',
#  'datamix.io',
#  'www.datamola.com',
#  'www.datanomic.com',
#  'data-observer.com',
#  'datap.io',
#  nan,
#  'www.datawin.de',
#  'www.broadbandmetrics.com',
#  'datenfreunde.com',
#  'www.datix.de',
#  'www.datlink.cz',
#  'www.datocms.com',
#  'www.davinchi.es',
#  'www.daxx.com/company',
#  'www.daybyday.de',
#  'dayprosoft.es',
#  'www.dazzle.be',
#  'www.debussac.net',
#  'dbnetlink.net',
#  'www.dcc.ruhr',
#  'www.mydcs.gr',
#  'www.dcsoftware.pt',
#  'www.debondt.de',
#  'www.debugged.be',
#  'debugme.eu',
#  'decigio.com',
#  'dij.digital',
#  'www.deemaze.com',
#  nan,
#  'deepvision.cz',
#  'defonic.com',
#  'www.internetcompagnie.nl',
#  'www.delta-ai.com',
#  'cds.com.ua',
#  'denforex.com',
#  'deonlinefabriek.nl',
#  'www.depositado.com',
#  'www.depotnet.co.uk',
#  'www.deprocrastination.co',
#  'dermosafe.com/en',
#  'www.ders.cz',
#  'www.dersa-it.de',
#  'designenmedia.nl',
#  'www.desoft.de',
#  'www.despotsoft.dk',
#  'www.desuvit.com',
#  'www.detectify.com',
#  'dev2code.pl',
#  'devana.rs',
#  'devanddeliver.com',
#  'www.devault.ch',
#  'it.devbu.com',
#  'www.devconsultberlin.de',
#  'www.devdivision.net',
#  'devedis.ch',
#  'www.bmgroup.be',
#  'www.deversity.com',
#  'www.devision.com',
#  'www.devlogiq.com',
#  'devmy.it',
#  'www.devolution.be',
#  'devoorkant.nl',
#  'www.devpark.pl',
#  'www.devpod.dk',
#  'www.devrry.com',
#  'devy.io',
#  'dgtl.productions',
#  'dharmafly.com',
#  'www.dianti.fi',
#  'www.dibloc.com/home',
#  'andere-it-beratung.de',
#  'www.schnittsteller.de',
#  'dige.rs',
#  'www.diggsweep.com',
#  'digiants.agency',
#  'digisin.it',
#  'www.signals.co.uk',
#  'www.digital-craftsman.de',
#  'digitaldragonsglobal.com',
#  'www.digitalestate.tech',
#  'www.thedigitalists.net',
#  'www.digitalmachine.it',
#  'www.DigitalOriented.co.uk',
#  'www.digitalreti.com',
#  'www.digitaltalents.be',
#  'www.digitalworkroom.co.uk',
#  'www.digiteum.com',
#  'www.digititaly.net',
#  'digitools.io',
#  'www.digitsign.net',
#  'diglabstudio.com',
#  'www.dil-93.hr',
#  'www.dimnida.com',
#  'www.directsitters.co.uk',
#  'discoverdigitals.com',
#  'dis.cuss.it',
#  'www.distemicha.com',
#  'ditho.berlin',
#  'diwa.ch',
#  'www.diya.pro',
#  'www.dnateam.io',
#  'dnavi.pl',
#  'dobster.pl',
#  'docaret.com/en',
#  'www.docospot.dk',
#  'www.doc-safe.co.uk',
#  'ged.dgroove.it',
#  'www.dokflyt.no',
#  'www.domainster.com/U14F-PnK-e/domaininfo',
#  'www.donation-tracker.de',
#  'dontpanicdesign.co.uk',
#  'www.doppioweb.it',
#  'www.dotcomwa.it',
#  'dotinum.com',
#  'www.dotmedia.it',
#  'www.dotnest.com',
#  'dotnext.it',
#  'www.dotoso.de',
#  'dotways.fr',
#  'doublebit.net',
#  'www.doxinet.it',
#  'www.dps.cz',
#  'drap.hr',
#  'www.dreamonkey.com/en/home',
#  'www.dreamslab.it',
#  'www.dreamsolution.nl',
#  'dreipol.ch',
#  'www.drherwig.de',
#  'driven.design',
#  'www.dsc.net',
#  'www.dse.se',
#  'www.dsesoftware.nl',
#  'www.dtad.com/de',
#  'dubbelepunt.nl',
#  'www.duepuntotre.it',
#  'www.dukehoff.com',
#  'dunked.com',
#  'www.dutchgamestudio.com',
#  'www.wearedwm.com',
#  'www.dx-solutions.be',
#  'dynabase.de',
#  'www.dynagroup.de',
#  'dynamit.nl',
#  'dynweb.cz',
#  'www.e621.ch',
#  'www.eagna.io',
#  'www.ealys.com',
#  'earth2.io',
#  'www.eastpoint.co.uk',
#  'eastsideco.com',
#  'www.easyfeedback.com',
#  'www.easyleaving.com',
#  'www.easy-net.dk',
#  'www.easysolution.be',
#  'www.ebalance.ch',
#  'ecerium.com',
#  'jamworks.com',
#  'www.echogon.de',
#  'www.echolibre.com',
#  'echoua.com',
#  'ecologital.com',
#  'www.ecomsoft.fr',
#  'www.e-confirm.de',
#  'www.eco-soft.ch',
#  'www.e-dea.ro',
#  'www.edgeimpact.co.uk',
#  'www.edgeware.tv',
#  'edicomedia.com',
#  'www.edsi-tech.com/en',
#  'www.edulib.com',
#  'eduspot.co.uk',
#  'eeku.fi',
#  'www.eemlandinternet.nl',
#  'efabriek.nl',
#  'www.effekt-etage.de',
#  'www.efigence.com',
#  'egebit.com.tr',
#  'www.egotec.com',
#  'www.eisod.com',
#  'www.ejidosoft.es',
#  'ekara.ip-label.com',
#  nan,
#  'www.ekoha.co',
#  'elasticwings.com',
#  'www.elatro.nl',
#  'elearniz.fr',
#  'elemento115.es',
#  'www.eleven.nl',
#  'www.elfo.net',
#  'eli5.io',
#  'elikosoft.com.mk',
#  'elix.sr',
#  'elligense.com',
#  'www.elvisolutions.com',
#  nan,
#  'emergeitsupport.pl/en/homepage',
#  'emico.nl',
#  'www.eminus-software.com',
#  'www.emsation.se',
#  'www.enantena.net',
#  'www.endprizesolutions.com',
#  nan,
#  'www.enfacade.com',
#  'enflow.nl',
#  'www.enhance.ie',
#  'www.enigmasoft.ltd.uk',
#  'enrysisland.com',
#  'www.enyosolutions.com/en',
#  'www.eobs.fr',
#  'www.epionet.com',
#  'www.epocaricerca.it',
#  'www.gefahrstoff.com',
#  'www.eprisma.it',
#  'www.epublic.it',
#  'www.eratio.it',
#  'www.erelia.fr',
#  'erpcontact.ro',
#  'www.esb-net.de',
#  'esconsulting.it',
#  'www.escriptum.de',
#  'www.escsoftware.it',
#  'www.grupoesentia.com',
#  'www.esi-groupe.com',
#  'www.esokia.com/en',
#  'www.essentiadesign.be',
#  'www.esyst.nl',
#  'www.eszconsulting.com',
#  'www.etabetaconsulting.net',
#  'www.e-tailors.com',
#  'www.etelenima.com',
#  'www.etgigrup.com',
#  'etiqa.it',
#  'www.etiskapp.com',
#  'www.etrend.hu',
#  'eunity-service.de',
#  'www.euraconsult.ch',
#  'eurocoders.com',
#  'eurohispana.es',
#  'www.euromediaitalia.com',
#  'www.europanda.ro',
#  'www.europublic.de',
#  'www.evantra.de',
#  'www.everchurch.com',
#  'evergreencomputing.com',
#  'everlabs.com',
#  'evermade.fi/en',
#  'weareevermore.com',
#  'everse.ro',
#  'www.evialog.com',
#  'www.evimedia.nl/index.html',
#  'www.evin.it',
#  'www.evomatic.it',
#  'evonove.it',
#  'www.evosec.de',
#  'cms-ew-2020.ew-labor.de',
#  'www.ex4e.co.uk',
#  'exaitec.com',
#  'www.excel-help.eu',
#  'www.exigeapp.com',
#  'exit25.it',
#  'www.exodussa.gr',
#  'www.exsportance.de',
#  'www.extellient.com',
#  'www.extrea.nl',
#  'www.exxtra.nl',
#  'eyloo.com',
#  'www.fabres.pl',
#  'fabricaludens.it',
#  'facet-novium.nl',
#  'www.fahrenheit.ch',
#  'www.fannabee.com',
#  'www.faqtory.nl',
#  'www.faromedia.be',
#  'www.fastest.cz',
#  'www.fastfocus.be',
#  'favo.no',
#  'www.fax.plus',
#  'www.fbd.be',
#  'www.fecher.de',
#  'www.feedzon.com',
#  'www.fenetre.nl',
#  'www.fernhall.co.uk',
#  'www.ferryheijnen.nl',
#  'fingersfingers.co.uk',
#  'fiberjungle.com',
#  'fiduro.net',
#  'fill.ly',
#  'www.filmamo.it',
#  'financekey.com',
#  'www.findrugbynow.com',
#  'www.finite-soft.com',
#  'www.finkoslo.no',
#  'www.finsoft.it',
#  'www.firefleye.be',
#  'fivedottwelve.com',
#  '5ly.co',
#  'www.fjordsoftware.eu',
#  'flatsoft.com',
#  'www.fleetback.com',
#  'www.flexio.fr',
#  'flexiweb.co',
#  'www.flightmate.ie',
#  'www.florida-digital.de',
#  'www.flux2fusion.com',
#  'www.flyacts.com',
#  'www.flying-cat.de',
#  'www.foe-services.de',
#  'foiz.io',
#  'foliovision.com',
#  'www.foodnotify.com',
#  'forcklabs.com',
#  'www.foreach.be',
#  'forecastads.com',
#  'foreto.com',
#  'forkflow.io',
#  'www.fork.de',
#  'form2chat.io',
#  'formatics.nl',
#  'www.formulewww.nl',
#  'www.forthbusiness.com',
#  'fotka.com',
#  'www.fotojet.com',
#  'www.fourdigits.nl',
#  'www.fourmeta.com',
#  'www.fps.hu',
#  'www.fraktal.co',
#  'www.freeformcreative.co.uk',
#  'freetimefor.biz',
#  'freshapps.nl',
#  'freshcodeit.com',
#  'www.fresh-internet.net',
#  'freshpigment.com',
#  'www.freshtag.nl',
#  'www.freyhauer.de',
#  'friends-of-it.de',
#  'friendstudios.no',
#  'www.frind.it',
#  'www.hypehype.com',
#  'frogspark.co.uk',
#  'fromidea.fi',
#  'frontosaur.com',
#  'ftprod.fr',
#  'www.fulcri.it',
#  'fullwebservice.nl',
#  'www.fusionglobalcapital.com',
#  'www.futurace.com',
#  'gulenayva.com',
#  'g1g.nl/index.html',
#  'web.ga-insights.com',
#  'gajelabs.com',
#  'galadrim.fr',
#  'gallimedia.com',
#  'token.gamee.com',
#  'www.gammadia.ch',
#  'gangverk.is',
#  'info.gapless.app',
#  'www.garbott.co.uk',
#  'www.zaprojektuj-ogrod.pl/en/Home',
#  'www.garlandsoftworx.com',
#  'www.gastrosoft.ch',
#  'www.gate49.com',
#  'www.gawlitta.com',
#  'geeksters.co',
#  'gelal.com',
#  'gematica.com',
#  'www.gemmedia.co.uk',
#  'www.generic.se',
#  'gentlereader.com',
#  'www.genux.com/it',
#  'geocento.com',
#  'www.geogarage.com',
#  'www.geographics.eu',
#  'www.gereedschapbeheer.nl',
#  'www.gerere.com',
#  'gestionmedica.com',
#  'gewoon-peter.nl/webstudio.php',
#  'www.gfactory.nl',
#  'www.ggate.it',
#  'www.ghmgesthotel.com',
#  'www.ghost.ch',
#  'www.gillz.nl',
#  'ginilab.com',
#  'www.gino.nl',
#  'giraffestudio.pl',
#  'giscloud.hr',
#  'www.gis-art.com',
#  'www.gis-consult.de',
#  'gis-plan.swiss',
#  'gitlabhost.com',
#  'givingtales.com',
#  'www.givtapp.net',
#  'www.firmware.be',
#  'glide.design',
#  'www.gfds-inc.com',
#  'www.globalis-ms.com',
#  'www.globule.net',
#  ...]

# %% [markdown]
# ---

# %% [markdown]
# ### Step 3: scrape privacy policies

# %%
nlp = spacy.load("en_core_web_md")

# %%
def get_privacy_policy_url(query):
    keyword_in_title = 0
    attempts = 0
    url = ""
    print("Query: " + query)
    
    try:
        query_results_list = return_google_results(query, 3, 5)
        print("Considering " + str(len(query_results_list)) + " URL(s) ...")
        for i, url in enumerate(query_results_list):
            term_in_url = 0
            attempts = attempts + 1
            print("Assessing privacy policy URL: " + url)
            
            if (re.findall('privacy', url) or re.findall('policy', url)): 
                print("Found relevant terms in URL! Succesful break!")
                break

#                     pass
            if keyword_in_title == 1 or attempts == 3 or i==(len(query_results_list)-1): 
                keyword_in_title = 0
                attempts = 0
                print("No results. Breaking ..")
                url = ""
#                 print(sentences)
                break   
    except Exception as e:
            print(str(e))
#             print("we're breaking ..")
            
#             sys.exit()
            pass
    return url

# %%
def return_google_results(keywords, num_results, attempts):
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'}
#     headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

    html_keyword = urllib.parse.quote_plus(keywords)
    sleep_init = 10
    
    url = "https://www.google.com/search?q=" + html_keyword + "&num=" + str(num_results)
    print("** Search query in URL: " + url)
#     print("** Results:")
    html = requests.get(url, headers=headers, timeout = 5)
#     print(html.status_code)
    if html.status_code == 429:
        
        if(attempts == 0):
            sys.exit("Too many request 429, attempted "+ str(5)+ " times, break ...")
        
        time.sleep(sleep_init)
        print("Too many requests (attempt "+ str(5 - attempts)+ "), we will attempt again in " + str(sleep_init) + " seconds")
        return_google_results(keywords, num_results, (attempts - 1))
    else: 
        pass
        
    soup = BeautifulSoup(html.text, 'html.parser')

    allData = soup.find_all("div",{"class":"g"})

    link_list = []
    print("len alldata: " + str(len(allData)))
    
    for i in range(0,len(allData)):
        link = allData[i].find('a').get('href')
        
        if(link is not None):
            if(link.find('https') != -1 and link.find('http') == 0 and link.find('aclk') == -1):
                print(link)
                link_list.append(link)
    print(link_list)
    return link_list

# %% [markdown]
# #### Collect privacy policy URLs

# %%
privacy_policies_url_list = []

# %%
# loop through each company URL and attempt to find the URL of the privacy policy
for i, url_company in enumerate(websites_list[75:]):
    print(i)
#     print(len(privacy_policies_url_list))
    if(isinstance("url_company", str) is False):
        privacy_policies_url_list.append("")
    else:
        query = "site:\"" + url_company + " \"privacy policy"
        privacy_policies_url_list.append(get_privacy_policy_url(query))
    print()
    time.sleep(10)
    if (i == 500):
        break
# Out:
# 0
# Query: site:"www.addink.net "privacy policy
# ** Search query in URL: https://www.google.com/search?q=site%3A%22www.addink.net+%22privacy+policy&num=3
# Too many requests (attempt 0), we will attempt again in 10 seconds
# ** Search query in URL: https://www.google.com/search?q=site%3A%22www.addink.net+%22privacy+policy&num=3
# Too many requests (attempt 1), we will attempt again in 10 seconds
# ** Search query in URL: https://www.google.com/search?q=site%3A%22www.addink.net+%22privacy+policy&num=3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-106-3b1ff5d9b051> in <module>
#       7     else:
#       8         query = "site:\"" + url_company + " \"privacy policy"
# ----> 9         privacy_policies_url_list.append(get_privacy_policy_url(query))
#      10     print()
#      11     time.sleep(10)
#
# <ipython-input-54-5eff841f0793> in get_privacy_policy_url(query)
#       6
#       7     try:
# ----> 8         query_results_list = return_google_results(query, 3, 5)
#       9         print("Considering " + str(len(query_results_list)) + " URL(s) ...")
#      10         for i, url in enumerate(query_results_list):
#
# <ipython-input-95-4af6c6a4e63d> in return_google_results(keywords, num_results, attempts)
#      18         time.sleep(sleep_init)
#      19         print("Too many requests (attempt "+ str(5 - attempts)+ "), we will attempt again in " + str(sleep_init) + " seconds")
# ---> 20         return_google_results(keywords, num_results, (attempts - 1))
#      21     else:
#      22         pass
#
# <ipython-input-95-4af6c6a4e63d> in return_google_results(keywords, num_results, attempts)
#      18         time.sleep(sleep_init)
#      19         print("Too many requests (attempt "+ str(5 - attempts)+ "), we will attempt again in " + str(sleep_init) + " seconds")
# ---> 20         return_google_results(keywords, num_results, (attempts - 1))
#      21     else:
#      22         pass
#
# <ipython-input-95-4af6c6a4e63d> in return_google_results(keywords, num_results, attempts)
#      16             sys.exit("Too many request 429, attempted "+ str(5)+ " times, break ...")
#      17
# ---> 18         time.sleep(sleep_init)
#      19         print("Too many requests (attempt "+ str(5 - attempts)+ "), we will attempt again in " + str(sleep_init) + " seconds")
#      20         return_google_results(keywords, num_results, (attempts - 1))
#
# KeyboardInterrupt:

# %%
keyword = "site:\"" + "https://www.facebook.com" + " \"privacy policy"
number_of_result = 3
llist = return_google_results(keyword, number_of_result, 1)
# Out:
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.facebook.com%22+privacy+policy&num=3
#
# []
#
# f2
# len alldata: 0
# []
# f5

# %%
privacy_policies_url_list[74]
# Out:
# ''

# %%
# privacy_policies_url_list_0_74 = privacy_policies_url_list
# privacy_policies_url_list_15_ = privacy_policies_url_list

# %%
privacy_policies_url_list_0_74
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'https://1minus1.com/legal/privacy',
#  '',
#  'https://21stwebb.co.uk/privacy/',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'https://www.2open.it/cookie-policy-it.html',
#  '',
#  '',
#  'https://33communication.com/privacy_policy/',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'https://blog.3ie.fr/privacy-policy/',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'https://www.4fx.co.uk/legals-privacy-policy.html',
#  'https://www.4homepages.de/privacy-policy',
#  '',
#  '',
#  'https://5w155.ch/legal/privacy-policy',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'https://8web.gr/en/wordpress-web-design-privacy-policy/',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'https://www.aaltra.eu/privacy-policy',
#  '',
#  'https://www.aardvark-creative.com/privacy.shtml',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'https://www.ablsoft.it/privacy-policy/',
#  '',
#  '',
#  '',
#  'https://accesslab.gr/en/privacy-policy/',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'https://www.adakom.de/en/privacy-policy.html',
#  '',
#  'https://adamfard.com/privacy-policy',
#  'https://www.adamkey.com/en/privacy/',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'https://www.advertage.com/privacy-policy/',
#  'https://www.adverteaser.com/privacy.html',
#  '',
#  '',
#  '',
#  '',
#  'https://www.aersyn.com/privacy-policy/',
#  '',
#  '',
#  'https://www.agifly.be/privacy-policy',
#  'https://agileapp.co/privacy-policy/',
#  '',
#  'https://ag-prop.com/page/privacy',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'https://www.aircury.com/privacy-policy',
#  '',
#  'https://www.ais.pl/en/privacy-policy/',
#  '']

# %%
len([print(collected_url) for collected_url in privacy_policies_url_list if collected_url is not ""])
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-106-96e161e2c96b>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   len([print(collected_url) for collected_url in privacy_policies_url_list if collected_url is not ""])
# 0

# %% [markdown]
# #### Scrape!

# %%
def scrape_policies_google(query):
    keyword_in_title = 0
    attempts = 0
    policies = []
    sentences = []    
    try:
        
        article = Article(url)
#             print(url)
        article.download() #Downloads the link’s HTML content
#             print(url)
        article.parse() #Parse the article
#             print(url)
#                 print(article.title)
        doc = nlp(article.text)
        print("PP language = EN?: " + str(detect(article.text) == 'en'))
        print("PP length > 10 sentences?: " + str(len(list(doc.sents)) > 10))

        if detect(article.text) == 'en' and len(list(doc.sents)) > 10:
            print("Policy meets requirements of language and length ... ")
            sentences = list(doc.sents)
            keyword_in_title = 1
            print("Scraping successful!")

        else:
            print("Scraping not successful")

    except:
            pass
    return sentences, url

# %%
len([print(collected_url) for collected_url in privacy_policies_url_list_0_74 if collected_url != ""])
# Out:
# https://1minus1.com/legal/privacy
# https://21stwebb.co.uk/privacy/
# https://www.2open.it/cookie-policy-it.html
# https://33communication.com/privacy_policy/
# https://blog.3ie.fr/privacy-policy/
# https://www.4fx.co.uk/legals-privacy-policy.html
# https://www.4homepages.de/privacy-policy
# https://5w155.ch/legal/privacy-policy
# https://8web.gr/en/wordpress-web-design-privacy-policy/
# https://www.aaltra.eu/privacy-policy
# https://www.aardvark-creative.com/privacy.shtml
# https://www.ablsoft.it/privacy-policy/
# https://accesslab.gr/en/privacy-policy/
# https://www.adakom.de/en/privacy-policy.html
# https://adamfard.com/privacy-policy
# https://www.adamkey.com/en/privacy/
# https://www.advertage.com/privacy-policy/
# https://www.adverteaser.com/privacy.html
# https://www.aersyn.com/privacy-policy/
# https://www.agifly.be/privacy-policy
# https://agileapp.co/privacy-policy/
# https://ag-prop.com/page/privacy
# https://www.aircury.com/privacy-policy
# https://www.ais.pl/en/privacy-policy/
# 24

# %%
pp_list_sentences = []
for i, pp_url in enumerate(privacy_policies_url_list_0_74):
    pp_list_sentences.append(scrape_policies_google(pp_url))

# %% [markdown]
# ---

# %% [markdown]
# ### Step 4: classification

# %%
# def return_google_results(keywords, num_results, attempts):
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'}
#     headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

html_keyword = urllib.parse.quote_plus("site:\"" + "https://www.facebook.com" + "\" privacy policy")
sleep_init = 10

url = "https://www.google.com/search?q=" + html_keyword + "&num=" + str(3)
print("** Search query in URL: " + url)
#     print("** Results:")
html = requests.get(url, headers=headers, timeout = 5)
#     print(html.status_code)
if html.status_code == 429:
    sys.exit("Too many request 429, attempted "+ str(5)+ " times, break ...")
# Out:
# ** Search query in URL: https://www.google.com/search?q=site%3A%22https%3A%2F%2Fwww.facebook.com%22+privacy+policy&num=3

# %%
soup = BeautifulSoup(html.text, 'html.parser')
print(soup)
print("")
# Out:
# <!DOCTYPE doctype html>
# <html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="nl-BE"><head><meta charset="utf-8"/><meta content="origin" name="referrer"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>site:"https://www.facebook.com" privacy policy - Google Zoeken</title><script nonce="XJ1bSfQIes_SIM50XbvPAQ">(function(){
# var b=window.addEventListener;window.addEventListener=function(a,c,d){"unload"!==a&&b(a,c,d)};}).call(this);(function(){window.google={kEI:'gTYkY-OmHLaF9u8Pn8G48Ao',kEXPI:'31',kBL:'o7pG'};google.sn='web';google.kHL='nl-BE';})();(function(){
# var f=this||self;var h,k=[];function l(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||h}function m(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}
# function n(a,b,c,d,g){var e="";c||-1!==b.search("&ei=")||(e="&ei="+l(d),-1===b.search("&lei=")&&(d=m(d))&&(e+="&lei="+d));d="";!c&&f._cshid&&-1===b.search("&cshid=")&&"slh"!==a&&(d="&cshid="+f._cshid);c=c||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+e+"&zx="+Date.now()+d;/^http:/i.test(c)&&"https:"===window.location.protocol&&(google.ml&&google.ml(Error("a"),!1,{src:c,glmm:1}),c="");return c};h=google.kEI;google.getEI=l;google.getLEI=m;google.ml=function(){return null};google.log=function(a,b,c,d,g){if(c=n(a,b,c,d,g)){a=new Image;var e=k.length;k[e]=a;a.onerror=a.onload=a.onabort=function(){delete k[e]};a.src=c}};google.logUrl=n;}).call(this);(function(){
# google.y={};google.sy=[];google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.sx=function(a){google.sy.push(a)};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};}).call(this);google.f={};(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){google.hs={h:true,nhs:false,sie:false};})();(function(){google.c={btfi:false,cap:2000,frt:false,gecoh:false,gl:false,lhc:false,logo:false,raf:false,taf:true,timl:false,wvclse:true,wve:true};})();(function(){
# var e=this||self;var f=window.performance;function g(a,b,c,d){a.addEventListener?a.addEventListener(b,c,d||!1):a.attachEvent&&a.attachEvent("on"+b,c)}function h(a,b,c,d){"addEventListener"in a?a.removeEventListener(b,c,d||!1):a.attachEvent&&a.detachEvent("on"+b,c)};google.c.iim=google.c.iim||{};function l(a){a&&e.google.aft(a.target)}var m;function n(){h(document.documentElement,"load",m,!0);h(document.documentElement,"error",m,!0)};google.timers={};google.startTick=function(a){google.timers[a]={t:{start:Date.now()},e:{},m:{}}};google.tick=function(a,b,c){google.timers[a]||google.startTick(a);c=void 0!==c?c:Date.now();b instanceof Array||(b=[b]);for(var d=0,k;k=b[d++];)google.timers[a].t[k]=c};google.c.e=function(a,b,c){google.timers[a].e[b]=c};google.c.b=function(a){var b=google.timers.load.m;b[a]&&google.ml(Error("a"),!1,{m:a});b[a]=!0};google.c.u=function(a){var b=google.timers.load.m;if(b[a]){b[a]=!1;for(a in b)if(b[a])return;google.csiReport()}else{var c="",d;for(d in b)c+=d+":"+b[d]+";";google.ml(Error("b"),!1,{m:a,b:!1===b[a],s:c})}};google.rll=function(a,b,c){function d(k){c(k);h(a,"load",d);h(a,"error",d)}g(a,"load",d);b&&g(a,"error",d)};e.google.aft=function(a){a.setAttribute("data-iml",String(Date.now()))};google.startTick("load");var p=google.timers.load;a:{var q=p.t;if(f){var r=f.timing;if(r){var t=r.navigationStart,u=r.responseStart;if(u>t&&u<=q.start){q.start=u;p.wsrt=u-t;break a}}f.now&&(p.wsrt=Math.floor(f.now()))}}function v(a){if("hidden"===document.visibilityState){google.c.wve&&(google.c.fh=a);var b;window.performance&&window.performance.timing&&(b=Math.floor(window.performance.timing.navigationStart+a));google.tick("load","fht",b);return!0}return!1}function w(a){v(a.timeStamp)&&h(document,"visibilitychange",w,!0)}
# google.c.wve&&(google.c.fh=Infinity);g(document,"visibilitychange",w,!0);v(0);google.c.b("pr");google.c.b("xe");google.c.gl&&(m=l,g(document.documentElement,"load",m,!0),google.c.glu=n);}).call(this);(function(){
# function k(){return window.performance&&window.performance.navigation&&window.performance.navigation.type};function p(a,b,c){if(!a||q(a))return 0;if(!a.getBoundingClientRect)return 1;var d=function(e){return e.getBoundingClientRect()};return r(a,b,d,c)?0:t(a,b,d)}function r(a,b,c,d){a:{for(var e=a;e&&e!==b;e=e.parentElement)if("hidden"===e.style.overflow||d&&"G-EXPANDABLE-CONTENT"===e.tagName&&"hidden"===getComputedStyle(e).getPropertyValue("overflow")){b=e;break a}b=null}if(!b)return!1;a=c(a);c=c(b);return a.bottom<c.top||a.top>=c.bottom||a.right<c.left||a.left>=c.right}
# function q(a){return"none"===a.style.display?!0:document.defaultView&&document.defaultView.getComputedStyle?(a=document.defaultView.getComputedStyle(a),!!a&&("hidden"===a.visibility||"0px"===a.height&&"0px"===a.width)):!1}
# function t(a,b,c){var d=c(a),e=d.left+window.pageXOffset,g=d.top+window.pageYOffset,l=d.width,h=d.height,f=0;if(0>=h&&0>=l)return f;var m=window.innerHeight||document.documentElement.clientHeight;0>g+h?f=2:g>=m&&(f=4);if(0>e+l||e>=(window.innerWidth||document.documentElement.clientWidth))f|=8;else if(b){for(d=d.left;a&&a!==b;a=a.parentElement)d+=a.scrollLeft;b=c(b);if(d+l<b.left||d>=b.right)f|=8}f||(f=1,g+h>m&&(f|=4));return f};var u=window.location,v="aft afti afts cbs cbt frt hct prt sct".split(" ");function w(a){return(a=u.search.match(new RegExp("[?&]"+a+"=(\\d+)")))?Number(a[1]):-1}
# function x(a){var b=google.timers.load,c=b.m;if(!c||!c.prs){var d=k()?0:w("qsubts");0<d&&(c=w("fbts"),0<c&&(b.t.start=Math.max(d,c)));var e=b.t,g=e.start;c={wsrt:b.wsrt||0};for(var l=0,h;h=v[l++];){var f=e[h];f&&g&&(c[h]=f-g)}0<d&&(c.gsasrt=b.t.start-d);b=b.e;a="/gen_204?s="+google.sn+"&t="+(a?"cap":"aft")+"&atyp=csi&ei="+google.kEI+"&rt=";d="";for(n in c)a+=""+d+n+"."+c[n],d=",";for(var m in b)a+="&"+m+"="+b[m];window._cshid&&(a+="&cshid="+window._cshid);2===k()&&(a+="&bb=1");1===k()&&(a+="&r=1");if("gsasrt"in c){var n=w("qsd");0<n&&(a+="&qsd="+n)}google.kBL&&(a+="&bl="+google.kBL);n=a;navigator.sendBeacon?navigator.sendBeacon(n,""):google.log("","",n)}};function y(a){a&&google.tick("load","cbs",a);google.tick("load","cbt");x(!0)};var z="src bsrc url ll image img-url".split(" ");function A(a){for(var b=0;b<z.length;++b)if(a.getAttribute("data-"+z[b]))return!0;return!1}function B(a){for(var b=a;b&&"center_col"!==b.id;)b=b.parentElement;var c=a.parentElement;if(c&&("G-IMG"===c.tagName||c.classList.contains("uhHOwf"))&&(c.style.height||c.style.width)){var d=c.getBoundingClientRect(),e=a.getBoundingClientRect();if(d.height<=e.height||d.width<=e.width)a=c}var g;return p(a,b,null==(g=google.c)?void 0:g.gecoh)}
# google.c.iim=google.c.iim||{};var C=window.innerHeight||document.documentElement.clientHeight,D=0,E=0,F=0,G=0,H=0,I=0,J=0,K=!0,L=!0,M=-1,N;function O(a,b,c,d){var e=google.timers.load.t[a];e&&(c||d&&null!=b&&b<e)||google.tick("load",a,b)}function P(a,b,c){"1"===a.getAttribute("data-frt")&&(O("frt",c,!1,!0),++G,Q());b&&(O("aft",c,!1,!0),O("afti",c,!1,!0),++I,Q());google.c.timl&&O("iml",c,!1,!0);++E;a.setAttribute("data-frt","0");(google.c.timl||b)&&R()}function R(){var a=google.c.timl?E===D:H===I;!L&&a&&google.c.u("il")}
# function Q(){if(!K){var a=I===H,b=G===F;a&&b&&(google.c.e("load","ima",String(H)),google.c.e("load","imad",String(J)),google.c.e("load","aftp",String(Math.round(M))),document.getElementsByClassName("Ib7Efc").length&&google.c.e("load","ddl","1"),N&&clearTimeout(N),x());"hidden"===document.visibilityState&&google.c.e("load","hddn","1");if(null!==google.aftq&&(2===google.fevent||3===google.fevent?google.fevent:1)&((a?1:0)|(b?2:0))){google.tick("load","aftqf",Date.now());var c;for(a=0;b=null==(c=google.aftq)?void 0:c[a++];)try{b()}catch(d){google.ml(d,!1)}google.aftq=null}}}function S(a,b){0===b||b&8||(a.setAttribute("data-frt","1"),++F)}if(0<google.c.cap)a:{var T=google.c.cap;if(window.performance&&window.performance.timing&&"navigationStart"in window.performance.timing){var U=window.performance.now(),V=T-U;if(0<V){N=setTimeout(y,V,Math.floor(window.performance.timing.navigationStart+U));break a}y()}N=void 0}google.c.wh=Math.floor(window.innerHeight||document.documentElement.clientHeight);google.c.e("load","wh",String(google.c.wh));google.c.b("il");google.c.setup=function(a,b,c){var d=a.getAttribute("data-atf");if(d)return c=Number(d),b&&!a.hasAttribute("data-frt")&&S(a,c),c;var e="string"!==typeof a.src||!a.src,g=!!a.getAttribute("data-bsrc");d=!!a.getAttribute("data-deferred");var l=!d&&A(a);l&&a.setAttribute("data-lzy_","1");var h=B(a);a.setAttribute("data-atf",String(h));var f=!!(h&1);e=(e||a.complete)&&!d&&!g&&!(f&&l);g=!google.c.lhc&&Number(a.getAttribute("data-iml"))||0;++D;if(e&&!g||a.hasAttribute("data-noaft"))a.setAttribute("data-frt","0"),++E;else{if(l=google.c.btfi&&h&4&&g&&M<C){var m=a.getBoundingClientRect().top+window.pageYOffset;!c||m<c?M=f?C:m:l=!1}f&&(++H,d&&++J);b&&S(a,h);l&&(O("aft",g,!1,!0),O("aftb",g,!1,!0));e&&g?P(a,f,google.c.btfi?0:g):(f&&(!c||c>=C)&&(M=C),google.rll(a,!0,function(){P(a,f,Date.now())}))}return h};google.c.ubr=function(a,b,c){google.c.taf&&M<C?(M=c||-1,O("aft",b)):0>M&&(c&&(M=c),google.c.btfi&&O("aft",b));a||O("afts",b,!0);O("aft",b,!0);K&&!google.c.frt&&(K=!1,Q());a&&L&&(O("prt",b),google.c.timl&&O("iml",b,!0),L=!1,R(),google.c.setup=function(){return 0},google.c.ubr=function(){})};}).call(this);(function(){
# var b=[function(){google.tick&&google.tick("load","dcl")}];google.dclc=function(a){b.length?b.push(a):a()};function c(){for(var a=b.shift();a;)a(),a=b.shift()}window.addEventListener?(document.addEventListener("DOMContentLoaded",c,!1),window.addEventListener("load",c,!1)):window.attachEvent&&window.attachEvent("onload",c);}).call(this);(function(){
# var b=[];google.jsc={xx:b,x:function(a){b.push(a)},mm:[],m:function(a){google.jsc.mm.length||(google.jsc.mm=a)}};}).call(this);(function(){
# var e=this||self;
#
# var f={};function w(a,c){if(null===c)return!1;if("contains"in a&&1==c.nodeType)return a.contains(c);if("compareDocumentPosition"in a)return a==c||!!(a.compareDocumentPosition(c)&16);for(;c&&a!=c;)c=c.parentNode;return c==a};var y=function(a,c){return function(d){d||(d=window.event);return c.call(a,d)}},z="undefined"!=typeof navigator&&/Macintosh/.test(navigator.userAgent),E=function(){this._mouseEventsPrevented=!0};var F=function(a){this.g=a;this.h=[]},G=function(a){for(var c=0;c<a.h.length;++c){var d=a.g,b=a.h[c];d.removeEventListener?d.removeEventListener(b.eventType,b.o,b.capture):d.detachEvent&&d.detachEvent("on"+b.eventType,b.o)}a.h=[]};
# var H=e._jsa||{};H._cfc=void 0;H._aeh=void 0;var I=function(){this.h=this.g=null},K=function(a,c){var d=J;d.g=a;d.h=c;return d};I.prototype.i=function(){var a=this.g;this.g&&this.g!=this.h?this.g=this.g.__owner||this.g.parentNode:this.g=null;return a};var L=function(){var a;this.j=a=void 0===a?[]:a;this.g=0;this.h=null;this.l=!1},N=function(a,c){var d=M;d.j=a;d.g=0;d.h=c;d.l=!1;return d};L.prototype.i=function(){if(this.l)return J.i();if(this.g!=this.j.length){var a=this.j[this.g];this.g++;a!=this.h&&a&&a.__owner&&(this.l=!0,K(a.__owner,this.h));return a}return null};var J=new I,M=new L;
# var Q=function(){this.s=[];this.g=[];this.h=[];this.l={};this.i=null;this.j=[];P(this,"_custom")},R=function(a){return String.prototype.trim?a.trim():a.replace(/^\s+/,"").replace(/\s+$/,"")},ia=function(a,c){return function m(b,g){g=void 0===g?!0:g;var l=c;if("_custom"==l){l=b.detail;if(!l||!l._type)return;l=l._type}var k=l;"click"==k&&(z&&b.metaKey||!z&&b.ctrlKey||2==b.which||null==b.which&&4==b.button||b.shiftKey)?k="clickmod":"keydown"==k&&!b.a11ysc&&(k="maybe_click");var u=b.srcElement||b.target;l=S(k,b,u,"",null);var aa=b.path?N(b.path,this):b.composedPath?N(b.composedPath(),this):K(u,this);for(var r;r=aa.i();){var h=r;var p=void 0;r=h;var q=k,ba=b;var n=r.__jsaction;if(!n){var x;n=null;"getAttribute"in r&&(n=r.getAttribute("jsaction"));if(x=n){n=f[x];if(!n){n={};for(var A=x.split(ca),da=A?A.length:0,B=0;B<da;B++){var v=A[B];if(v){var C=v.indexOf(":"),O=-1!=C,fa=O?R(v.substr(0,C)):ea;v=O?R(v.substr(C+1)):v;n[fa]=v}}f[x]=n}r.__jsaction=n}else n=ha,r.__jsaction=n}"maybe_click"==q&&n.click?(p=q,q="click"):"clickkey"==q?q="click":"click"!=q||n.click||(q="clickonly");p=H._cfc&&n.click?H._cfc(r,ba,n,q,p):{eventType:p?p:q,action:n[q]||"",event:null,ignore:!1};l=S(p.eventType,p.event||b,u,p.action||"",h,l.timeStamp);if(p.ignore||p.action)break}l&&"touchend"==l.eventType&&(l.event._preventMouseEvents=E);if(p&&p.action){if("mouseenter"==k||"mouseleave"==k||"pointerenter"==k||"pointerleave"==k)if(u=b.relatedTarget,!("mouseover"==b.type&&"mouseenter"==k||"mouseout"==b.type&&"mouseleave"==k||
# "pointerover"==b.type&&"pointerenter"==k||"pointerout"==b.type&&"pointerleave"==k)||u&&(u===h||w(h,u)))l.action="",l.actionElement=null;else{k={};for(var t in b)"function"!==typeof b[t]&&"srcElement"!==t&&"target"!==t&&(k[t]=b[t]);k.type="mouseover"==b.type?"mouseenter":"mouseout"==b.type?"mouseleave":"pointerover"==b.type?"pointerenter":"pointerleave";k.target=k.srcElement=h;k.bubbles=!1;l.event=k;l.targetElement=h}}else l.action="",l.actionElement=null;h=l;a.i&&!h.event.a11ysgd&&(t=S(h.eventType,h.event,h.targetElement,h.action,h.actionElement,h.timeStamp),"clickonly"==t.eventType&&(t.eventType="click"),a.i(t,!0));if(h.actionElement||"maybe_click"==h.eventType){if(a.i){if(!h.actionElement||"A"!=h.actionElement.tagName||"click"!=h.eventType&&"clickmod"!=h.eventType||(b.preventDefault?b.preventDefault():b.returnValue=!1),(b=a.i(h))&&g){m.call(this,b,!1);return}}else{if((g=e.document)&&!g.createEvent&&g.createEventObject)try{var D=g.createEventObject(b)}catch(la){D=b}else D=b;h.event=D;a.j.push(h)}H._aeh&&
# H._aeh(h)}}},S=function(a,c,d,b,g,m){return{eventType:a,event:c,targetElement:d,action:b,actionElement:g,timeStamp:m||Date.now()}},ja=function(a,c){return function(d){var b=a,g=c,m=!1;"mouseenter"==b?b="mouseover":"mouseleave"==b?b="mouseout":"pointerenter"==b?b="pointerover":"pointerleave"==b&&(b="pointerout");if(d.addEventListener){if("focus"==b||"blur"==b||"error"==b||"load"==b)m=!0;d.addEventListener(b,g,m)}else d.attachEvent&&("focus"==b?b="focusin":"blur"==b&&(b="focusout"),g=y(d,g),d.attachEvent("on"+
# b,g));return{eventType:b,o:g,capture:m}}},P=function(a,c){if(!a.l.hasOwnProperty(c)){var d=ia(a,c),b=ja(c,d);a.l[c]=d;a.s.push(b);for(d=0;d<a.g.length;++d){var g=a.g[d];g.h.push(b.call(null,g.g))}"click"==c&&P(a,"keydown")}};Q.prototype.o=function(a){return this.l[a]};var W=function(a,c){var d=new F(c);a:{for(var b=0;b<a.g.length;b++)if(T(a.g[b].g,c)){c=!0;break a}c=!1}if(c)return a.h.push(d),d;U(a,d);a.g.push(d);V(a);return d},V=function(a){for(var c=a.h.concat(a.g),d=[],b=[],g=0;g<a.g.length;++g){var m=a.g[g];X(m,c)?(d.push(m),G(m)):b.push(m)}for(g=0;g<a.h.length;++g)m=a.h[g],X(m,c)?d.push(m):(b.push(m),U(a,m));a.g=b;a.h=d},U=function(a,c){var d=c.g;ka&&(d.style.cursor="pointer");for(d=0;d<a.s.length;++d)c.h.push(a.s[d].call(null,c.g))},Y=function(a,c){a.i=c;a.j&&(0<a.j.length&&c(a.j),a.j=null)},X=function(a,c){for(var d=0;d<c.length;++d)if(c[d].g!=a.g&&T(c[d].g,a.g))return!0;return!1},T=function(a,c){for(;a!=c&&c.parentNode;)c=c.parentNode;return a==c},ka="undefined"!=typeof navigator&&/iPhone|iPad|iPod/.test(navigator.userAgent),ca=/\s*;\s*/,ea="click",ha={};var Z=new Q;W(Z,window.document.documentElement);P(Z,"click");P(Z,"focus");P(Z,"focusin");P(Z,"blur");P(Z,"focusout");P(Z,"error");P(Z,"load");P(Z,"auxclick");P(Z,"change");P(Z,"dblclick");P(Z,"beforeinput");P(Z,"input");P(Z,"keyup");P(Z,"keydown");P(Z,"keypress");P(Z,"mousedown");P(Z,"mouseenter");P(Z,"mouseleave");P(Z,"mouseout");P(Z,"mouseover");P(Z,"mouseup");P(Z,"paste");P(Z,"touchstart");P(Z,"touchend");P(Z,"touchcancel");P(Z,"transitioncancel");P(Z,"transitionend");P(Z,"transitionrun");P(Z,"transitionstart");P(Z,"dragover");P(Z,"dragenter");P(Z,"dragleave");P(Z,"drop");P(Z,"dragstart");P(Z,"dragend");P(Z,"speech");(function(a){google.jsad=function(c){Y(a,c)};google.jsaac=function(c){return W(a,c)};google.jsarc=function(c){G(c);for(var d=!1,b=0;b<a.g.length;++b)if(a.g[b]===c){a.g.splice(b,1);d=!0;break}if(!d)for(d=0;d<a.h.length;++d)if(a.h[d]===c){a.h.splice(d,1);break}V(a)}})(Z);e.gws_wizbind=function(a){return{trigger:function(c){var d=a.o(c.type);d||(P(a,c.type),d=a.o(c.type));var b=c.target||c.srcElement;d&&d.call(b.ownerDocument.documentElement,c)},bind:function(c){Y(a,c)}}}(Z);}).call(this);(function(){window._skwEvts=[];})();(function(){window.google.erd={jsr:1,bv:1655,sd:true,de:true};})();(function(){var sdo=false;var mei=10;
# var h=this||self;var k,l=null!=(k=h.mei)?k:1,n,p=null!=(n=h.sdo)?n:!0,q=0,r,t=google.erd,v=t.jsr;google.ml=function(a,b,d,m,e){e=void 0===e?2:e;b&&(r=a&&a.message);if(google.dl)return google.dl(a,e,d),null;if(0>v){window.console&&console.error(a,d);if(-2===v)throw a;b=!1}else b=!a||!a.message||"Error loading script"===a.message||q>=l&&!m?!1:!0;if(!b)return null;q++;d=d||{};b=encodeURIComponent;var c="/gen_204?atyp=i&ei="+b(google.kEI);google.kEXPI&&(c+="&jexpid="+b(google.kEXPI));c+="&srcpg="+b(google.sn)+"&jsr="+b(t.jsr)+"&bver="+b(t.bv);var f=a.lineNumber;void 0!==f&&(c+="&line="+f);var g=
# a.fileName;g&&(0<g.indexOf("-extension:/")&&(e=3),c+="&script="+b(g),f&&g===window.location.href&&(f=document.documentElement.outerHTML.split("\n")[f],c+="&cad="+b(f?f.substring(0,300):"No script found.")));c+="&jsel="+e;for(var u in d)c+="&",c+=b(u),c+="=",c+=b(d[u]);c=c+"&emsg="+b(a.name+": "+a.message);c=c+"&jsst="+b(a.stack||"N/A");12288<=c.length&&(c=c.substr(0,12288));a=c;m||google.log(0,"",a);return a};window.onerror=function(a,b,d,m,e){r!==a&&(a=e instanceof Error?e:Error(a),void 0===d||"lineNumber"in a||(a.lineNumber=d),void 0===b||"fileName"in a||(a.fileName=b),google.ml(a,!1,void 0,!1,"SyntaxError"===a.name||"SyntaxError"===a.message.substring(0,11)||0<a.message.indexOf("Script error")?2:0));r=null;p&&q>=l&&(window.onerror=null)};})();
# var h="function"==typeof Object.defineProperties?Object.defineProperty:function(a,b,c){if(a==Array.prototype||a==Object.prototype)return a;a[b]=c.value;return a},k=function(a){a=["object"==typeof globalThis&&globalThis,a,"object"==typeof window&&window,"object"==typeof self&&self,"object"==typeof global&&global];for(var b=0;b<a.length;++b){var c=a[b];if(c&&c.Math==Math)return c}throw Error("a");},l=k(this),m=function(a,b){if(b)a:{var c=l;a=a.split(".");for(var d=0;d<a.length-1;d++){var e=a[d];if(!(e in
# c))break a;c=c[e]}a=a[a.length-1];d=c[a];b=b(d);b!=d&&null!=b&&h(c,a,{configurable:!0,writable:!0,value:b})}};m("String.prototype.startsWith",function(a){return a?a:function(b,c){if(null==this)throw new TypeError("The 'this' value for String.prototype.startsWith must not be null or undefined");if(b instanceof RegExp)throw new TypeError("First argument to String.prototype.startsWith must not be a regular expression");var d=this+"";b+="";var e=d.length,g=b.length;c=Math.max(0,Math.min(c|0,d.length));for(var f=0;f<g&&c<e;)if(d[c++]!=b[f++])return!1;return f>=g}});google.arwt=function(a){a.href=document.getElementById(a.id.substring(a.id.startsWith("vcs")?3:1)).href;return!0};(function(){google.eufsv=true;(function(){
# var e=function(a){var c=a.url;a=a.l;this.i=c;this.o=a;a=/[?&]dsh=1(&|$)/.test(c);this.h=!a&&/[?&]ae=1(&|$)/.test(c);this.s=!a&&/[?&]ae=2(&|$)/.test(c);if((this.g=/[?&]adurl=([^&]*)/.exec(c))&&this.g[1]){try{var b=decodeURIComponent(this.g[1])}catch(f){b=null}this.j=b}},l=function(a,c){return a.h&&a.j||a.s?1==c?a.h?a.j:k(a,"&dct=1"):2==c?k(a,"&ri=2"):k(a,"&ri=16"):a.i},k=function(a,c){return a.g?a.i.slice(0,a.g.index)+c+a.i.slice(a.g.index):a.i+c},n=function(a){a=a.o;var c=encodeURIComponent,b="";a.platform&&(b+="&uap="+c(a.platform));a.platformVersion&&(b+="&uapv="+c(a.platformVersion));a.uaFullVersion&&(b+="&uafv="+c(a.uaFullVersion));a.architecture&&(b+="&uaa="+c(a.architecture));a.model&&(b+="&uam="+c(a.model));a.bitness&&(b+="&uab="+c(a.bitness));a.fullVersionList&&(b+="&uafvl="+c(a.fullVersionList.map(function(f){return c(f.brand)+";"+c(f.version)}).join("|")));"undefined"!==typeof a.wow64&&(b+="&uaw="+Number(a.wow64));return b};var r=function(a,c){this.g=c===q?a:""};r.prototype.toString=function(){return this.g.toString()};r.prototype.i=!0;r.prototype.h=function(){return this.g.toString()};var t=function(a){return a instanceof r&&a.constructor===r?a.g:"type_error:SafeUrl"},v=/^(?:(?:https?|mailto|ftp):|[^:/?#]*(?:[/?#]|$))/i,q={},w=new r("about:invalid#zClosurez",q);var x=/^((market|itms|intent|itms-appss):\/\/)/i;
# var A;try{new URL("s://g"),A=!0}catch(a){A=!1}var B=A;var C=function(a){this.A=a};function D(a){return new C(function(c){return c.substr(0,a.length+1).toLowerCase()===a+":"})}var E=[D("data"),D("http"),D("https"),D("mailto"),D("ftp"),new C(function(a){return/^[^:]*([/?#]|$)/.test(a)})];function F(a,c){var b=/[?&]adurl=/.exec(c);return b?""+c.slice(0,b.index+1)+a+"&"+c.slice(b.index+1):""+c+(-1===c.indexOf("?")?"?":"&")+a}function G(a,c){a=a.href;var b=/[?&]nis=([^&]*)/.exec(a);return b&&b[1]===c?a:b?a.replace(/([?&])nis=([^&]*)/,function(f,h){return h+"nis="+c}):F("nis="+c,a)}function H(){var a;return!(null==(a=document.featurePolicy)||!a.allowedFeatures().includes("attribution-reporting"))};var I=new function(){var a={v:google.eufsv},c=this;a=(void 0===a?{}:a).v;this.g=null;a&&navigator.userAgentData&&navigator.userAgentData.getHighEntropyValues&&(a=navigator.userAgentData.getHighEntropyValues("platform platformVersion uaFullVersion architecture model bitness fullVersionList wow64".split(" ")))&&a.then(function(b){c.g=b})};google.ausb=function(a){if(!a)return google.ml(Error("a"),!1),!0;if(a.hasAttribute("data-impdclcc"))try{var c=a.hasAttribute("attributionsourceid")&&a.hasAttribute("attributeon")&&a.hasAttribute("attributiondestination")?"2":a.hasAttribute("attributionsrc")?H()?"6":"5":H()?"7":"8";var b=G(a,c);var f=void 0===f?E:f;a:{c=f;c=void 0===c?E:c;for(f=0;f<c.length;++f){var h=c[f];if(h instanceof C&&h.A(b)){var g=new r(b,q);break a}}g=void 0}var d=g||w;if(d instanceof r)var m=t(d);else{b:if(B){try{var J=new URL(d)}catch(y){var p=
# "https:";break b}p=J.protocol}else c:{var z=document.createElement("a");try{z.href=d}catch(y){p=void 0;break c}var u=z.protocol;p=":"===u||""===u?"https:":u}m="javascript:"!==p?d:void 0}d=m;void 0!==d&&(a.href=d)}catch(y){}a.getAttribute("data-sbv2")&&(a.hasAttribute("data-ohref")?d=a.getAttribute("data-ohref"):(d=a.href,a.setAttribute("data-ohref",d)),g=d,b={l:I.g},b=new e({url:g,l:(void 0===b?{}:b).l}),b.h&&b.j||b.s?navigator.sendBeacon?(g=navigator,h=g.sendBeacon,m="&act=1&ri=1",b.h&&b.o&&(m+=
# n(b)),b=h.call(g,k(b,m),"")?l(b,1):l(b,2)):b=l(b,0):b=g,b=b instanceof r||!x.test(b)?b:new r(b,q),d!=b&&(b instanceof r?d=b:(d=b,d instanceof r||(d="object"==typeof d&&d.i?d.h():String(d),v.test(d)||(d="about:invalid#zClosurez"),d=new r(d,q))),a.href=t(d)));return!0};}).call(this);})();(function(){
# var c=this||self;function d(a){for(;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName)return a;return null}function e(a){if(a=d(a.target))switch(a.getAttribute("data-agdh")){case "arwt":google.arwt(a);break;case "fvd3vc":c.J4LCUe(a);break;case "EdKoMd":(0,google.f.LmvwCb)(a)}return!0};window.document.documentElement.addEventListener("mousedown",e,!0);window.document.documentElement.addEventListener("touchstart",e,!0);window.document.documentElement.addEventListener("click",function(a){var b=d(a.target);if(b)switch(b.getAttribute("data-agch")){case "ausb":google.ausb(b);break;case "HJ3bqe":window.YvikHb(a,b);break;case "cqUJI":(0,google.f.DfwaCb)(b)}return!0},!0);}).call(this);/*CSH_START*//*CSH_END*/
# </script><style>html,body,h1,input,select{font-family:arial,sans-serif}body,h1{font-size:14px;}h1{font-weight:normal;margin:0;padding:0}h3{font-weight:normal;margin:0;padding:0;font-size:20px;line-height:1.3}body{margin:0;background:#fff;color:#202124;}a{color:#1a0dab;text-decoration:none;-webkit-tap-highlight-color:rgba(0,0,0,.10)}a:visited{color:#681da8}a:hover{text-decoration:underline}a:hover h3{text-decoration:underline}a.a-no-hover-decoration:hover,a.a-no-hover-decoration:hover h3{text-decoration:none}cite,cite a:link,cite a:visited{color:#202124;font-style:normal}button{margin:0}ol li{list-style:none}ol,ul,li{margin:0;padding:0}input{font-size:14px}em{font-weight:bold;font-style:normal}.aCOpRe em,.yXK7lf em{color:#5f6368;}.aCOpRe a em{color:inherit}@-webkit-keyframes qs-timer {0%{}}html:not(.zAoYTe) [tabindex]{outline:0}html:not(.zAoYTe) [href],html:not(.zAoYTe) button,html:not(.zAoYTe) iframe,html:not(.zAoYTe) input,html:not(.zAoYTe) select,html:not(.zAoYTe) textarea{outline:0}html:not(.zAoYTe) .F0azHf{outline:0}.z1asCe{display:inline-block;fill:currentColor;height:24px;line-height:24px;position:relative;width:24px}.z1asCe svg{display:block;height:100%;width:100%}.iUh30{font-size:14px;line-height:1.3}.f{color:#70757a;line-height:1.58}.std,.g{font-family:arial,sans-serif;font-size:14px;}.g{line-height:1.58;text-align:left}.g,.KIy09e{width:600px;margin-top:0;margin-bottom:30px;}.iUh30{padding-top:1px;}.FzvWSb{margin-bottom:5px}.vk_c{position:relative;padding:20px 16px 24px;background-color:#fff;width:618px;}#rhs .fIcnad{border:none;margin-left:0}.vk_c,#rhs .fIcnad{border-radius:8px;border:1px solid #dadce0;box-shadow:none}.vk_c .vk_c{border-radius:0;box-shadow:none;background-color:transparent;border:0;box-shadow:none;margin:0;padding:0;position:static}.vkc_np{margin-left:-16px;margin-right:-16px}.WIDPrb{padding-left:16px}.iiFzhd{padding-right:16px}.vk_arc{border-top:1px solid #dadce0;cursor:pointer;height:0;margin-bottom:-19px;overflow:hidden;padding:20px 0;text-align:center}.vk_ard{top:-11px}.vk_aru{bottom:-6px}.vk_ard,.vk_aru{background-color:#ebebeb;margin-left:auto;margin-right:auto;position:relative;height:6px;width:64px}.vk_ard:after,.vk_ard:before,.vk_aru:after,.vk_aru:before{content:' ';height:0;left:0;position:absolute;width:0;border-left:32px solid rgba(255,255,255,0);border-right:32px solid rgba(255,255,255,0)}.vk_ard:before{border-top:16px solid #ebebeb;top:6px}.vk_aru:before{border-bottom:16px solid #ebebeb;bottom:6px}.vk_ard:after{top:0;border-top:16px solid #fff}.vk_aru:after{bottom:0;border-bottom:16px solid #fff}.jC7Epd.vk_ard,.jC7Epd.vk_aru{background-color:#202124}.jC7Epd.vk_ard:before{border-top-color:#202124}.jC7Epd.vk_aru:before{border-bottom-color:#202124}.xpdclps,.xpdxpnd{overflow:hidden}.xpdclps,.xpdxpnd{-webkit-transition:max-height 0.3s}.xpdxpnd,.xpdopen .xpdclps,.xpdopen .xpdxpnd.xpdnoxpnd{max-height:0}.xpdopen .xpdxpnd{max-height:none}.xpdopen .xpdbox .xpdxpnd,.xpdopen .xpdbox.xpdopen .xpdclps{max-height:0}.xpdopen .xpdbox.xpdopen .xpdxpnd,.xpdopen .xpdbox .xpdclps{max-height:none}.xpdclose .k5nfEc{display:none}.fp-i .SzDvzc{display:none}.fp-f{bottom:0;height:auto;left:0;position:fixed !important;right:0;top:0;width:auto;z-index:127}.fp-h:not(.fp-nh):not(.goog-modalpopup-bg):not(.goog-modalpopup){display:none !important}.fp-zh.fp-h:not(.fp-nh):not(.goog-modalpopup-bg):not(.goog-modalpopup){display:block !important;height:0;overflow:hidden;transform:translate3d(0,0,0);transform:translate3d(0,0,0)}.fp-i .fp-c{display:block;min-height:100vh}li.fp-c{list-style:none}.fp-w{box-sizing:border-box;left:0;margin-left:auto;margin-right:auto;max-width:1217px;right:0}.ellip{overflow:hidden;text-overflow:ellipsis;white-space:nowrap}.tF2Cxc{position:relative}.Jb0Zif .BDNLRc{margin:16px 16px -11px}.RUXr2d{display:inline}.MTB56{margin-right:12px;vertical-align:middle}.Pthbuf{display:flex;align-items:center}.m164Nd{vertical-align:middle;display:inline-block}.qpGQpf{clear:both;padding-top:6px}.tcPEUc .MTB56{di ...
# (function(){if(document.fonts&&document.fonts.load)for(var d=l.split(","),b={},c=0,a=void 0;a=d[c];++c)b[a]||(b[a]=!0,document.fonts.load(a+" 10pt "+font).catch(function(){}))})();})();</script><h1 class="Uo8X3b OhScic zsYMMe">Toegankelijkheidslinks</h1><div class="wYq63b" jscontroller="EufiNb"><div class="S6VXfe"><a class="gyPpGe" data-ved="0ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4Q67oDCAU" jsaction="i3viod" jsname="BKxS1e" role="link" tabindex="0">Naar hoofdcontent</a><a class="gyPpGe" href="https://support.google.com/websearch/answer/181196?hl=nl-BE" jsname="KI37ad" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;url=https://support.google.com/websearch/answer/181196%3Fhl%3Dnl-BE&amp;ved=0ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4QwcMDCAY">Hulp bij toegankelijkheid</a><div data-async-context="async_id:duf3-78;authority:0;card_id:;entry_point:0;feature_id:;ftoe:0;header:0;is_jobs_spam_form:0;open:0;preselect_answer_index:-1;suggestions:;suggestions_subtypes:;suggestions_types:;surface:0;title:;type:78"><div jsaction="rcuQ6b:npT2md" jscontroller="EkevXb" style="display:none"></div><div class="yp" data-async-context-required="type,open,feature_id,async_id,entry_point,authority,card_id,ftoe,title,header,suggestions,surface,suggestions_types,suggestions_subtypes,preselect_answer_index,is_jobs_spam_form" data-async-type="duffy3" data-jiis="up" data-ved="0ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4Q-0EIBw" id="duf3-78"></div><a class="gyPpGe" data-async-trigger="duf3-78" jsaction="trigger.szjOR" jsname="JUypV" role="link" tabindex="0">Feedback over toegankelijkheid</a></div></div></div><div aria-label="Voordat je verdergaat naar Google Zoeken" aria-modal="true" class="HTjtHe" data-ved="0ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4QhJAHCAg" id="xe7COe" role="dialog" tabindex="0"><div class="vUd4jb" data-ved="0ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4QhZAHCAk" id="KjcHPc"></div><div data-ved="0ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4QkZAHCAo" id="rGDSnb"></div><div class="jw8mI"><div aria-live="polite" class="Hbu4y" id="sNCQb"></div><span><div class="KxvlWc" id="CXQnmb"><div class="HOq4He wX2YHc"><div class="dbsFrd"><div><div class="IczZ4b" id="uMousc"><img alt="Google" class="qIBnUc" src="https://fonts.gstatic.com/s/i/productlogos/googleg/v6/24px.svg"/><div class="IXMIVb"><div class="tn3Mmd"><button aria-disabled="false" aria-expanded="false" aria-haspopup="true" aria-label="Taal selecteren, nl" class="neDYw tHlp8d" data-ved="0ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4Qi5AHCAs" id="vc3jof"><div class="QS5gu ud1jmf" role="none"><div class="V5OCtd"><svg class="Hv5UEb" height="30" viewbox="0 0 30 30" width="30" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M2.5 15C2.5 8.1 8.0875 2.5 14.9875 2.5C21.9 2.5 27.5 8.1 27.5 15C27.5 21.9 21.9 27.5 14.9875 27.5C8.0875 27.5 2.5 21.9 2.5 15ZM19.9625 10H23.65C22.45 7.9375 20.5375 6.3375 18.2375 5.55C18.9875 6.9375 19.5625 8.4375 19.9625 10ZM15 5.05C16.0375 6.55 16.85 8.2125 17.3875 10H12.6125C13.15 8.2125 13.9625 6.55 15 5.05ZM5 15C5 15.8625 5.125 16.7 5.325 17.5H9.55C9.45 16.675 9.375 15.85 9.375 15C9.375 14.15 9.45 13.325 9.55 12.5H5.325C5.125 13.3 5 14.1375 5 15ZM6.35 20H10.0375C10.4375 21.5625 11.0125 23.0625 11.7625 24.45C9.4625 23.6625 7.55 22.075 6.35 20ZM6.35 10H10.0375C10.4375 8.4375 11.0125 6.9375 11.7625 5.55C9.4625 6.3375 7.55 7.925 6.35 10ZM15 24.95C13.9625 23.45 13.15 21.7875 12.6125 20H17.3875C16.85 21.7875 16.0375 23.45 15 24.95ZM11.875 15C11.875 15.85 11.9625 16.675 12.075 17.5H17.925C18.0375 16.675 18.125 15.85 18.125 15C18.125 14.15 18.0375 13.3125 17.925 12.5H12.075C11.9625 13.3125 11.875 14.15 11.875 15ZM18.2375 24.45C18.9875 23.0625 19.5625 21.5625 19.9625 20H23.65C22.45 22.0625 20.5375 23.6625 18.2375 24.45ZM20.625 15C20.625 15.85 20.55 16.675 20.45 17.5H24.675C24.875 16.7 25 15.8625 25 15C25 14.1375 24.875 13.3 24.675 12.5H20.45C20.55 13.325 20.625 14.15 20.625 15Z" fill="currentColor" fill-rule="evenodd"></path></svg><div class="FYXSad">nl</div></div></div></button><div class="cGY8if" data-ved="0ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4QjJA ...
# var aa=function(a){var b=0;return function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}}},ba="function"==typeof Object.defineProperties?Object.defineProperty:function(a,b,c){if(a==Array.prototype||a==Object.prototype)return a;a[b]=c.value;return a},ca=function(a){a=["object"==typeof globalThis&&globalThis,a,"object"==typeof window&&window,"object"==typeof self&&self,"object"==typeof global&&global];for(var b=0;b<a.length;++b){var c=a[b];if(c&&c.Math==Math)return c}throw Error("a");},da=ca(this),m=function(a,b){if(b)a:{var c=da;a=a.split(".");for(var d=0;d<a.length-1;d++){var e=a[d];if(!(e in c))break a;c=c[e]}a=a[a.length-1];d=c[a];b=b(d);b!=d&&null!=b&&ba(c,a,{configurable:!0,writable:!0,value:b})}};m("Symbol",function(a){if(a)return a;var b=function(f,g){this.g=f;ba(this,"description",{configurable:!0,writable:!0,value:g})};b.prototype.toString=function(){return this.g};var c="jscomp_symbol_"+(1E9*Math.random()>>>0)+"_",d=0,e=function(f){if(this instanceof e)throw new TypeError("Symbol is not a constructor");return new b(c+(f||"")+"_"+d++,f)};return e});m("Symbol.iterator",function(a){if(a)return a;a=Symbol("Symbol.iterator");for(var b="Array Int8Array Uint8Array Uint8ClampedArray Int16Array Uint16Array Int32Array Uint32Array Float32Array Float64Array".split(" "),c=0;c<b.length;c++){var d=da[b[c]];"function"===typeof d&&"function"!=typeof d.prototype[a]&&ba(d.prototype,a,{configurable:!0,writable:!0,value:function(){return ea(aa(this))}})}return a});var ea=function(a){a={next:a};a[Symbol.iterator]=function(){return this};return a},fa="function"==typeof Object.create?Object.create:function(a){var b=function(){};b.prototype=a;return new b},ha;if("function"==typeof Object.setPrototypeOf)ha=Object.setPrototypeOf;else{var ia;a:{var ja={a:!0},ka={};try{ka.__proto__=ja;ia=ka.a;break a}catch(a){}ia=!1}ha=ia?function(a,b){a.__proto__=b;if(a.__proto__!==b)throw new TypeError(a+" is not extensible");return a}:null}
# var la=ha,p=function(a,b){a.prototype=fa(b.prototype);a.prototype.constructor=a;if(la)la(a,b);else for(var c in b)if("prototype"!=c)if(Object.defineProperties){var d=Object.getOwnPropertyDescriptor(b,c);d&&Object.defineProperty(a,c,d)}else a[c]=b[c];a.Ha=b.prototype},ma=function(a,b){a instanceof String&&(a+="");var c=0,d=!1,e={next:function(){if(!d&&c<a.length){var f=c++;return{value:b(f,a[f]),done:!1}}d=!0;return{done:!0,value:void 0}}};e[Symbol.iterator]=function(){return e};return e};m("Number.isNaN",function(a){return a?a:function(b){return"number"===typeof b&&isNaN(b)}});m("Array.prototype.keys",function(a){return a?a:function(){return ma(this,function(b){return b})}});var q=this||self;var na={};function r(){throw Error("b");}function oa(a,b){b=String.fromCharCode.apply(null,b);return null==a?b:a+b}var t=void 0,pa,qa="undefined"!==typeof TextDecoder;var ra=String.prototype.trim?function(a){return a.trim()}:function(a){return/^[\s\xa0]*([\s\S]*?)[\s\xa0]*$/.exec(a)[1]},sa=function(a,b){return a<b?-1:a>b?1:0};function u(){var a=q.navigator;return a&&(a=a.userAgent)?a:""}function v(a){return-1!=u().indexOf(a)};function ta(){return v("Safari")&&!(ua()||v("Coast")||v("Opera")||v("Edge")||v("Edg/")||v("OPR")||v("Firefox")||v("FxiOS")||v("Silk")||v("Android"))}function ua(){return(v("Chrome")||v("CriOS"))&&!v("Edge")||v("Silk")}function va(){return v("Android")&&!(ua()||v("Firefox")||v("FxiOS")||v("Opera")||v("Silk"))};var wa=Array.prototype.indexOf?function(a,b){return Array.prototype.indexOf.call(a,b,void 0)}:function(a,b){if("string"===typeof a)return"string"!==typeof b||1!=b.length?-1:a.indexOf(b,0);for(var c=0;c<a.length;c++)if(c in a&&a[c]===b)return c;return-1},xa=Array.prototype.forEach?function(a,b,c){Array.prototype.forEach.call(a,b,c)}:function(a,b,c){for(var d=a.length,e="string"===typeof a?a.split(""):a,f=0;f<d;f++)f in e&&b.call(c,e[f],f,a)},ya=Array.prototype.every?function(a,b){return Array.prototype.every.call(a,b,void 0)}:function(a,b){for(var c=a.length,d="string"===typeof a?a.split(""):a,e=0;e<c;e++)if(e in d&&!b.call(void 0,d[e],e,a))return!1;return!0};var Aa=function(a,b){var c=za;return Object.prototype.hasOwnProperty.call(c,a)?c[a]:c[a]=b(a)};var Ba=v("Opera"),w=v("Trident")||v("MSIE"),Ca=v("Edge"),Da=v("Gecko")&&!(-1!=u().toLowerCase().indexOf("webkit")&&!v("Edge"))&&!(v("Trident")||v("MSIE"))&&!v("Edge"),Ea=-1!=u().toLowerCase().indexOf("webkit")&&!v("Edge"),Fa;a:{var Ga="",Ha=function(){var a=u();if(Da)return/rv:([^\);]+)(\)|;)/.exec(a);if(Ca)return/Edge\/([\d\.]+)/.exec(a);if(w)return/\b(?:MSIE|rv)[:]([^\);]+)(\)|;)/.exec(a);if(Ea)return/WebKit\/(\S+)/.exec(a);if(Ba)return/(?:Version)[ \/]?(\S+)/.exec(a)}();Ha&&(Ga=Ha?Ha[1]:"");if(w){var x,Ia=q.document;x=Ia?Ia.documentMode:void 0;if(null!=x&&x>parseFloat(Ga)){Fa=String(x);break a}}Fa=Ga}
# var Ja=Fa,za={},Ka=function(a){return Aa(a,function(){for(var b=0,c=ra(String(Ja)).split("."),d=ra(String(a)).split("."),e=Math.max(c.length,d.length),f=0;0==b&&f<e;f++){var g=c[f]||"",h=d[f]||"";do{g=/(\d*)(\D*)(.*)/.exec(g)||["","","",""];h=/(\d*)(\D*)(.*)/.exec(h)||["","","",""];if(0==g[0].length&&0==h[0].length)break;b=sa(0==g[1].length?0:parseInt(g[1],10),0==h[1].length?0:parseInt(h[1],10))||sa(0==g[2].length,0==h[2].length)||sa(g[2],h[2]);g=g[3];h=h[3]}while(0==b)}return 0<=b})};va();ua();ta();var La={},y=null,Na=function(a){var b;void 0===b&&(b=0);Ma();b=La[b];for(var c=Array(Math.floor(a.length/3)),d=b[64]||"",e=0,f=0;e<a.length-2;e+=3){var g=a[e],h=a[e+1],k=a[e+2],l=b[g>>2];g=b[(g&3)<<4|h>>4];h=b[(h&15)<<2|k>>6];k=b[k&63];c[f++]=""+l+g+h+k}l=0;k=d;switch(a.length-e){case 2:l=a[e+1],k=b[(l&15)<<2]||d;case 1:a=a[e],c[f]=""+b[a>>2]+b[(a&3)<<4|l>>4]+k+d}return c.join("")},Qa=function(){var a=[];Oa(Pa,function(b){a.push(b)});return a},Ra=function(a){var b=a.length,c=3*b/4;c%3?c=Math.floor(c):-1!="=.".indexOf(a[b-1])&&(c=-1!="=.".indexOf(a[b-2])?c-2:c-1);var d=new Uint8Array(c),e=0;Oa(a,function(f){d[e++]=f});return e!==c?d.subarray(0,e):d},Oa=function(a,b){function c(k){for(;d<a.length;){var l=a.charAt(d++),n=y[l];if(null!=n)return n;if(!/^[\s\xa0]*$/.test(l))throw Error("c`"+l);}return k}Ma();for(var d=0;;){var e=c(-1),f=c(0),g=c(64),h=c(64);if(64===h&&-1===e)break;b(e<<2|f>>4);64!=g&&(b(f<<4&240|g>>2),64!=h&&b(g<<6&192|h))}},Ma=function(){if(!y){y={};for(var a="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789".split(""),b=["+/=","+/","-_=","-_.","-_"],c=0;5>c;c++){var d=a.concat(b[c].split(""));La[c]=d;for(var e=0;e<d.length;e++){var f=d[e];void 0===y[f]&&(y[f]=e)}}}};var Sa="undefined"!==typeof Uint8Array,Ta,z={};var Ua,A=function(a,b){if(b!==z)throw Error("d");this.P=a;if(null!=a&&0===a.length)throw Error("e");},Va=function(){return Ua||(Ua=new A(null,z))};A.prototype.ka=function(){return null==this.P};var B="function"===typeof Symbol&&"symbol"===typeof Symbol()?Symbol(void 0):void 0;function C(a,b){Object.isFrozen(a)||(B?a[B]|=b:void 0!==a.A?a.A|=b:Object.defineProperties(a,{A:{value:b,configurable:!0,writable:!0,enumerable:!1}}))}function Wa(a,b){Object.isExtensible(a)&&(B?a[B]&&(a[B]&=~b):void 0!==a.A&&(a.A&=~b))}function D(a){var b;B?b=a[B]:b=a.A;return null==b?0:b}
# function Xa(a,b){B?a[B]=b:void 0!==a.A?a.A=b:Object.defineProperties(a,{A:{value:b,configurable:!0,writable:!0,enumerable:!1}})}function Ya(a){C(a,1);return a}function Za(a){C(a,17);return a}function E(a){return a?!!(D(a)&2):!1}function $a(a){if(!Array.isArray(a))throw Error("f");Wa(a,16)};var ab={};function bb(a){return null!==a&&"object"===typeof a&&!Array.isArray(a)&&a.constructor===Object}var cb=Object.freeze(Ya([])),F=function(a){if(E(a.j))throw Error("g");},db="undefined"!=typeof Symbol&&"undefined"!=typeof Symbol.hasInstance;function eb(a){return{value:a,configurable:!1,writable:!1,enumerable:!1}};function fb(a,b,c){var d=!1;if(null!=a&&"object"===typeof a&&!(d=Array.isArray(a))&&a.sa===ab)return a;if(d)return new b(a);if(c)return new b};function gb(a){switch(typeof a){case "number":return isFinite(a)?a:String(a);case "object":if(a&&!Array.isArray(a)){if(Sa&&null!=a&&a instanceof Uint8Array)return Na(a);if(a instanceof A){var b=a.P;return null==b?"":"string"===typeof b?b:a.P=Na(b)}}}return a};function hb(a,b,c){if(null!=a){if(Array.isArray(a))a=ib(a,b,c);else if(bb(a)){var d={},e;for(e in a)d[e]=hb(a[e],b,c);a=d}else a=b(a);return a}}function ib(a,b,c){var d=Array.prototype.slice.call(a);c(a,d);for(a=0;a<d.length;a++)d[a]=hb(d[a],b,c);return d}function jb(a){if(a.sa===ab)return a.toJSON();a=gb(a);return Array.isArray(a)?ib(a,jb,kb):a}function kb(){};var G=function(a,b,c){return-1===b?null:b>=a.D?a.o?a.o[b]:void 0:(void 0===c?0:c)&&a.o&&(c=a.o[b],null!=c)?c:a.j[b+a.C]},H=function(a,b,c,d,e){d=void 0===d?!1:d;(void 0===e?0:e)||F(a);a.ra&&(a.ra=void 0);b>=a.D||d?(a.o||(a.o=a.j[a.D+a.C]={}))[b]=c:(void 0!==a.o&&a.D>=a.j.length?(d=a.j.length-1,e=b+a.C,e>=d?(a.j[d]=void 0,a.j[e]=c,a.j.push(a.o)):a.j[e]=c):a.j[b+a.C]=c,void 0!==a.o&&b in a.o&&delete a.o[b])};function lb(a,b,c,d,e,f){if(a=a.g&&a.g[c]){d=f.ha?Ya(a.slice()):a;F(b);if(null!=d){e=Ya([]);f=!1;for(a=0;a<d.length;a++)e[a]=d[a].j,f=f||E(e[a]);b.g||(b.g={});b.g[c]=d;d=e;f?Wa(d,8):C(d,8)}else b.g&&(b.g[c]=void 0),e=cb;H(b,c,e)}else Sa&&d instanceof Uint8Array?e=d.length?new A(new Uint8Array(d),z):Va():(Array.isArray(d)&&(e?C(d,2):d&&D(d)&1&&f.ha?(e=Array.prototype.slice.call(d),Xa(e,(D(d)|0)&-51),d=e):$a(d)),e=d),H(b,c,e)};var I=function(a,b,c){a||(a=mb);mb=null;var d=this.constructor.g||0,e=0<d,f=this.constructor.h,g=!1;if(!a){var h=f?[f]:[];C(h,48);a=h;h=!0}else if(h=!!(D(a)&16))g=D(a),Xa(a,g|32),g=!!(g&32);e&&0<a.length&&bb(a[a.length-1])&&"g"in a[a.length-1]&&(d=0);this.C=(f?0:-1)-d;this.g=void 0;this.j=a;a:{f=this.j.length;d=f-1;if(f&&(f=this.j[d],bb(f))){this.o=f;b=Object.keys(f);0<b.length&&ya(b,isNaN)?this.D=Number.MAX_VALUE:this.D=d-this.C;break a}void 0!==b&&-1<b?(this.D=Math.max(b,d+1-this.C),this.o=void 0):this.D=Number.MAX_VALUE}if(!e&&this.o&&"g"in this.o)throw Error("j");if(c)for(e=h&&!g?Za:Ya,b=0;b<c.length;b++)h=c[b],(g=G(this,h))?Array.isArray(g)&&e(g):H(this,h,cb,!1,!0)};I.prototype.toJSON=function(){return ib(this.j,jb,kb)};I.prototype.F=function(){return E(this.j)};I.prototype.K=function(){if(E(this.j)){var a={ha:!0};var b=E(this.j);if(b&&!a.ha)throw Error("h");b||$a(this.j);var c=new this.constructor;this.Y&&(c.Y=this.Y.slice());for(var d=this.j,e=0;e<d.length;e++){var f=d[e];if(e===d.length-1&&bb(f))for(var g in f){var h=+g;Number.isNaN(h)?(c.o||(c.o=c.j[c.D+c.C]={}))[g]=f[g]:lb(this,c,h,f[g],b,a)}else lb(this,c,e-this.C,f,b,a)}c.ra=this;a=c}else a=this;return a};I.prototype.sa=ab;I.prototype.toString=function(){return this.j.toString()};var mb;function nb(a){if("string"===typeof a)return{buffer:Ra(a),F:!1};if(Array.isArray(a))return{buffer:new Uint8Array(a),F:!1};if(a.constructor===Uint8Array)return{buffer:a,F:!1};if(a.constructor===ArrayBuffer)return{buffer:new Uint8Array(a),F:!1};if(a.constructor===A){if(z!==z)throw Error("d");var b=a.P;b=null==b||Sa&&null!=b&&b instanceof Uint8Array?b:"string"===typeof b?Ra(b):null;return{buffer:(null==b?b:a.P=b)||Ta||(Ta=new Uint8Array(0)),F:!0}}if(a instanceof Uint8Array)return{buffer:new Uint8Array(a.buffer, ...
# function Hb(a,b){var c=a[b];"function"==typeof c&&0===c.length&&(c=c(),a[b]=c);return Array.isArray(c)&&(Ib in c||Jb in c||0<c.length&&"function"==typeof c[0])?c:void 0}var Jb=Symbol(),Ib=Symbol();function Kb(a,b){a[0]=b}function Lb(a,b,c,d){var e=c.aa;a[b]=d?function(f,g,h){return e(f,g,h,d)}:e}function Mb(a,b,c,d,e){var f=c.aa,g=Cb(d),h=Db(d).ia;a[b]=function(k,l,n){return f(k,l,n,h,g,e)}}function Nb(a,b,c,d,e,f,g){var h=c.aa,k=Bb(d,e,f);a[b]=function(l,n,L){return h(l,n,L,d,k,g)}}
# function Db(a){var b=a[Ib];if(b)return b;b=a[Ib]={};var c=Kb,d=Lb,e=Mb,f=Nb;b.ia=a[0];var g=1;if(a.length>g&&"number"!==typeof a[g]){var h=a[g++];c(b,h)}for(;g<a.length;){c=a[g++];for(var k=g+1;k<a.length&&"number"!==typeof a[k];)k++;h=a[g++];k-=g;switch(k){case 0:d(b,c,h);break;case 1:(k=Hb(a,g))?(g++,e(b,c,h,k)):d(b,c,h,a[g++]);break;case 2:k=b;var l=g++;l=Hb(a,l);e(k,c,h,l,a[g++]);break;case 3:f(b,c,h,a[g++],a[g++],a[g++]);break;case 4:f(b,c,h,a[g++],a[g++],a[g++],a[g++]);break;default:throw Error("t`"+
# k);}}Ib in a&&Jb in a&&(a.length=0);return b}function Eb(a,b,c){for(;wb(b)&&4!=b.h;){var d=b.l,e=c[d];if(!e){var f=c[0];f&&(f=f[d])&&(e=c[d]=Gb(f))}if(!e||!e(b,a,d)){e=b;d=a;f=e.i;xb(e);var g=e;if(!g.ja){e=g.g.g-f;g.g.g=f;g=g.g;if(0==e)e=Va();else{f=rb(g,e);if(g.W&&g.s)e=g.i.subarray(f,f+e);else{g=g.i;var h=f;e=f+e;e=h===e?Ta||(Ta=new Uint8Array(0)):ob?g.slice(h,e):new Uint8Array(g.subarray(h,e))}e=0==e.length?Va():new A(e,z)}(f=d.Y)?f.push(e):d.Y=[e]}}}return a}
# function N(a,b){return{aa:a,Ia:b}}
# var Ob=N(function(a,b,c){if(0!==a.h)return!1;var d=a.g,e=0,f=a=0,g=d.i,h=d.g;do{var k=g[h++];e|=(k&127)<<f;f+=7}while(32>f&&k&128);32<f&&(a|=(k&127)>>4);for(f=3;32>f&&k&128;f+=7)k=g[h++],a|=(k&127)<<f;J(d,h);if(128>k){d=e>>>0;k=a>>>0;if(a=k&2147483648)d=~d+1>>>0,k=~k>>>0,0==d&&(k=k+1>>>0);d=4294967296*k+(d>>>0)}else throw Error("p");a=a?-d:d;F(b);0!==a?H(b,c,a):H(b,c,void 0,!1);return!0},function(a,b,c){a.i(c,G(b,c))}),Pb=N(function(a,b,c){if(0!==a.h)return!1;a=K(a.g);F(b);0!==a?H(b,c,a):H(b,c,void 0,!1);return!0},function(a,b,c){a.h(c,G(b,c))}),Qb=N(function(a,b,c){if(2!==a.h)return!1;var d=K(a.g)>>>0;a=a.g;var e=rb(a,d);a=a.i;if(qa){var f=a,g;(g=pa)||(g=pa=new TextDecoder("utf-8",{fatal:!0}));a=e+d;f=0===e&&a===f.length?f:f.subarray(e,a);try{var h=g.decode(f)}catch(L){if(void 0===t){try{g.decode(new Uint8Array([128]))}catch(Lc){}try{g.decode(new Uint8Array([97])),t=!0}catch(Lc){t=!1}}!t&&(pa=void 0);throw L;}}else{h=e;d=h+d;e=[];for(var k=null,l,n;h<d;)l=a[h++],128>l?e.push(l):224>l?h>=d?r():(n=a[h++],194>l||128!==(n&192)?(h--,r()):e.push((l&31)<<6|n&63)):240>l?h>=d-1?r():(n=a[h++],128!==(n&192)||224===l&&160>n||237===l&&160<=n||128!==((f=a[h++])&192)?(h--,r()):e.push((l&15)<<12|(n&63)<<6|f&63)):244>=l?h>=d-2?r():(n=a[h++],128!==(n&192)||0!==(l<<28)+(n-144)>>30||128!==((f=a[h++])&192)||128!==((g=a[h++])&192)?(h--,r()):(l=(l&7)<<18|(n&63)<<12|(f&63)<<6|g&63,l-=65536,e.push((l>>10&1023)+55296,(l&1023)+56320))):r(),8192<=e.length&&(k=oa(k,e),e.length=0);h=oa(k,e)}H(b,c,h);return!0},function(a,b,c){a.s(c,G(b,c))}),Rb=N(function(a,b,c,d,e){if(2!==a.h)return!1;F(b);var f=G(b,c);d=fb(f,d,!0).K(na);f!==d&&H(b,c,d);b=a.g.h;c=K(a.g)>>>0;f=a.g.g+c;var g=f-b;0>=g&&(a.g.h=f,e(d,a,void 0,void 0,void 0),g=f-a.g.g);if(g)throw Error("k`"+c+"`"+(c-g));a.g.g=f;a.g.h=b;return!0},function(a,b,c,d,e){var f=a.l;var g=void 0===g?!1:g;var h=G(b,c,g);d=fb(h,d);d!==h&&null!=d&&(H(b,c,d,g,!0),C(d.j,D(b.j)&-33));h=d;null!=h&&E(h.j)&&!E(b.j)&&(h=h.K(na),H(b,c,h,g));f.call(a,c,h,e)}),Sb=N(function(a,b,c){if(0!==
# ...
# var Gd=[1,2,3,4,5,6,9,10,11,13,14,28,29,30,34,35,37,38,39,40,42,43,48,49,50,51,52,53,62,500],Jd=function(a,b,c,d,e,f){Jc.call(this,a,b);_.Sa(this.data,{oge:d,ogex:_.u(_.D(a,9)),ogp:_.u(_.D(a,6)),ogsr:Math.round(1/(Hd(d)?_.Pa(_.sc(c,3,1)):_.Pa(_.sc(c,2,1E-4)))),ogus:e});if(f){"ogw"in f&&(this.data.ogw=f.ogw,delete f.ogw);"ved"in f&&(this.data.ved=f.ved,delete f.ved);a=[];for(var g in f)0!=a.length&&a.push(","),a.push(Id(g)),a.push("."),a.push(Id(f[g]));f=a.join("");""!=f&&(this.data.ogad=f)}};
# _.w(Jd,Jc);var Id=function(a){a=String(a);return a.replace(".","%2E").replace(",","%2C")},Hd=function(a){if(!Kd){Kd={};for(var b=0;b<Gd.length;b++)Kd[Gd[b]]=!0}return!!Kd[a]},Kd=null;
# var Ld=function(a){_.G.call(this,a)};_.w(Ld,_.G);
# var Qd=function(){var a=Md,b=Nd,c=Pd;this.o=a;this.j=b;this.B=_.Pa(_.sc(a,2,1E-4),1E-4);this.D=_.Pa(_.sc(a,3,1),1);b=Math.random();this.A=_.t(_.E(a,1))&&b<this.B;this.C=_.t(_.E(a,1))&&b<this.D;a=0;_.t(_.E(c,1))&&(a|=1);_.t(_.E(c,2))&&(a|=2);_.t(_.E(c,3))&&(a|=4);this.F=a};Qd.prototype.log=function(a,b){try{if(Hd(a)?this.C:this.A){var c=new Jd(this.j,"quantum:gapiBuildLabel",this.o,a,this.F,b);_.sd(c)}}catch(d){}};
# _.Rd=function(a){this.Aa=a;this.j=void 0;this.o=[]};_.Rd.prototype.then=function(a,b,c){this.o.push(new Sd(a,b,c));Td(this)};_.Rd.prototype.resolve=function(a){if(void 0!==this.Aa||void 0!==this.j)throw Error("J");this.Aa=a;Td(this)};_.Rd.prototype.reject=function(a){if(void 0!==this.Aa||void 0!==this.j)throw Error("J");this.j=a;Td(this)};var Td=function(a){if(0<a.o.length){var b=void 0!==a.Aa,c=void 0!==a.j;if(b||c){b=b?a.A:a.B;c=a.o;a.o=[];try{_.wb(c,b,a)}catch(d){console.error(d)}}}};
# _.Rd.prototype.A=function(a){a.o&&a.o.call(a.j,this.Aa)};_.Rd.prototype.B=function(a){a.A&&a.A.call(a.j,this.j)};var Sd=function(a,b,c){this.o=a;this.A=b;this.j=c};
# _.I=function(){this.B=new _.Rd;this.j=new _.Rd;this.G=new _.Rd;this.D=new _.Rd;this.F=new _.Rd;this.H=new _.Rd;this.C=new _.Rd;this.A=new _.Rd;this.o=new _.Rd;this.K=new _.Rd};_.k=_.I.prototype;_.k.ii=function(){return this.B};_.k.ti=function(){return this.j};_.k.Ai=function(){return this.G};_.k.si=function(){return this.D};_.k.yi=function(){return this.F};_.k.ni=function(){return this.H};_.k.oi=function(){return this.C};_.k.Yh=function(){return this.A};_.k.Xh=function(){return this.o};_.I.j=function(){return _.wd(_.I)};
# var Ud=function(a){_.G.call(this,a)};_.w(Ud,_.G);_.Wd=function(){return _.F(_.Vd,_.Cc,1)};_.Xd=function(){return _.F(_.Vd,_.Dc,5)};
# var Yd;window.gbar_&&window.gbar_.CONFIG?Yd=window.gbar_.CONFIG[0]||{}:Yd=[];_.Vd=new Ud(Yd);
# var Dd,Ed,Nd,Pd,Md;Dd=_.F(_.Vd,_.vd,3)||new _.vd;Ed=_.Wd()||new _.Cc;_.J=new Fd;Nd=_.Wd()||new _.Cc;Pd=_.Xd()||new _.Dc;Md=_.F(_.Vd,Ld,4)||new Ld;_.Zd=new Qd;
# _.A("gbar_._DumpException",function(a){_.J?_.J.log(a):console.error(a)});
# _.$d=new Fc(_.J);
# _.Zd.log(8,{m:"BackCompat"==document.compatMode?"q":"s"});_.A("gbar.A",_.Rd);_.Rd.prototype.aa=_.Rd.prototype.then;_.A("gbar.B",_.I);_.I.prototype.ba=_.I.prototype.ti;_.I.prototype.bb=_.I.prototype.Ai;_.I.prototype.bd=_.I.prototype.yi;_.I.prototype.bf=_.I.prototype.ii;_.I.prototype.bg=_.I.prototype.si;_.I.prototype.bh=_.I.prototype.ni;_.I.prototype.bi=_.I.prototype.oi;_.I.prototype.bj=_.I.prototype.Yh;_.I.prototype.bk=_.I.prototype.Xh;_.A("gbar.a",_.I.j());var ae=new Ec(window);_.zd("api",ae);
# var be=_.Xd()||new _.Dc;window.__PVT=_.u(_.D(be,8));_.zd("eq",_.$d);
#
# }catch(e){_._DumpException(e)}
# try{
# var ce=function(a){_.G.call(this,a)};_.w(ce,_.G);
# var de=function(){_.H.call(this);this.o=[];this.j=[]};_.w(de,_.H);de.prototype.A=function(a,b){this.o.push({features:a,options:b})};de.prototype.init=function(a,b,c){window.gapi={};var d=window.___jsl={};d.h=_.u(_.D(a,1));_.pc(a,12)&&(d.dpo=_.t(_.E(a,12)));d.ms=_.u(_.D(a,2));d.m=_.u(_.D(a,3));d.l=[];_.D(b,1)&&(a=_.D(b,3))&&this.j.push(a);_.D(c,1)&&(c=_.D(c,2))&&this.j.push(c);_.A("gapi.load",(0,_.z)(this.A,this));return this};
# var ee=_.F(_.Vd,_.Gc,14)||new _.Gc,fe=_.F(_.Vd,_.Hc,9)||new _.Hc,ge=new ce,he=new de;he.init(ee,fe,ge);_.zd("gs",he);
#
# }catch(e){_._DumpException(e)}
# })(this.gbar_);
# // Google Inc.
# ;});})();(function(){window.jsl.dh('_gTYkY-OmHLaF9u8Pn8G48Ao_5','\x3cspan class\x3d\x22z1asCe E9hVAb\x22\x3e\x3csvg focusable\x3d\x22false\x22 xmlns\x3d\x22http://www.w3.org/2000/svg\x22 viewBox\x3d\x220 0 24 24\x22\x3e\x3cpath d\x3d\x22M13.85 22.25h-3.7c-.74 0-1.36-.54-1.45-1.27l-.27-1.89c-.27-.14-.53-.29-.79-.46l-1.8.72c-.7.26-1.47-.03-1.81-.65L2.2 15.53c-.35-.66-.2-1.44.36-1.88l1.53-1.19c-.01-.15-.02-.3-.02-.46 0-.15.01-.31.02-.46l-1.52-1.19c-.59-.45-.74-1.26-.37-1.88l1.85-3.19c.34-.62 1.11-.9 1.79-.63l1.81.73c.26-.17.52-.32.78-.46l.27-1.91c.09-.7.71-1.25 1.44-1.25h3.7c.74 0 1.36.54 1.45 1.27l.27 1.89c.27.14.53.29.79.46l1.8-.72c.71-.26 1.48.03 1.82.65l1.84 3.18c.36.66.2 1.44-.36 1.88l-1.52 1.19c.01.15.02.3.02.46s-.01.31-.02.46l1.52 1.19c.56.45.72 1.23.37 1.86l-1.86 3.22c-.34.62-1.11.9-1.8.63l-1.8-.72c-.26.17-.52.32-.78.46l-.27 1.91c-.1.68-.72 1.22-1.46 1.22zm-3.23-2h2.76l.37-2.55.53-.22c.44-.18.88-.44 1.34-.78l.45-.34 2.38.96 1.38-2.4-2.03-1.58.07-.56c.03-.26.06-.51.06-.78s-.03-.53-.06-.78l-.07-.56 2.03-1.58-1.39-2.4-2.39.96-.45-.35c-.42-.32-.87-.58-1.33-.77l-.52-.22-.37-2.55h-2.76l-.37 2.55-.53.21c-.44.19-.88.44-1.34.79l-.45.33-2.38-.95-1.39 2.39 2.03 1.58-.07.56a7 7 0 0 0-.06.79c0 .26.02.53.06.78l.07.56-2.03 1.58 1.38 2.4 2.39-.96.45.35c.43.33.86.58 1.33.77l.53.22.38 2.55z\x22\x3e\x3c/path\x3e\x3ccircle cx\x3d\x2212\x22 cy\x3d\x2212\x22 r\x3d\x223.5\x22\x3e\x3c/circle\x3e\x3c/svg\x3e\x3c/span\x3e\x3cdiv jsname\x3d\x22suEOdc\x22 class\x3d\x22ZOyvub\x22\x3eInstellingen\x3c/div\x3e');})();(function(){window.jsl.dh('_gTYkY-OmHLaF9u8Pn8G48Ao_7','\x3cspan class\x3d\x22gb\x22 style\x3d\x22display:none\x22\x3e\x3c/span\x3e\x3cdiv class\x3d\x22gb_oa gb_Xd gb_1a\x22 id\x3d\x22gb\x22\x3e\x3cdiv class\x3d\x22gb_Vd gb_Xa gb_Kd\x22 data-ogsr-up\x3d\x22\x22\x3e\x3cdiv class\x3d\x22gb_Re\x22\x3e\x3cdiv class\x3d\x22gb_Sc\x22\x3e\x3cdiv class\x3d\x22gb_z gb_gd gb_f gb_zf\x22 data-ogsr-fb\x3d\x22true\x22 data-ogsr-alt\x3d\x22\x22 id\x3d\x22gbwa\x22\x3e\x3cdiv class\x3d\x22gb_yf\x22\x3e\x3ca class\x3d\x22gb_A\x22 aria-label\x3d\x22Google-apps\x22 href\x3d\x22https://www.google.be/intl/nl/about/products?tab\x3dwh\x22 aria-expanded\x3d\x22false\x22 role\x3d\x22button\x22 tabindex\x3d\x220\x22\x3e\x3csvg class\x3d\x22gb_Ue\x22 focusable\x3d\x22false\x22 viewbox\x3d\x220 0 24 24\x22\x3e\x3cpath d\x3d\x22M6,8c1.1,0 2,-0.9 2,-2s-0.9,-2 -2,-2 -2,0.9 -2,2 0.9,2 2,2zM12,20c1.1,0 2,-0.9 2,-2s-0.9,-2 -2,-2 -2,0.9 -2,2 0.9,2 2,2zM6,20c1.1,0 2,-0.9 2,-2s-0.9,-2 -2,-2 -2,0.9 -2,2 0.9,2 2,2zM6,14c1.1,0 2,-0.9 2,-2s-0.9,-2 -2,-2 -2,0.9 -2,2 0.9,2 2,2zM12,14c1.1,0 2,-0.9 2,-2s-0.9,-2 -2,-2 -2,0.9 -2,2 0.9,2 2,2zM16,6c0,1.1 0.9,2 2,2s2,-0.9 2,-2 -0.9,-2 -2,-2 -2,0.9 -2,2zM12,8c1.1,0 2,-0.9 2,-2s-0.9,-2 -2,-2 -2,0.9 -2,2 0.9,2 2,2zM18,14c1.1,0 2,-0.9 2,-2s-0.9,-2 -2,-2 -2,0.9 -2,2 0.9,2 2,2zM18,20c1.1,0 2,-0.9 2,-2s-0.9,-2 -2,-2 -2,0.9 -2,2 0.9,2 2,2z\x22\x3e\x3c/path\x3e\x3c/svg\x3e\x3c/a\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3ca class\x3d\x22gb_1 gb_2 gb_8d gb_8c\x22 href\x3d\x22https://accounts.google.com/ServiceLogin?hl\x3dnl\x26amp;passive\x3dtrue\x26amp;continue\x3dhttps://www.google.com/search%3Fq%3Dsite%253A%2522https%253A%252F%252Fwww.facebook.com%2522%2Bprivacy%2Bpolicy%26num%3D3\x26amp;ec\x3dGAZAAQ\x22 target\x3d\x22_top\x22\x3eInloggen\x3c/a\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e');})();(function(){window.jsl.dh('_gTYkY-OmHLaF9u8Pn8G48Ao_10','\x3cg-menu jsname\x3d\x22xl07Ob\x22 class\x3d\x22cF4V5c zriOQb UU8UAb gLSAk rShyOb\x22 jscontroller\x3d\x22WlNQGd\x22 role\x3d\x22menu\x22 tabindex\x3d\x22-1\x22 jsaction\x3d\x22PSl28c;focus:h06R8;keydown:uYT2Vb;mouseenter:WOQqYb;mouseleave:Tx5Rb;mouseover:IgJl9c\x22\x3e\x3cg-menu-item jsname\x3d\x22NNJLud\x22 jscontroller\x3d\x22CnSW2d\x22 class\x3d\x22ErsxPb\x22 role\x3d\x22none\x22 data-short-label\x3d\x22\x22 jsdata\x3d\x22zPXzie;_;B0CclY\x22\x3e\x3cdiv jsname\x3d\x22ibnC6b\x22 class\x3d\x22znKVS OSrXXb tnhqA\x22 role\x3d\x22none\x22\x3e\x3ca href\x3d\x22/search?q\x3dsite:%22https://www.facebook.com%2 ...
# try{
# _.ie=function(a,b,c){if(!a.o)if(c instanceof Array){c=_.Za(c);for(var d=c.next();!d.done;d=c.next())_.ie(a,b,d.value)}else{d=(0,_.z)(a.F,a,b);var e=a.B+c;a.B++;b.setAttribute("data-eqid",e);a.D[e]=d;b&&b.addEventListener?b.addEventListener(c,d,!1):b&&b.attachEvent?b.attachEvent("on"+c,d):a.A.log(Error("E`"+b))}};
#
# }catch(e){_._DumpException(e)}
# try{
# /*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# _.je=function(){if(!_.n.addEventListener||!Object.defineProperty)return!1;var a=!1,b=Object.defineProperty({},"passive",{get:function(){a=!0}});try{_.n.addEventListener("test",function(){},b),_.n.removeEventListener("test",function(){},b)}catch(c){}return a}();
# _.ke=_.Hb?"webkitTransitionEnd":"transitionend";
#
# }catch(e){_._DumpException(e)}
# try{
# var le=document.querySelector(".gb_z .gb_A"),me=document.querySelector("#gb.gb_Jc");le&&!me&&_.ie(_.$d,le,"click");
#
# }catch(e){_._DumpException(e)}
# try{
# var Xh=function(a){_.H.call(this);this.C=a;this.A=null;this.o={};this.D={};this.j={};this.B=null};_.w(Xh,_.H);_.Yh=function(a){if(a.A)return a.A;for(var b in a.j)if(a.j[b].Me()&&a.j[b].Ib())return a.j[b];return null};_.k=Xh.prototype;_.k.mf=function(a){a&&_.Yh(this)&&a!=_.Yh(this)&&_.Yh(this).Gd(!1);this.A=a};_.k.rg=function(a){a=this.j[a]||a;return _.Yh(this)==a};_.k.ve=function(a,b){b=b.Pc();if(this.o[a]&&this.o[a][b])for(var c=0;c<this.o[a][b].length;c++)try{this.o[a][b][c]()}catch(d){this.C.log(d)}};
# _.k.Ch=function(a){return!this.D[a.Pc()]};_.k.Jg=function(a){this.j[a]&&(_.Yh(this)&&_.Yh(this).Pc()==a||this.j[a].Gd(!0))};_.k.Wa=function(a){this.B=a;for(var b in this.j)this.j[b].Me()&&this.j[b].Wa(a)};_.k.hf=function(a){this.j[a.Pc()]=a};_.k.me=function(a){return a in this.j?this.j[a]:null};var Zh=new Xh(_.J);_.zd("dd",Zh);
#
# }catch(e){_._DumpException(e)}
# try{
# var zj=document.querySelector(".gb_Ma .gb_A"),Aj=document.querySelector("#gb.gb_Jc");zj&&!Aj&&_.ie(_.$d,zj,"click");
#
# }catch(e){_._DumpException(e)}
# })(this.gbar_);
# // Google Inc.
# ;this.gbar_=this.gbar_||{};(function(_){var window=this;
# try{
# /*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# _.ne=function(a,b){return 0<=(0,_.vb)(a,b)};_.oe=function(a){var b=typeof a;return"object"!=b?b:a?Array.isArray(a)?"array":b:"null"};_.pe=function(a){var b=_.oe(a);return"array"==b||"object"==b&&"number"==typeof a.length};_.qe=function(a,b){var c=Array.prototype.slice.call(arguments,1);return function(){var d=c.slice();d.push.apply(d,arguments);return a.apply(this,d)}};try{(new self.OffscreenCanvas(0,0)).getContext("2d")}catch(a){}_.re=_.C||_.Hb;
# _.se=function(a,b){this.width=a;this.height=b};_.k=_.se.prototype;_.k.aspectRatio=function(){return this.width/this.height};_.k.bc=function(){return!(this.width*this.height)};_.k.ceil=function(){this.width=Math.ceil(this.width);this.height=Math.ceil(this.height);return this};_.k.floor=function(){this.width=Math.floor(this.width);this.height=Math.floor(this.height);return this};_.k.round=function(){this.width=Math.round(this.width);this.height=Math.round(this.height);return this};
# var ue,xe;_.te=function(a,b){return(b||document).getElementsByTagName(String(a))};_.ve=function(a,b){_.Qa(b,function(c,d){c&&"object"==typeof c&&c.Pb&&(c=c.vb());"style"==d?a.style.cssText=c:"class"==d?a.className=c:"for"==d?a.htmlFor=c:ue.hasOwnProperty(d)?a.setAttribute(ue[d],c):0==d.lastIndexOf("aria-",0)||0==d.lastIndexOf("data-",0)?a.setAttribute(d,c):a[d]=c})};
# ue={cellpadding:"cellPadding",cellspacing:"cellSpacing",colspan:"colSpan",frameborder:"frameBorder",height:"height",maxlength:"maxLength",nonce:"nonce",role:"role",rowspan:"rowSpan",type:"type",usemap:"useMap",valign:"vAlign",width:"width"};_.ye=function(a,b){var c=b[1],d=_.we(a,String(b[0]));c&&("string"===typeof c?d.className=c:Array.isArray(c)?d.className=c.join(" "):_.ve(d,c));2<b.length&&xe(a,d,b);return d};
# xe=function(a,b,c){function d(h){h&&b.appendChild("string"===typeof h?a.createTextNode(h):h)}for(var e=2;e<c.length;e++){var f=c[e];if(!_.pe(f)||_.mb(f)&&0<f.nodeType)d(f);else{a:{if(f&&"number"==typeof f.length){if(_.mb(f)){var g="function"==typeof f.item||"string"==typeof f.item;break a}if("function"===typeof f){g="function"==typeof f.item;break a}}g=!1}_.wb(g?_.ma(f):f,d)}}};_.ze=function(a){return _.we(document,a)};
# _.we=function(a,b){b=String(b);"application/xhtml+xml"===a.contentType&&(b=b.toLowerCase());return a.createElement(b)};_.Ae=function(a){for(var b;b=a.firstChild;)a.removeChild(b)};_.Be=function(a){return _.mb(a)&&1==a.nodeType};_.Ce=function(a){return 9==a.nodeType?a:a.ownerDocument||a.document};_.De=function(a,b){for(var c=0;a;){if(b(a))return a;a=a.parentNode;c++}return null};
#
# }catch(e){_._DumpException(e)}
# try{
# /*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# _.Re=function(a){_.G.call(this,a)};_.w(_.Re,_.G);_.Se=function(a){return _.Bd(_.xd.j(),a)};
#
# }catch(e){_._DumpException(e)}
# try{
# _.Ej=function(a,b,c){return void 0!==_.qc(a,b,c,!1)};_.Fj=function(a){_.G.call(this,a)};_.w(_.Fj,_.G);
#
# }catch(e){_._DumpException(e)}
# try{
# _.Gj=function(a,b,c){a.rel=c;-1!=c.toLowerCase().indexOf("stylesheet")?(a.href=_.Qc(b),(b=_.od(a.ownerDocument&&a.ownerDocument.defaultView))&&a.setAttribute("nonce",b)):a.href=b instanceof _.Oc?_.Qc(b):b instanceof _.Sc?_.Tc(b):_.Tc(_.Yc(b))};
#
# }catch(e){_._DumpException(e)}
# try{
# /*
#
#  SPDX-License-Identifier: Apache-2.0
# */
# var Hj;try{new URL("s://g"),Hj=!0}catch(a){Hj=!1}_.Ij=Hj;
#
# }catch(e){_._DumpException(e)}
# try{
# _.Jj=function(a){var b,c,d=null==(c=(b=(a.ownerDocument&&a.ownerDocument.defaultView||window).document).querySelector)?void 0:c.call(b,"script[nonce]");(b=d?d.nonce||d.getAttribute("nonce")||"":"")&&a.setAttribute("nonce",b)};_.Kj=function(a){var b=_.Mc();a=b?b.createScriptURL(a):a;return new _.Oc(a,_.Nc)};
# /*
#
#  SPDX-License-Identifier: Apache-2.0
# */
#
# }catch(e){_._DumpException(e)}
# try{
# var Lj=function(a,b,c){_.Zd.log(46,{att:a,max:b,url:c})},Nj=function(a,b,c){_.Zd.log(47,{att:a,max:b,url:c});a<b?Mj(a+1,b):_.J.log(Error("ha`"+a+"`"+b),{url:c})},Mj=function(a,b){if(Oj){var c=_.ze("SCRIPT");c.async=!0;c.type="text/javascript";c.charset="UTF-8";c.src=_.Pc(Oj);_.Jj(c);c.onload=_.qe(Lj,a,b,c.src);c.onerror=_.qe(Nj,a,b,c.src);_.Zd.log(45,{att:a,max:b,url:c.src});_.te("HEAD")[0].appendChild(c)}},Pj=function(a){_.G.call(this,a)};_.w(Pj,_.G);
# var Qj=_.F(_.Vd,Pj,17)||new Pj,Rj,Oj=(Rj=_.F(Qj,_.Fj,1))?_.Kj(_.D(Rj,4)||""):null,Sj,Tj=(Sj=_.F(Qj,_.Fj,2))?_.Kj(_.D(Sj,4)||""):null,Uj=function(){Mj(1,2);if(Tj){var a=_.ze("LINK");a.setAttribute("type","text/css");_.Gj(a,Tj,"stylesheet");var b=_.od();b&&a.setAttribute("nonce",b);_.te("HEAD")[0].appendChild(a)}};
# (function(){var a=_.Wd();if(_.E(a,18))Uj();else{var b=_.D(a,19)||0;window.addEventListener("load",function(){window.setTimeout(Uj,b)})}})();
#
# }catch(e){_._DumpException(e)}
# })(this.gbar_);
# // Google Inc.
# ;});})();(function(){google.drty&&google.drty(undefined,true);})();});</script><div></div><div id="Rvx4kc" jsaction="rcuQ6b:npT2md" jscontroller="MTV2Lb" src="/uviewer?q=site%3A%22https%3A%2F%2Fwww.facebook.com%22+privacy+policy&amp;num=3&amp;origin=https%3A%2F%2Fwww.google.com&amp;ptzd=1" style="display:none"><iframe jsname="L5Fo6c" src="about:blank"></iframe></div><div id="DDeXhf"></div><div id="lfootercc"><script nonce="XJ1bSfQIes_SIM50XbvPAQ">(function(){for(var i in google.iir||{}){_setImagesSrc([i],google.iir[i]);}google.iir={};})();
# google.jslm=3;</script><div class="yp" data-async-context="async_id_prefix:" data-async-context-required="async_id_prefix" data-async-type="reviewDialog" data-jiis="up" id="reviewDialog"></div><div id="dbg_"></div></div></body></html>

# %%
allData = soup.find_all("div",{"class":"g"})
print(allData)
print("")
# Out:
# [<div class="g Ww4FFb vt6azd tF2Cxc" data-hveid="CBAQAA" data-ved="2ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4QFSgAegQIEBAA" jsaction="QyLbLe:OMITjf" jscontroller="SC7lYd" lang="en" style="width:600px"><div class="kvH3mc BToiNc UK95Uc" data-sokoban-container="ih6Jnb_aXHwIb"><div class="Z26q7c UK95Uc jGGQ5e" data-header-feature="0"><div class="yuRUbf"><a data-ved="2ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4QFnoECAsQAQ" href="https://www.facebook.com/privacy/policy" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;url=https://www.facebook.com/privacy/policy&amp;ved=2ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4QFnoECAsQAQ"><br/><h3 class="LC20lb MBeuO DKV0Md">Meta Privacy Policy - How Meta collects and uses user data</h3><div class="TbwUpd NJjxre"><cite class="iUh30 qLRx3b tjvcx" role="text">https://www.facebook.com<span class="dyjrff qzEoUe" role="text"> › privacy › policy</span></cite></div></a><div class="B6fmyf"><div class="TbwUpd"><cite class="iUh30 qLRx3b tjvcx" role="text">https://www.facebook.com<span class="dyjrff qzEoUe" role="text"> › privacy › policy</span></cite></div><div class="eFM0qc"><span><span class="PEA3Bd" jsaction="KyPa0e:Y0y4c;BVfjhf:VFzweb;wjOG7e:gDkf4c;" jscontroller="nabPbb"><g-popup jsaction="A05xBd:IYtByb;EOZ57e:WFrRFb;" jscontroller="DPreE" jsdata="mVjAjf;_;B0CclU" jsname="V68bde"><div aria-expanded="false" aria-haspopup="true" aria-label="Resultaatopties" class="rIbAWc" jsaction="WFrRFb;keydown:uYT2Vb" jsname="oYxtQd" role="button" tabindex="0"><div class="vlFZgc" data-ved="2ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4Q7B16BAgLEAU" jsname="LgbsSe"><span class="gTl8xb"></span></div></div><div class="EwsJzb sAKBe B8Kd8d" id="_gTYkY-OmHLaF9u8Pn8G48Ao_25" jsname="V68bde" style="display:none;z-index:200"></div></g-popup></span></span></div></div></div></div><div class="Z26q7c UK95Uc" data-content-feature="1"><div class="VwiC3b yXK7lf MUxGbd yDYNvb lyLwlc lEBKkf" style="-webkit-line-clamp:2"><span>This helps you use Meta Products in the way that's right for you. In the <em>Privacy Policy</em>, we explain how we collect, use, share, retain and transfer information.</span></div></div><div class="Z26q7c UK95Uc"></div></div></div>, <div class="g Ww4FFb vt6azd tF2Cxc" data-hveid="CA8QAA" data-ved="2ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4QFSgAegQIDxAA" jsaction="QyLbLe:OMITjf" jscontroller="SC7lYd" lang="en" style="width:600px"><div class="kvH3mc BToiNc UK95Uc" data-sokoban-container="ih6Jnb_uh7Phc"><div class="Z26q7c UK95Uc jGGQ5e" data-header-feature="0"><div class="yuRUbf"><a data-ved="2ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4QFnoECAoQAQ" href="https://www.facebook.com/about/privacy/previous" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;url=https://www.facebook.com/about/privacy/previous&amp;ved=2ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4QFnoECAoQAQ"><br/><h3 class="LC20lb MBeuO DKV0Md">Data Policy - Facebook</h3><div class="TbwUpd NJjxre"><cite class="iUh30 qLRx3b tjvcx" role="text">https://www.facebook.com<span class="dyjrff qzEoUe" role="text"> › previous</span></cite></div></a><div class="B6fmyf"><div class="TbwUpd"><cite class="iUh30 qLRx3b tjvcx" role="text">https://www.facebook.com<span class="dyjrff qzEoUe" role="text"> › previous</span></cite></div><div class="eFM0qc"><span><span class="PEA3Bd" jsaction="KyPa0e:Y0y4c;BVfjhf:VFzweb;wjOG7e:gDkf4c;" jscontroller="nabPbb"><g-popup jsaction="A05xBd:IYtByb;EOZ57e:WFrRFb;" jscontroller="DPreE" jsdata="mVjAjf;_;B0CclU" jsname="V68bde"><div aria-expanded="false" aria-haspopup="true" aria-label="Resultaatopties" class="rIbAWc" jsaction="WFrRFb;keydown:uYT2Vb" jsname="oYxtQd" role="button" tabindex="0"><div class="vlFZgc" data-ved="2ahUKEwij68OF9Zj6AhW2gv0HHZ8gDq4Q7B16BAgKEAU" jsname="LgbsSe"><span class="gTl8xb"></span></div></div><div class="EwsJzb sAKBe B8Kd8d" id="_gTYkY-OmHLaF9u8Pn8G48Ao_21" jsname="V68bde" style="display:none;z-index:200"></div></g-popup></span></span><a class="fl iUh30" href="https://translate.google.com/translate?hl=nl&amp;sl=en&amp;u=https://www.facebook.com/about/privacy/previous&amp;prev=search&amp;pto=aue" ping ...

# %%
print("len alldata: " + str(len(allData)))
# Out:
# len alldata: 2

# %%
for i in range(0,len(allData)):
    link = allData[i].find('a').get('href')
    print("f3")
    print("")

    if(link is not None):
        if(link.find('https') != -1 and link.find('http') == 0 and link.find('aclk') == -1):
            print(link)
# Out:
# f3
#
# https://www.facebook.com/privacy/policy
# f3
#
# https://www.facebook.com/about/privacy/previous
